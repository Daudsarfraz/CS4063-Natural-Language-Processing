# %% [markdown]
# # Task 1: Bigrams & Trigrams

# %%
import nltk # Importing NLTK

# %%
from nltk.book import *
from nltk.util import ngrams
from nltk.collocations import *
from nltk.collocations import TrigramCollocationFinder, TrigramAssocMeasures

# %%
list1 = [text1, text2, text3]
for idx,i in enumerate(list1, start = 1):
    print(f"Start for Text {idx}-> \n", i)
    words = sorted(set(i))[280:]
    long_words = [w for w in words if len(w) > 16]
    print("\nPrint Long Words : \n",long_words)
    freqdist = FreqDist(text1)
    high_freq = [w for w in words if freqdist[w] > 500]
    print("\nPrint High Frequency Words : \n",high_freq)
    words = sorted(set(i))
    ed_words = [w for w in words if w.endswith('ed')]
    print("\nLength of Words End with ed \n",len(ed_words))
    print(ed_words)
    bigram = list(bigrams(i))
    bigram_10 = list(bigrams(i))[:10]
    print("\nPrint 10 Bigrams : \n ", bigram_10)
    trigram = list(ngrams(i, 3))
    trigram_5 = TrigramCollocationFinder.from_words(i).nbest(TrigramAssocMeasures().pmi, 5)
    print("\nPrint 5 Trigrams :\n ", trigram_5)
    print("================================ \n")
# Out:
# Start for Text 1->
#  <Text: Moby Dick by Herman Melville 1851>
#
# Print Long Words :
#  ['cannibalistically', 'characteristically', 'circumnavigations', 'comprehensiveness', 'indispensableness', 'preternaturalness', 'subterraneousness', 'superstitiousness', 'uncomfortableness', 'uncompromisedness', 'uninterpenetratingly']
#
# Print High Frequency Words :
#  ['Ahab', 'But', 'I', 'The', 'a', 'all', 'an', 'and', 'are', 'as', 'at', 'be', 'but', 'by', 'for', 'from', 'had', 'have', 'he', 'him', 'his', 'in', 'into', 'is', 'it', 'like', 'man', 'me', 'more', 'my', 'not', 'now', 'of', 'on', 'one', 'or', 'out', 's', 'ship', 'so', 'some', 'that', 'the', 'their', 'then', 'there', 'they', 'this', 'to', 'up', 'upon', 'was', 'were', 'whale', 'when', 'which', 'with', 'you']
#
# Length of Words End with ed
#  2196
# ['Abashed', 'Accursed', 'Affected', 'Affrighted', 'Alarmed', 'Alfred', 'Animated', 'Applied', 'Arched', 'Arrayed', 'Arrived', 'Assaulted', 'Attached', 'Befooled', 'Belated', 'Beloved', 'Belubed', 'Buoyed', 'Commanded', 'Contrasted', 'Coppered', 'Crazed', 'Created', 'Crossed', 'Cruppered', 'Crushed', 'Cursed', 'Cussed', 'Desecrated', 'Detached', 'Dragged', 'Emboldened', 'Enveloped', 'Espied', 'Fashioned', 'Fired', 'Floundered', 'Forced', 'Frighted', 'Gifted', 'Gnawed', 'Gulfweed', 'Headed', 'Heated', 'Heed', 'Horned', 'Indeed', 'Jumped', 'Killed', 'Lashed', 'Launched', 'Led', 'Lifted', 'Loaded', 'Measured', 'Mixed', 'Muffled', 'Obed', 'Passed', 'Petrified', 'Planted', 'Posted', 'Proceed', 'Red', 'Regarded', 'Relieved', 'Screwed', 'Seated', 'Seed', 'Shipped', 'Shrouded', 'Smuggled', 'Soothed', 'Started', 'Startled', 'Steed', 'Stretched', 'Stripped', 'Supplied', 'Suspended', 'Tempered', 'Thrusted', 'Tied', 'Transported', 'Tumbled', 'Tusked', 'Unappalled', 'United', 'Unobserved', 'Unshored', 'Untried', 'Whelped', 'Wrapped', 'Wretched', 'Wrinkled', 'Zoned', 'abandoned', 'abased', 'abashed', 'abated', 'abed', 'abhorred', 'abided', 'abominated', 'abounded', 'abridged', 'absorbed', 'abstained', 'abstracted', 'accelerated', 'accommodated', 'accompanied', 'accomplished', 'accosted', 'accounted', 'accumulated', 'accursed', 'accustomed', 'ached', 'achieved', 'acquainted', 'acquiesced', 'acquired', 'acted', 'actuated', 'adapted', 'added', 'addressed', 'administered', 'admitted', 'admonished', 'adopted', 'adorned', 'advanced', 'advertised', 'advised', 'aerated', 'affected', 'affixed', 'afflicted', 'afforded', 'affrighted', 'affronted', 'aged', 'aggregated', 'aggrieved', 'agitated', 'agonized', 'agreed', 'aimed', 'alarmed', 'alleged', 'allotted', 'allowed', 'alluded', 'allured', 'altered', 'amounted', 'amplified', 'amputated', 'analysed', 'anchored', 'animated', 'annihilated', 'announced', 'anointed', 'answered', 'anticipated', 'antlered', 'appalled', 'apparelled', 'appeared', 'applied', 'appointed', 'apportioned', 'apprised', 'approached', 'appropriated', 'approved', 'arched', 'argued', 'armed', 'arranged', 'arrayed', 'arrested', 'arrived', 'articulated', 'ascended', 'ascertained', 'ascribed', 'asked', 'assailed', 'assembled', 'assented', 'asserted', 'assigned', 'assisted', 'associated', 'assumed', 'assured', 'astonished', 'attached', 'attacked', 'attained', 'attended', 'attenuated', 'attested', 'attracted', 'attuned', 'augmented', 'authenticated', 'authorized', 'averred', 'averted', 'awaited', 'awakened', 'awarded', 'awed', 'backed', 'baffled', 'bagged', 'baked', 'balanced', 'ballasted', 'balmed', 'bandaged', 'banded', 'bandied', 'banished', 'banked', 'banned', 'bannered', 'baptised', 'baptized', 'barbacued', 'barbed', 'barnacled', 'barred', 'bartered', 'based', 'basketed', 'bathed', 'battened', 'battled', 'bawled', 'beached', 'beaked', 'beamed', 'bearded', 'becalmed', 'becharmed', 'beckoned', 'bed', 'bedarned', 'bedded', 'bedeadened', 'bedraggled', 'befogged', 'befooled', 'befriended', 'begged', 'begrimed', 'beheaded', 'bejuggled', 'belayed', 'believed', 'belled', 'bellied', 'belonged', 'beloved', 'belted', 'bended', 'bepatched', 'bequeathed', 'besieged', 'besmoked', 'besooted', 'bestirred', 'bestowed', 'bestreaked', 'betokened', 'betrayed', 'bewildered', 'bewitched', 'biased', 'billed', 'billeted', 'blackened', 'bladed', 'blanched', 'blasted', 'blazed', 'bleached', 'bled', 'bleed', 'blended', 'blessed', 'blighted', 'blinded', 'blistered', 'bloated', 'blooded', 'bloodshed', 'blotted', 'blunted', 'blurred', 'boarded', 'boasted', 'bobbed', 'bodied', 'bolted', 'boomed', 'bordered', 'bored', 'borrowed', 'bottled', 'bottomed', 'bounced', 'bounded', 'bowed', 'bowled', 'braced', 'braided', 'brained', 'branded', 'breasted', 'breathed', 'bred', 'breed', 'bressed', 'brewed', 'brimmed', 'brindled', 'broidered', 'broiled', 'browed', 'bruised', 'bruited', 'brushed', 'bubbled', 'budged', 'builded', 'bullied', 'bumped', 'bunched', 'buoyed', 'buried', 'b ...
#
# Print 10 Bigrams :
#   [('[', 'Moby'), ('Moby', 'Dick'), ('Dick', 'by'), ('by', 'Herman'), ('Herman', 'Melville'), ('Melville', '1851'), ('1851', ']'), (']', 'ETYMOLOGY'), ('ETYMOLOGY', '.'), ('.', '(')]
# Print 5 Trigrams :
#   [('AFTER', 'EXCHANGING', 'HAILS'), ('Anacharsis', 'Clootz', 'deputation'), ('CAULKING', 'ITS', 'SEAMS'), ('ELIZABETH', 'OAKES', 'SMITH'), ('Et', 'tu', 'Brute')]
# ================================
#
# Start for Text 2->
#  <Text: Sense and Sensibility by Jane Austen 1811>
#
# Print Long Words :
#  ['companionableness', 'disinterestedness', 'disqualifications']
#
# Print High Frequency Words :
#  ['I', 'The', 'a', 'all', 'an', 'and', 'are', 'as', 'at', 'be', 'but', 'by', 'for', 'from', 'had', 'have', 'he', 'him', 'his', 'in', 'into', 'is', 'it', 'like', 'man', 'me', 'more', 'my', 'not', 'now', 'of', 'on', 'one', 'or', 'out', 's', 'so', 'some', 'that', 'the', 'their', 'then', 'there', 'they', 'this', 'to', 'up', 'upon', 'was', 'were', 'when', 'which', 'with', 'you']
#
# Length of Words End with ed
#  902
# ['Ashamed', 'Astonished', 'Chagrined', 'Determined', 'Disappointed', 'Encouraged', 'Engaged', 'Indeed', 'Invited', 'Offended', 'Pleased', 'Reserved', 'Supported', 'Surprised', 'Watched', 'abandoned', 'abhorred', 'abounded', 'abstracted', 'abused', 'accepted', 'accompanied', 'accomplished', 'accosted', 'accounted', 'acknowledged', 'acquainted', 'acquiesced', 'acquired', 'acquitted', 'acted', 'adapted', 'added', 'addressed', 'admired', 'admitted', 'adopted', 'adorned', 'advanced', 'advised', 'affected', 'affixed', 'afflicted', 'afforded', 'agitated', 'agreed', 'aimed', 'alarmed', 'alienated', 'alighted', 'alleged', 'allowed', 'alluded', 'altered', 'amended', 'amounted', 'amused', 'animated', 'annexed', 'announced', 'answered', 'anticipated', 'apologized', 'appeared', 'appeased', 'applauded', 'applied', 'appointed', 'apprehended', 'approached', 'approved', 'arranged', 'arrived', 'ascended', 'ascertained', 'ashamed', 'asked', 'assembled', 'assented', 'asserted', 'assigned', 'assisted', 'assured', 'astonished', 'atoned', 'attached', 'attacked', 'attained', 'attempted', 'attended', 'attracted', 'attributed', 'augmented', 'authorised', 'availed', 'avoided', 'awaited', 'awakened', 'banished', 'bathed', 'beamed', 'bed', 'begged', 'behaved', 'believed', 'belonged', 'beloved', 'benefited', 'bequeathed', 'bestowed', 'betrayed', 'biased', 'blamed', 'blasted', 'blessed', 'blinded', 'blundered', 'blushed', 'boiled', 'borrowed', 'bowed', 'branched', 'bred', 'breed', 'brightened', 'bruised', 'calculated', 'called', 'carried', 'caused', 'ceased', 'celebrated', 'censured', 'centered', 'chained', 'chanced', 'changed', 'charged', 'charmed', 'cheated', 'checked', 'cheered', 'cherished', 'choked', 'circumstanced', 'claimed', 'clapped', 'classed', 'cleared', 'clogged', 'closed', 'collected', 'coloured', 'comforted', 'commanded', 'commended', 'commissioned', 'communicated', 'compared', 'complained', 'completed', 'complicated', 'composed', 'comprehended', 'comprised', 'concealed', 'conceited', 'concerned', 'concluded', 'condemned', 'conditioned', 'conducted', 'confessed', 'confined', 'confirmed', 'confounded', 'confused', 'congratulated', 'conjectured', 'connected', 'consented', 'considered', 'consisted', 'consoled', 'conspired', 'constrained', 'consulted', 'contained', 'contented', 'continued', 'contracted', 'contradicted', 'contrasted', 'contributed', 'contrived', 'controlled', 'conversed', 'conveyed', 'convinced', 'copied', 'couched', 'counteracted', 'courted', 'covered', 'created', 'cried', 'crimsoned', 'crooked', 'crowned', 'cultivated', 'danced', 'dared', 'dawdled', 'dawned', 'debated', 'deceived', 'decided', 'declared', 'declined', 'deed', 'deemed', 'defended', 'defined', 'degraded', 'dejected', 'delayed', 'delighted', 'delineated', 'delivered', 'demanded', 'denied', 'denoted', 'departed', 'depended', 'depressed', 'deprived', 'derived', 'described', 'deserted', 'deserved', 'desired', 'despised', 'destroyed', 'detected', 'determined', 'deterred', 'detested', 'devolved', 'devoted', 'died', 'differed', 'dignified', 'diminished', 'dined', 'directed', 'disappeared', 'disappointed', 'disapproved', 'discarded', 'discharged', 'discomposed', 'discontented', 'discovered', 'disengaged', 'disgraced', 'disgusted', 'disinherited', 'disinterested', 'disliked', 'dismissed', 'dismounted', 'disordered', 'dispatched', 'dispersed', 'dispirited', 'displayed', 'displeased', 'disposed', 'disregarded', 'dissatisfied', 'dissented', 'dissipated', 'distinguished', 'distressed', 'disturbed', 'diverted', 'divided', 'doomed', 'doted', 'dotted', 'doubted', 'dreaded', 'dressed', 'dried', 'dropped', 'earned', 'echoed', 'effected', 'elevated', 'eluded', 'embarrassed', 'embraced', 'employed', 'enabled', 'enamoured', 'encouraged', 'encumbered', 'endeavoured', 'ended', 'endowed', 'endured', 'enfeebled', 'enforced', 'engaged', 'engrossed', 'enjoyed', 'enlightened', 'enquired', 'enraged', 'ensued', 'ensured', 'entered', 'entertained', 'entitled', 'entreated', 'entrusted', 'equalled', ...
#
# Print 10 Bigrams :
#   [('[', 'Sense'), ('Sense', 'and'), ('and', 'Sensibility'), ('Sensibility', 'by'), ('by', 'Jane'), ('Jane', 'Austen'), ('Austen', '1811'), ('1811', ']'), (']', 'CHAPTER'), ('CHAPTER', '1')]
# Print 5 Trigrams :
#   [('Austen', '1811', ']'), ('Jane', 'Austen', '1811'), ('200', 'L', 'per'), ('Drury', 'Lane', 'lobby'), ('L', 'per', 'annum')]
# ================================
#
# Start for Text 3->
#  <Text: The Book of Genesis>
#
# Print Long Words :
#  []
#
# Print High Frequency Words :
#  ['I', 'The', 'a', 'all', 'an', 'and', 'are', 'as', 'at', 'be', 'but', 'by', 'for', 'from', 'had', 'have', 'he', 'him', 'his', 'in', 'into', 'is', 'it', 'like', 'man', 'me', 'more', 'my', 'not', 'now', 'of', 'on', 'one', 'or', 'out', 's', 'so', 'some', 'that', 'the', 'their', 'then', 'there', 'they', 'this', 'to', 'up', 'upon', 'was', 'were', 'when', 'which', 'with', 'you']
#
# Length of Words End with ed
#  281
# ['Bered', 'Blessed', 'Chesed', 'Cursed', 'Feed', 'Galeed', 'Jared', 'Matred', 'Sered', 'Shed', 'abated', 'accepted', 'acknowledged', 'answered', 'appeared', 'appointed', 'armed', 'arrayed', 'ashamed', 'asked', 'assigned', 'asswaged', 'attained', 'avenged', 'awaked', 'bed', 'beguiled', 'believed', 'bereaved', 'blasted', 'blessed', 'bowed', 'breathed', 'breed', 'budded', 'builded', 'buried', 'called', 'carried', 'caused', 'ceased', 'changed', 'charged', 'circumcised', 'closed', 'clothed', 'comforted', 'commanded', 'commended', 'committed', 'communed', 'compassed', 'conceived', 'conspired', 'consumed', 'continued', 'corrupted', 'couched', 'counted', 'covered', 'created', 'cried', 'cursed', 'deceived', 'decreased', 'deed', 'deferred', 'defiled', 'delivered', 'denied', 'departed', 'deprived', 'desired', 'despised', 'destroyed', 'devoured', 'died', 'digged', 'dipped', 'discerned', 'displeased', 'distressed', 'divided', 'doubled', 'dreamed', 'dressed', 'dried', 'dwelled', 'embalmed', 'embraced', 'emptied', 'ended', 'endued', 'entered', 'entreated', 'envied', 'erected', 'escaped', 'espied', 'established', 'eyed', 'failed', 'fainted', 'famished', 'fatfleshed', 'favoured', 'feared', 'fed', 'feed', 'fetched', 'filled', 'finished', 'fled', 'followed', 'formed', 'fulfilled', 'gathered', 'grieved', 'grisled', 'halted', 'hanged', 'hasted', 'hastened', 'hated', 'healed', 'hearkened', 'heed', 'hired', 'hundred', 'imagined', 'increased', 'indeed', 'inhabited', 'interpreted', 'intreated', 'joined', 'journeyed', 'judged', 'killed', 'kindled', 'kindred', 'kissed', 'laded', 'laughed', 'leanfleshed', 'leaped', 'learned', 'led', 'lifted', 'lighted', 'lingered', 'lived', 'lodged', 'looked', 'loved', 'magnified', 'married', 'marvelled', 'mocked', 'mourned', 'moved', 'multiplied', 'naked', 'named', 'nourished', 'numbered', 'obeyed', 'observed', 'offended', 'offered', 'opened', 'parted', 'passed', 'perceived', 'pilled', 'pitched', 'placed', 'plagued', 'planted', 'played', 'pleased', 'poured', 'prayed', 'prepared', 'presented', 'preserved', 'pressed', 'prevailed', 'prospered', 'proved', 'pulled', 'purchased', 'pursued', 'rained', 'reached', 'rebelled', 'rebuked', 'received', 'red', 'redeemed', 'refrained', 'refused', 'reigned', 'remained', 'remembered', 'removed', 'repented', 'reproved', 'required', 'reserved', 'rested', 'restored', 'restrained', 'returned', 'rewarded', 'ringstraked', 'rolled', 'ruled', 'saddled', 'sanctified', 'saved', 'scattered', 'searched', 'seed', 'seemed', 'separated', 'served', 'sewed', 'shamed', 'shaved', 'shed', 'shewed', 'smelled', 'sojourned', 'sowed', 'speckled', 'speed', 'spilled', 'spoiled', 'spotted', 'stayed', 'stooped', 'stopped', 'strengthened', 'stretched', 'struggled', 'suffered', 'supplanted', 'sustained', 'talked', 'tarried', 'touched', 'trained', 'travailed', 'trembled', 'troubled', 'turned', 'uncircumcised', 'uncovered', 'ungirded', 'unleavened', 'urged', 'verified', 'visited', 'vowed', 'waited', 'walked', 'wandered', 'washed', 'watered', 'waxed', 'weaned', 'wearied', 'weighed', 'wicked', 'winged', 'withered', 'worshipped', 'wrapped', 'wrestled', 'yielded']
#
# Print 10 Bigrams :
#   [('In', 'the'), ('the', 'beginning'), ('beginning', 'God'), ('God', 'created'), ('created', 'the'), ('the', 'heaven'), ('heaven', 'and'), ('and', 'the'), ('the', 'earth'), ('earth', '.')]
#
# Print 5 Trigrams :
#   [('olive', 'leaf', 'pluckt'), ('sewed', 'fig', 'leaves'), ('yield', 'royal', 'dainties'), ('Fifteen', 'cubits', 'upward'), ('leaf', 'pluckt', 'o')]
# ================================

# %%
text1.collocations()
# Out:
# Sperm Whale; Moby Dick; White Whale; old man; Captain Ahab; sperm
# whale; Right Whale; Captain Peleg; New Bedford; Cape Horn; cried Ahab;
# years ago; lower jaw; never mind; Father Mapple; cried Stubb; chief
# mate; white whale; ivory leg; one hand

# %%
text3.collocations()
# Out:
# said unto; pray thee; thou shalt; thou hast; thy seed; years old;
# spake unto; thou art; LORD God; every living; God hath; begat sons;
# seven years; shalt thou; little ones; living creature; creeping thing;
# savoury meat; thirty years; every beast

# %%
text2.collocations()
# Out:
# Colonel Brandon; Sir John; Lady Middleton; Miss Dashwood; every thing;
# thousand pounds; dare say; Miss Steeles; said Elinor; Miss Steele;
# every body; John Dashwood; great deal; Harley Street; Berkeley Street;
# Miss Dashwoods; young man; Combe Magna; every day; next morning

# %% [markdown]
# # Task 2: Accessing Corpora

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
gutenberg_sc = nltk.corpus.gutenberg.words('shakespeare-caesar.txt')

# %%
gutenberg_sc
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Julius', 'Caesar', ...]

# %%
from nltk.corpus import brown
brown.words()
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
daw_raw = nltk.data.load('dawood.txt', format ='raw')
daw_txt = nltk.data.load('dawood.txt', format ='text')

# %%
from nltk.util import ngrams
words = nltk.word_tokenize(daw_txt)
daw_bigrams = list(ngrams(words, 2))
daw_trigrams = list(ngrams(words, 3))

# %%
daw_bigrams
# Out:
# [('Natural', 'Language'),
#  ('Language', 'Processing'),
#  ('Processing', '('),
#  ('(', 'NLP'),
#  ('NLP', ')'),
#  (')', 'represents'),
#  ('represents', 'a'),
#  ('a', 'transformative'),
#  ('transformative', 'field'),
#  ('field', 'within'),
#  ('within', 'the'),
#  ('the', 'domain'),
#  ('domain', 'of'),
#  ('of', 'artificial'),
#  ('artificial', 'intelligence'),
#  ('intelligence', ','),
#  (',', 'dedicated'),
#  ('dedicated', 'to'),
#  ('to', 'unraveling'),
#  ('unraveling', 'the'),
#  ('the', 'complexities'),
#  ('complexities', 'of'),
#  ('of', 'human'),
#  ('human', 'language'),
#  ('language', 'and'),
#  ('and', 'enabling'),
#  ('enabling', 'machines'),
#  ('machines', 'to'),
#  ('to', 'comprehend'),
#  ('comprehend', ','),
#  (',', 'interpret'),
#  ('interpret', ','),
#  (',', 'and'),
#  ('and', 'generate'),
#  ('generate', 'human-like'),
#  ('human-like', 'text'),
#  ('text', '.'),
#  ('.', 'At'),
#  ('At', 'its'),
#  ('its', 'core'),
#  ('core', ','),
#  (',', 'NLP'),
#  ('NLP', 'seeks'),
#  ('seeks', 'to'),
#  ('to', 'bridge'),
#  ('bridge', 'the'),
#  ('the', 'communication'),
#  ('communication', 'gap'),
#  ('gap', 'between'),
#  ('between', 'humans'),
#  ('humans', 'and'),
#  ('and', 'computers'),
#  ('computers', ','),
#  (',', 'opening'),
#  ('opening', 'up'),
#  ('up', 'avenues'),
#  ('avenues', 'for'),
#  ('for', 'seamless'),
#  ('seamless', 'interaction'),
#  ('interaction', 'and'),
#  ('and', 'understanding'),
#  ('understanding', '.'),
#  ('.', 'This'),
#  ('This', 'interdisciplinary'),
#  ('interdisciplinary', 'field'),
#  ('field', 'draws'),
#  ('draws', 'upon'),
#  ('upon', 'linguistics'),
#  ('linguistics', ','),
#  (',', 'computer'),
#  ('computer', 'science'),
#  ('science', ','),
#  (',', 'and'),
#  ('and', 'machine'),
#  ('machine', 'learning'),
#  ('learning', ','),
#  (',', 'fusing'),
#  ('fusing', 'these'),
#  ('these', 'domains'),
#  ('domains', 'to'),
#  ('to', 'create'),
#  ('create', 'algorithms'),
#  ('algorithms', 'and'),
#  ('and', 'models'),
#  ('models', 'that'),
#  ('that', 'can'),
#  ('can', 'navigate'),
#  ('navigate', 'the'),
#  ('the', 'nuances'),
#  ('nuances', 'of'),
#  ('of', 'natural'),
#  ('natural', 'language.One'),
#  ('language.One', 'of'),
#  ('of', 'the'),
#  ('the', 'foundational'),
#  ('foundational', 'challenges'),
#  ('challenges', 'that'),
#  ('that', 'NLP'),
#  ('NLP', 'addresses'),
#  ('addresses', 'is'),
#  ('is', 'the'),
#  ('the', 'inherent'),
#  ('inherent', 'ambiguity'),
#  ('ambiguity', 'and'),
#  ('and', 'variability'),
#  ('variability', 'present'),
#  ('present', 'in'),
#  ('in', 'human'),
#  ('human', 'language'),
#  ('language', '.'),
#  ('.', 'Unlike'),
#  ('Unlike', 'structured'),
#  ('structured', 'data'),
#  ('data', ','),
#  (',', 'natural'),
#  ('natural', 'language'),
#  ('language', 'is'),
#  ('is', 'rich'),
#  ('rich', ','),
#  (',', 'context-dependent'),
#  ('context-dependent', ','),
#  (',', 'and'),
#  ('and', 'laden'),
#  ('laden', 'with'),
#  ('with', 'intricacies'),
#  ('intricacies', 'such'),
#  ('such', 'as'),
#  ('as', 'idioms'),
#  ('idioms', ','),
#  (',', 'metaphors'),
#  ('metaphors', ','),
#  (',', 'and'),
#  ('and', 'cultural'),
#  ('cultural', 'nuances'),
#  ('nuances', '.'),
#  ('.', 'NLP'),
#  ('NLP', 'algorithms'),
#  ('algorithms', 'grapple'),
#  ('grapple', 'with'),
#  ('with', 'these'),
#  ('these', 'challenges'),
#  ('challenges', ','),
#  (',', 'aiming'),
#  ('aiming', 'to'),
#  ('to', 'impart'),
#  ('impart', 'machines'),
#  ('machines', 'with'),
#  ('with', 'the'),
#  ('the', 'capability'),
#  ('capability', 'to'),
#  ('to', 'comprehend'),
#  ('comprehend', 'the'),
#  ('the', 'subtleties'),
#  ('subtleties', 'of'),
#  ('of', 'language'),
#  ('language', ','),
#  (',', 'discern'),
#  ('discern', 'sentiment'),
#  ('sentiment', ','),
#  (',', 'and'),
#  ('and', 'extract'),
#  ('extract', 'meaningful'),
#  ('meaningful', 'information'),
#  ('information', 'from'),
#  ('from', 'vast'),
#  ('vast', 'corpora'),
#  ('corpora', 'of'),
#  ('of', 'text.The'),
#  ('text.The', 'evolution'),
#  ('evolution', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'can'),
#  ('can', 'be'),
#  ('be', 'traced'),
#  ('traced', 'back'),
#  ('back', 'to'),
#  ('to', 'the'),
#  ('the', 'mid-20th'),
#  ('mid-20th', 'century'),
#  ('century', 'when'),
#  ('when', 'researchers'),
#  ('researchers', 'began'),
#  ('began', 'exploring'),
#  ('exploring', 'the'),
#  ('the', 'possibility'),
#  ('possibility', 'of'),
#  ('of', 'teaching'),
#  ('teaching', 'computers'),
#  ('computers', 'to'),
#  ('to', 'understand'),
#  ('understand', 'and'),
#  ('and', 'generate'),
#  ('generate', 'human'),
#  ('human', 'language'),
#  ('language', '.'),
#  ('.', 'Early'),
#  ('Early', 'endeavors'),
#  ('endeavors', 'were'),
#  ('were', 'marked'),
#  ('marked', 'by'),
#  ('by', 'rule-based'),
#  ('rule-based', 'systems'),
#  ('systems', ','),
#  (',', 'where'),
#  ('where', 'linguistic'),
#  ('linguistic', 'rules'),
#  ('rules', 'were'),
#  ('were', 'manually'),
#  ('manually', 'crafted'),
#  ('crafted', 'to'),
#  ('to', 'parse'),
#  ('parse', 'and'),
#  ('and', 'analyze'),
#  ('analyze', 'text'),
#  ('text', '.'),
#  ('.', 'However'),
#  ('However', ','),
#  (',', 'the'),
#  ('the', 'inherent'),
#  ('inherent', 'limitations'),
#  ('limitations', 'of'),
#  ('of', 'rule-based'),
#  ('rule-based', 'approaches'),
#  ('approaches', 'became'),
#  ('became', 'evident'),
#  ('evident', 'as'),
#  ('as', 'the'),
#  ('the', 'scale'),
#  ('scale', 'and'),
#  ('and', 'complexity'),
#  ('complexity', 'of'),
#  ('of', 'linguistic'),
#  ('linguistic', 'patterns'),
#  ('patterns', 'expanded.The'),
#  ('expanded.The', 'advent'),
#  ('advent', 'of'),
#  ('of', 'machine'),
#  ('machine', 'learning'),
#  ('learning', 'and'),
#  ('and', 'the'),
#  ('the', 'availability'),
#  ('availability', 'of'),
#  ('of', 'large-scale'),
#  ('large-scale', 'linguistic'),
#  ('linguistic', 'datasets'),
#  ('datasets', 'revolutionized'),
#  ('revolutionized', 'the'),
#  ('the', 'NLP'),
#  ('NLP', 'landscape'),
#  ('landscape', '.'),
#  ('.', 'Statistical'),
#  ('Statistical', 'models'),
#  ('models', ','),
#  (',', 'particularly'),
#  ('particularly', 'those'),
#  ('those', 'based'),
#  ('based', 'on'),
#  ('on', 'probabilistic'),
#  ('probabilistic', 'approaches'),
#  ('approaches', ','),
#  (',', 'gained'),
#  ('gained', 'prominence'),
#  ('prominence', '.'),
#  ('.', 'These'),
#  ('These', 'models'),
#  ('models', ','),
#  (',', 'often'),
#  ('often', 'utilizing'),
#  ('utilizing', 'techniques'),
#  ('techniques', 'like'),
#  ('like', 'Hidden'),
#  ('Hidden', 'Markov'),
#  ('Markov', 'Models'),
#  ('Models', 'and'),
#  ('and', 'n-gram'),
#  ('n-gram', 'analysis'),
#  ('analysis', ','),
#  (',', 'demonstrated'),
#  ('demonstrated', 'improved'),
#  ('improved', 'language'),
#  ('language', 'understanding'),
#  ('understanding', 'capabilities'),
#  ('capabilities', 'by'),
#  ('by', 'learning'),
#  ('learning', 'patterns'),
#  ('patterns', 'and'),
#  ('and', 'probabilities'),
#  ('probabilities', 'from'),
#  ('from', 'data'),
#  ('data', '.'),
#  ('.', 'Yet'),
#  ('Yet', ','),
#  (',', 'they'),
#  ('they', 'struggled'),
#  ('struggled', 'with'),
#  ('with', 'the'),
#  ('the', 'contextual'),
#  ('contextual', 'intricacies'),
#  ('intricacies', 'inherent'),
#  ('inherent', 'in'),
#  ('in', 'language.A'),
#  ('language.A', 'paradigm'),
#  ('paradigm', 'shift'),
#  ('shift', 'occurred'),
#  ('occurred', 'with'),
#  ('with', 'the'),
#  ('the', 'rise'),
#  ('rise', 'of'),
#  ('of', 'neural'),
#  ('neural', 'network-based'),
#  ('network-based', 'approaches'),
#  ('approaches', ','),
#  (',', 'propelled'),
#  ('propelled', 'by'),
#  ('by', 'the'),
#  ('the', 'deep'),
#  ('deep', 'learning'),
#  ('learning', 'revolution'),
#  ('revolution', '.'),
#  ('.', 'Recurrent'),
#  ('Recurrent', 'Neural'),
#  ('Neural', 'Networks'),
#  ('Networks', '('),
#  ('(', 'RNNs'),
#  ('RNNs', ')'),
#  (')', 'and'),
#  ('and', ','),
#  (',', 'more'),
#  ('more', 'prominently'),
#  ('prominently', ','),
#  (',', 'Transformer'),
#  ('Transformer', 'architectures'),
#  ('architectures', ','),
#  (',', 'exemplified'),
#  ('exemplified', 'by'),
#  ('by', 'models'),
#  ('models', 'like'),
#  ('like', 'BERT'),
#  ('BERT', '('),
#  ('(', 'Bidirectional'),
#  ('Bidirectional', 'Encoder'),
#  ('Encoder', 'Representations'),
#  ('Representations', 'from'),
#  ('from', 'Transformers'),
#  ('Transformers', ')'),
#  (')', ','),
#  (',', 'GPT'),
#  ('GPT', '('),
#  ('(', 'Generative'),
#  ('Generative', 'Pre-trained'),
#  ('Pre-trained', 'Transformer'),
#  ('Transformer', ')'),
#  (')', ','),
#  (',', 'and'),
#  ('and', 'their'),
#  ('their', 'successors'),
#  ('successors', ','),
#  (',', 'have'),
#  ('have', 'redefined'),
#  ('redefined', 'the'),
#  ('the', 'state-of-the-art'),
#  ('state-of-the-art', 'in'),
#  ('in', 'NLP'),
#  ('NLP', '.'),
#  ('.', 'These'),
#  ('These', 'models'),
#  ('models', ','),
#  (',', 'often'),
#  ('often', 'pre-trained'),
#  ('pre-trained', 'on'),
#  ('on', 'massive'),
#  ('massive', 'datasets'),
#  ('datasets', ','),
#  (',', 'exhibit'),
#  ('exhibit', 'an'),
#  ('an', 'unprecedented'),
#  ('unprecedented', 'capacity'),
#  ('capacity', 'to'),
#  ('to', 'capture'),
#  ('capture', 'contextual'),
#  ('contextual', 'nuances'),
#  ('nuances', ','),
#  (',', 'syntactic'),
#  ('syntactic', 'structures'),
#  ('structures', ','),
#  (',', 'and'),
#  ('and', 'even'),
#  ('even', 'semantic'),
#  ('semantic', 'relationships'),
#  ('relationships', 'within'),
#  ('within', 'language.NLP'),
#  ('language.NLP', 'applications'),
#  ('applications', 'have'),
#  ('have', 'permeated'),
#  ('permeated', 'various'),
#  ('various', 'facets'),
#  ('facets', 'of'),
#  ('of', 'our'),
#  ('our', 'daily'),
#  ('daily', 'lives'),
#  ('lives', ','),
#  (',', 'showcasing'),
#  ('showcasing', 'the'),
#  ('the', 'practical'),
#  ('practical', 'impact'),
#  ('impact', 'of'),
#  ('of', 'this'),
#  ('this', 'field'),
#  ('field', '.'),
#  ('.', 'Virtual'),
#  ('Virtual', 'assistants'),
#  ('assistants', ','),
#  (',', 'such'),
#  ('such', 'as'),
#  ('as', 'Siri'),
#  ('Siri', 'and'),
#  ('and', 'Alexa'),
#  ('Alexa', ','),
#  (',', 'leverage'),
#  ('leverage', 'NLP'),
#  ('NLP', 'to'),
#  ('to', 'comprehend'),
#  ('comprehend', 'and'),
#  ('and', 'respond'),
#  ('respond', 'to'),
#  ('to', 'spoken'),
#  ('spoken', 'commands'),
#  ('commands', ','),
#  (',', 'showcasing'),
#  ('showcasing', 'the'),
#  ('the', 'ability'),
#  ('ability', 'to'),
#  ('to', 'understand'),
#  ('understand', 'and'),
#  ('and', 'generate'),
#  ('generate', 'human-like'),
#  ('human-like', 'speech'),
#  ('speech', '.'),
#  ('.', 'Sentiment'),
#  ('Sentiment', 'analysis'),
#  ('analysis', 'tools'),
#  ('tools', 'employ'),
#  ('employ', 'NLP'),
#  ('NLP', 'to'),
#  ('to', 'gauge'),
#  ('gauge', 'the'),
#  ('the', 'mood'),
#  ('mood', 'and'),
#  ('and', 'opinions'),
#  ('opinions', 'expressed'),
#  ('expressed', 'in'),
#  ('in', 'online'),
#  ('online', 'reviews'),
#  ('reviews', ','),
#  (',', 'social'),
#  ('social', 'media'),
#  ('media', 'posts'),
#  ('posts', ','),
#  (',', 'and'),
#  ('and', 'news'),
#  ('news', 'articles'),
#  ('articles', ','),
#  (',', 'offering'),
#  ('offering', 'valuable'),
#  ('valuable', 'insights'),
#  ('insights', 'for'),
#  ('for', 'businesses'),
#  ('businesses', 'and'),
#  ('and', 'researchers.Machine'),
#  ('researchers.Machine', 'translation'),
#  ('translation', ','),
#  (',', 'another'),
#  ('another', 'cornerstone'),
#  ('cornerstone', 'application'),
#  ('application', 'of'),
#  ('of', 'NLP'),
#  ('NLP', ','),
#  (',', 'has'),
#  ('has', 'undergone'),
#  ('undergone', 'remarkable'),
#  ('remarkable', 'transformations'),
#  ('transformations', '.'),
#  ('.', 'Neural'),
#  ('Neural', 'machine'),
#  ('machine', 'translation'),
#  ('translation', 'models'),
#  ('models', ','),
#  (',', 'driven'),
#  ('driven', 'by'),
#  ('by', 'deep'),
#  ('deep', 'learning'),
#  ('learning', ','),
#  (',', 'have'),
#  ('have', 'significantly'),
#  ('significantly', 'improved'),
#  ('improved', 'the'),
#  ('the', 'accuracy'),
#  ('accuracy', 'and'),
#  ('and', 'fluency'),
#  ('fluency', 'of'),
#  ('of', 'translations'),
#  ('translations', ','),
#  (',', 'making'),
#  ('making', 'cross-language'),
#  ('cross-language', 'communication'),
#  ('communication', 'more'),
#  ('more', 'accessible'),
#  ('accessible', '.'),
#  ('.', 'Moreover'),
#  ('Moreover', ','),
#  (',', 'in'),
#  ('in', 'the'),
#  ('the', 'realm'),
#  ('realm', 'of'),
#  ('of', 'healthcare'),
#  ('healthcare', ','),
#  (',', 'NLP'),
#  ('NLP', 'contributes'),
#  ('contributes', 'to'),
#  ('to', 'clinical'),
#  ('clinical', 'decision'),
#  ('decision', 'support'),
#  ('support', 'systems'),
#  ('systems', ','),
#  (',', 'extracting'),
#  ('extracting', 'valuable'),
#  ('valuable', 'information'),
#  ('information', 'from'),
#  ('from', 'electronic'),
#  ('electronic', 'health'),
#  ('health', 'records'),
#  ('records', 'and'),
#  ('and', 'medical'),
#  ('medical', 'literature'),
#  ('literature', ','),
#  (',', 'aiding'),
#  ('aiding', 'healthcare'),
#  ('healthcare', 'professionals'),
#  ('professionals', 'in'),
#  ('in', 'making'),
#  ('making', 'informed'),
#  ('informed', 'decisions.Despite'),
#  ('decisions.Despite', 'these'),
#  ('these', 'advancements'),
#  ('advancements', ','),
#  (',', 'challenges'),
#  ('challenges', 'persist'),
#  ('persist', 'within'),
#  ('within', 'the'),
#  ('the', 'realm'),
#  ('realm', 'of'),
#  ('of', 'NLP'),
#  ('NLP', '.'),
#  ('.', 'The'),
#  ('The', 'understanding'),
#  ('understanding', 'of'),
#  ('of', 'context'),
#  ('context', ','),
#  (',', 'especially'),
#  ('especially', 'in'),
#  ('in', 'ambiguous'),
#  ('ambiguous', 'scenarios'),
#  ('scenarios', ','),
#  (',', 'remains'),
#  ('remains', 'an'),
#  ('an', 'ongoing'),
#  ('ongoing', 'area'),
#  ('area', 'of'),
#  ('of', 'research'),
#  ('research', '.'),
#  ('.', 'Issues'),
#  ('Issues', 'of'),
#  ('of', 'bias'),
#  ('bias', 'and'),
#  ('and', 'fairness'),
#  ('fairness', 'in'),
#  ('in', 'language'),
#  ('language', 'models'),
#  ('models', 'have'),
#  ('have', 'garnered'),
#  ('garnered', 'increased'),
#  ('increased', 'attention'),
#  ('attention', ','),
#  (',', 'necessitating'),
#  ('necessitating', 'ethical'),
#  ('ethical', 'considerations'),
#  ('considerations', 'in'),
#  ('in', 'the'),
#  ('the', 'development'),
#  ('development', 'and'),
#  ('and', 'deployment'),
#  ('deployment', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'systems'),
#  ('systems', '.'),
#  ('.', 'Additionally'),
#  ('Additionally', ','),
#  (',', 'the'),
#  ('the', 'multilingual'),
#  ('multilingual', 'nature'),
#  ('nature', 'of'),
#  ('of', 'communication'),
#  ('communication', 'poses'),
#  ('poses', 'a'),
#  ('a', 'challenge'),
#  ('challenge', ','),
#  (',', 'requiring'),
#  ('requiring', 'NLP'),
#  ('NLP', 'models'),
#  ('models', 'to'),
#  ('to', 'be'),
#  ('be', 'adept'),
#  ('adept', 'at'),
#  ('at', 'understanding'),
#  ('understanding', 'diverse'),
#  ('diverse', 'linguistic'),
#  ('linguistic', 'structures'),
#  ('structures', 'and'),
#  ('and', 'cultural'),
#  ('cultural', 'nuances.The'),
#  ('nuances.The', 'future'),
#  ('future', 'trajectory'),
#  ('trajectory', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'holds'),
#  ('holds', 'immense'),
#  ('immense', 'promise'),
#  ('promise', 'and'),
#  ('and', 'raises'),
#  ('raises', 'intriguing'),
#  ('intriguing', 'possibilities'),
#  ('possibilities', '.'),
#  ('.', 'Continued'),
#  ('Continued', 'advancements'),
#  ('advancements', 'in'),
#  ('in', 'transformer'),
#  ('transformer', 'architectures'),
#  ('architectures', ','),
#  (',', 'coupled'),
#  ('coupled', 'with'),
#  ('with', 'ongoing'),
#  ('ongoing', 'research'),
#  ('research', 'in'),
#  ('in', 'unsupervised'),
#  ('unsupervised', 'and'),
#  ('and', 'self-supervised'),
#  ('self-supervised', 'learning'),
#  ('learning', ','),
#  (',', 'are'),
#  ('are', 'expected'),
#  ('expected', 'to'),
#  ('to', 'further'),
#  ('further', 'enhance'),
#  ('enhance', 'the'),
#  ('the', 'capabilities'),
#  ('capabilities', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'models'),
#  ('models', '.'),
#  ('.', 'The'),
#  ('The', 'pursuit'),
#  ('pursuit', 'of'),
#  ('of', 'Explainable'),
#  ('Explainable', 'AI'),
#  ('AI', '('),
#  ('(', 'XAI'),
#  ('XAI', ')'),
#  (')', 'within'),
#  ('within', 'NLP'),
#  ('NLP', 'aims'),
#  ('aims', 'to'),
#  ('to', 'demystify'),
#  ('demystify', 'the'),
#  ('the', 'decision-making'),
#  ('decision-making', 'processes'),
#  ('processes', 'of'),
#  ('of', 'these'),
#  ('these', 'models'),
#  ('models', ','),
#  (',', 'fostering'),
#  ('fostering', 'transparency'),
#  ('transparency', 'and'),
#  ('and', 'trust.In'),
#  ('trust.In', 'conclusion'),
#  ('conclusion', ','),
#  (',', 'Natural'),
#  ('Natural', 'Language'),
#  ('Language', 'Processing'),
#  ('Processing', 'stands'),
#  ('stands', 'as'),
#  ('as', 'a'),
#  ('a', 'testament'),
#  ('testament', 'to'),
#  ('to', 'the'),
#  ('the', 'remarkable'),
#  ('remarkable', 'convergence'),
#  ('convergence', 'of'),
#  ('of', 'linguistics'),
#  ('linguistics', ','),
#  (',', 'computer'),
#  ('computer', 'science'),
#  ('science', ','),
#  (',', 'and'),
#  ('and', 'artificial'),
#  ('artificial', 'intelligence'),
#  ('intelligence', '.'),
#  ('.', 'From'),
#  ('From', 'rule-based'),
#  ('rule-based', 'systems'),
#  ('systems', 'to'),
#  ('to', 'state-of-the-art'),
#  ('state-of-the-art', 'transformer'),
#  ('transformer', 'models'),
#  ('models', ','),
#  (',', 'the'),
#  ('the', 'journey'),
#  ('journey', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'reflects'),
#  ('reflects', 'a'),
#  ('a', 'relentless'),
#  ('relentless', 'pursuit'),
#  ('pursuit', 'of'),
#  ('of', 'understanding'),
#  ('understanding', 'and'),
#  ('and', 'harnessing'),
#  ('harnessing', 'the'),
#  ('the', 'power'),
#  ('power', 'of'),
#  ('of', 'human'),
#  ('human', 'language'),
#  ('language', '.'),
#  ('.', 'As'),
#  ('As', 'NLP'),
#  ('NLP', 'continues'),
#  ('continues', 'to'),
#  ('to', 'shape'),
#  ('shape', 'our'),
#  ('our', 'digital'),
#  ('digital', 'interactions'),
#  ('interactions', ','),
#  (',', 'its'),
#  ('its', 'impact'),
#  ('impact', 'reverberates'),
#  ('reverberates', 'across'),
#  ('across', 'industries'),
#  ('industries', ','),
#  (',', 'shaping'),
#  ('shaping', 'the'),
#  ('the', 'way'),
#  ('way', 'we'),
#  ('we', 'communicate'),
#  ('communicate', ','),
#  (',', 'gather'),
#  ('gather', 'information'),
#  ('information', ','),
#  (',', 'and'),
#  ('and', 'engage'),
#  ('engage', 'with'),
#  ('with', 'technology'),
#  ('technology', '.'),
#  ('.', 'The'),
#  ('The', 'ongoing'),
#  ('ongoing', 'exploration'),
#  ('exploration', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'holds'),
#  ('holds', 'the'),
#  ('the', 'promise'),
#  ('promise', 'of'),
#  ('of', 'not'),
#  ('not', 'only'),
#  ('only', 'unraveling'),
#  ('unraveling', 'the'),
#  ('the', 'intricacies'),
#  ('intricacies', 'of'),
#  ('of', 'language'),
#  ('language', 'but'),
#  ('but', 'also'),
#  ('also', 'fostering'),
#  ('fostering', 'a'),
#  ('a', 'more'),
#  ('more', 'connected'),
#  ('connected', 'and'),
#  ('and', 'intelligible'),
#  ('intelligible', 'future'),
#  ('future', 'between'),
#  ('between', 'humans'),
#  ('humans', 'and'),
#  ('and', 'machines.Computer'),
#  ('machines.Computer', 'vision'),
#  ('vision', ','),
#  (',', 'an'),
#  ('an', 'interdisciplinary'),
#  ('interdisciplinary', 'field'),
#  ('field', 'situated'),
#  ('situated', 'at'),
#  ('at', 'the'),
#  ('the', 'intersection'),
#  ('intersection', 'of'),
#  ('of', 'computer'),
#  ('computer', 'science'),
#  ('science', ','),
#  (',', 'machine'),
#  ('machine', 'learning'),
#  ('learning', ','),
#  (',', 'and'),
#  ('and', 'image'),
#  ('image', 'processing'),
#  ('processing', ','),
#  (',', 'seeks'),
#  ('seeks', 'to'),
#  ('to', 'emulate'),
#  ('emulate', 'human'),
#  ('human', 'vision'),
#  ('vision', 'capabilities'),
#  ('capabilities', 'in'),
#  ('in', 'machines'),
#  ('machines', '.'),
#  ('.', 'At'),
#  ('At', 'its'),
#  ('its', 'essence'),
#  ('essence', ','),
#  (',', 'computer'),
#  ('computer', 'vision'),
#  ('vision', 'endeavors'),
#  ('endeavors', 'to'),
#  ('to', 'empower'),
#  ('empower', 'machines'),
#  ('machines', 'with'),
#  ('with', 'the'),
#  ('the', 'ability'),
#  ('ability', 'to'),
#  ('to', 'interpret'),
#  ('interpret', 'and'),
#  ('and', 'understand'),
#  ('understand', 'visual'),
#  ('visual', 'information'),
#  ('information', 'from'),
#  ('from', 'the'),
#  ('the', 'world'),
#  ('world', 'around'),
#  ('around', 'them'),
#  ('them', '.'),
#  ('.', 'Anchored'),
#  ('Anchored', 'by'),
#  ('by', 'a'),
#  ('a', 'myriad'),
#  ('myriad', 'of'),
#  ('of', 'algorithms'),
#  ('algorithms', ','),
#  (',', 'models'),
#  ('models', ','),
#  (',', 'and'),
#  ('and', 'technologies'),
#  ('technologies', ','),
#  (',', 'computer'),
#  ('computer', 'vision'),
#  ('vision', 'has'),
#  ('has', 'evolved'),
#  ('evolved', 'from'),
#  ('from', 'basic'),
#  ('basic', 'image'),
#  ('image', 'processing'),
#  ('processing', 'tasks'),
#  ('tasks', 'to'),
#  ('to', 'sophisticated'),
#  ('sophisticated', 'applications'),
#  ('applications', 'that'),
#  ('that', 'transcend'),
#  ('transcend', 'human'),
#  ('human', 'visual'),
#  ('visual', 'abilities.The'),
#  ('abilities.The', 'foundational'),
#  ('foundational', 'principle'),
#  ('principle', 'of'),
#  ('of', 'computer'),
#  ('computer', 'vision'),
#  ('vision', 'lies'),
#  ('lies', 'in'),
#  ('in', 'image'),
#  ('image', 'understanding'),
#  ('understanding', 'and'),
#  ('and', 'pattern'),
#  ('pattern', 'recognition'),
#  ('recognition', '.'),
#  ('.', 'Early'),
#  ('Early', 'developments'),
#  ('developments', 'centered'),
#  ('centered', 'on'),
#  ('on', 'tasks'),
#  ('tasks', 'such'),
#  ('such', 'as'),
#  ('as', 'image'),
#  ('image', 'segmentation'),
#  ('segmentation', 'and'),
#  ('and', 'object'),
#  ('object', 'detection'),
#  ('detection', ','),
#  (',', 'where'),
#  ('where', 'algorithms'),
#  ('algorithms', 'were'),
#  ('were', 'designed'),
#  ('designed', 'to'),
#  ('to', 'identify'),
#  ('identify', 'and'),
#  ('and', 'delineate'),
#  ('delineate', 'distinct'),
#  ('distinct', 'elements'),
#  ('elements', 'within'),
#  ('within', 'an'),
#  ('an', 'image'),
#  ('image', '.'),
#  ('.', 'As'),
#  ('As', 'the'),
#  ('the', 'field'),
#  ('field', 'progressed'),
#  ('progressed', ','),
#  (',', 'the'),
#  ('the', 'advent'),
#  ('advent', 'of'),
#  ('of', 'feature'),
#  ('feature', 'extraction'),
#  ('extraction', 'techniques'),
#  ('techniques', ','),
#  (',', 'including'),
#  ('including', 'edge'),
#  ('edge', 'detection'),
#  ('detection', 'and'),
#  ('and', 'corner'),
#  ('corner', 'detection'),
#  ('detection', ','),
#  (',', 'enhanced'),
#  ('enhanced', 'the'),
#  ('the', 'ability'),
#  ('ability', 'of'),
#  ('of', 'systems'),
#  ('systems', 'to'),
#  ('to', 'capture'),
#  ('capture', 'and'),
#  ('and', 'analyze'),
#  ('analyze', 'intricate'),
#  ('intricate', 'details'),
#  ('details', 'in'),
#  ('in', 'visual'),
#  ('visual', 'data.Advancements'),
#  ('data.Advancements', 'in'),
#  ('in', 'machine'),
#  ('machine', 'learning'),
#  ('learning', ','),
#  (',', 'particularly'),
#  ('particularly', 'the'),
#  ('the', 'rise'),
#  ('rise', 'of'),
#  ('of', 'deep'),
#  ('deep', 'learning'),
#  ('learning', 'architectures'),
#  ('architectures', ','),
#  (',', 'marked'),
#  ('marked', 'a'),
#  ('a', 'watershed'),
#  ('watershed', 'moment'),
#  ('moment', 'in'),
#  ('in', 'the'),
#  ('the', 'evolution'),
#  ('evolution', 'of'),
#  ('of', 'computer'),
#  ('computer', 'vision'),
#  ('vision', '.'),
#  ('.', 'Convolutional'),
#  ('Convolutional', 'Neural'),
#  ('Neural', 'Networks'),
#  ('Networks', '('),
#  ('(', 'CNNs'),
#  ('CNNs', ')'),
#  (')', 'emerged'),
#  ('emerged', 'as'),
#  ('as', 'a'),
#  ('a', 'cornerstone'),
#  ('cornerstone', 'technology'),
#  ('technology', ','),
#  (',', 'revolutionizing'),
#  ('revolutionizing', 'image'),
#  ('image', 'classification'),
#  ('classification', ','),
#  (',', 'object'),
#  ('object', 'detection'),
#  ('detection', ','),
#  (',', 'and'),
#  ('and', 'semantic'),
#  ('semantic', 'segmentation'),
#  ('segmentation', '.'),
#  ('.', 'Pioneering'),
#  ('Pioneering', 'models'),
#  ('models', 'like'),
#  ('like', 'AlexNet'),
#  ('AlexNet', ','),
#  (',', 'VGGNet'),
#  ('VGGNet', ','),
#  (',', 'and'),
#  ...]

# %%
daw_trigrams
# Out:
# [('Natural', 'Language', 'Processing'),
#  ('Language', 'Processing', '('),
#  ('Processing', '(', 'NLP'),
#  ('(', 'NLP', ')'),
#  ('NLP', ')', 'represents'),
#  (')', 'represents', 'a'),
#  ('represents', 'a', 'transformative'),
#  ('a', 'transformative', 'field'),
#  ('transformative', 'field', 'within'),
#  ('field', 'within', 'the'),
#  ('within', 'the', 'domain'),
#  ('the', 'domain', 'of'),
#  ('domain', 'of', 'artificial'),
#  ('of', 'artificial', 'intelligence'),
#  ('artificial', 'intelligence', ','),
#  ('intelligence', ',', 'dedicated'),
#  (',', 'dedicated', 'to'),
#  ('dedicated', 'to', 'unraveling'),
#  ('to', 'unraveling', 'the'),
#  ('unraveling', 'the', 'complexities'),
#  ('the', 'complexities', 'of'),
#  ('complexities', 'of', 'human'),
#  ('of', 'human', 'language'),
#  ('human', 'language', 'and'),
#  ('language', 'and', 'enabling'),
#  ('and', 'enabling', 'machines'),
#  ('enabling', 'machines', 'to'),
#  ('machines', 'to', 'comprehend'),
#  ('to', 'comprehend', ','),
#  ('comprehend', ',', 'interpret'),
#  (',', 'interpret', ','),
#  ('interpret', ',', 'and'),
#  (',', 'and', 'generate'),
#  ('and', 'generate', 'human-like'),
#  ('generate', 'human-like', 'text'),
#  ('human-like', 'text', '.'),
#  ('text', '.', 'At'),
#  ('.', 'At', 'its'),
#  ('At', 'its', 'core'),
#  ('its', 'core', ','),
#  ('core', ',', 'NLP'),
#  (',', 'NLP', 'seeks'),
#  ('NLP', 'seeks', 'to'),
#  ('seeks', 'to', 'bridge'),
#  ('to', 'bridge', 'the'),
#  ('bridge', 'the', 'communication'),
#  ('the', 'communication', 'gap'),
#  ('communication', 'gap', 'between'),
#  ('gap', 'between', 'humans'),
#  ('between', 'humans', 'and'),
#  ('humans', 'and', 'computers'),
#  ('and', 'computers', ','),
#  ('computers', ',', 'opening'),
#  (',', 'opening', 'up'),
#  ('opening', 'up', 'avenues'),
#  ('up', 'avenues', 'for'),
#  ('avenues', 'for', 'seamless'),
#  ('for', 'seamless', 'interaction'),
#  ('seamless', 'interaction', 'and'),
#  ('interaction', 'and', 'understanding'),
#  ('and', 'understanding', '.'),
#  ('understanding', '.', 'This'),
#  ('.', 'This', 'interdisciplinary'),
#  ('This', 'interdisciplinary', 'field'),
#  ('interdisciplinary', 'field', 'draws'),
#  ('field', 'draws', 'upon'),
#  ('draws', 'upon', 'linguistics'),
#  ('upon', 'linguistics', ','),
#  ('linguistics', ',', 'computer'),
#  (',', 'computer', 'science'),
#  ('computer', 'science', ','),
#  ('science', ',', 'and'),
#  (',', 'and', 'machine'),
#  ('and', 'machine', 'learning'),
#  ('machine', 'learning', ','),
#  ('learning', ',', 'fusing'),
#  (',', 'fusing', 'these'),
#  ('fusing', 'these', 'domains'),
#  ('these', 'domains', 'to'),
#  ('domains', 'to', 'create'),
#  ('to', 'create', 'algorithms'),
#  ('create', 'algorithms', 'and'),
#  ('algorithms', 'and', 'models'),
#  ('and', 'models', 'that'),
#  ('models', 'that', 'can'),
#  ('that', 'can', 'navigate'),
#  ('can', 'navigate', 'the'),
#  ('navigate', 'the', 'nuances'),
#  ('the', 'nuances', 'of'),
#  ('nuances', 'of', 'natural'),
#  ('of', 'natural', 'language.One'),
#  ('natural', 'language.One', 'of'),
#  ('language.One', 'of', 'the'),
#  ('of', 'the', 'foundational'),
#  ('the', 'foundational', 'challenges'),
#  ('foundational', 'challenges', 'that'),
#  ('challenges', 'that', 'NLP'),
#  ('that', 'NLP', 'addresses'),
#  ('NLP', 'addresses', 'is'),
#  ('addresses', 'is', 'the'),
#  ('is', 'the', 'inherent'),
#  ('the', 'inherent', 'ambiguity'),
#  ('inherent', 'ambiguity', 'and'),
#  ('ambiguity', 'and', 'variability'),
#  ('and', 'variability', 'present'),
#  ('variability', 'present', 'in'),
#  ('present', 'in', 'human'),
#  ('in', 'human', 'language'),
#  ('human', 'language', '.'),
#  ('language', '.', 'Unlike'),
#  ('.', 'Unlike', 'structured'),
#  ('Unlike', 'structured', 'data'),
#  ('structured', 'data', ','),
#  ('data', ',', 'natural'),
#  (',', 'natural', 'language'),
#  ('natural', 'language', 'is'),
#  ('language', 'is', 'rich'),
#  ('is', 'rich', ','),
#  ('rich', ',', 'context-dependent'),
#  (',', 'context-dependent', ','),
#  ('context-dependent', ',', 'and'),
#  (',', 'and', 'laden'),
#  ('and', 'laden', 'with'),
#  ('laden', 'with', 'intricacies'),
#  ('with', 'intricacies', 'such'),
#  ('intricacies', 'such', 'as'),
#  ('such', 'as', 'idioms'),
#  ('as', 'idioms', ','),
#  ('idioms', ',', 'metaphors'),
#  (',', 'metaphors', ','),
#  ('metaphors', ',', 'and'),
#  (',', 'and', 'cultural'),
#  ('and', 'cultural', 'nuances'),
#  ('cultural', 'nuances', '.'),
#  ('nuances', '.', 'NLP'),
#  ('.', 'NLP', 'algorithms'),
#  ('NLP', 'algorithms', 'grapple'),
#  ('algorithms', 'grapple', 'with'),
#  ('grapple', 'with', 'these'),
#  ('with', 'these', 'challenges'),
#  ('these', 'challenges', ','),
#  ('challenges', ',', 'aiming'),
#  (',', 'aiming', 'to'),
#  ('aiming', 'to', 'impart'),
#  ('to', 'impart', 'machines'),
#  ('impart', 'machines', 'with'),
#  ('machines', 'with', 'the'),
#  ('with', 'the', 'capability'),
#  ('the', 'capability', 'to'),
#  ('capability', 'to', 'comprehend'),
#  ('to', 'comprehend', 'the'),
#  ('comprehend', 'the', 'subtleties'),
#  ('the', 'subtleties', 'of'),
#  ('subtleties', 'of', 'language'),
#  ('of', 'language', ','),
#  ('language', ',', 'discern'),
#  (',', 'discern', 'sentiment'),
#  ('discern', 'sentiment', ','),
#  ('sentiment', ',', 'and'),
#  (',', 'and', 'extract'),
#  ('and', 'extract', 'meaningful'),
#  ('extract', 'meaningful', 'information'),
#  ('meaningful', 'information', 'from'),
#  ('information', 'from', 'vast'),
#  ('from', 'vast', 'corpora'),
#  ('vast', 'corpora', 'of'),
#  ('corpora', 'of', 'text.The'),
#  ('of', 'text.The', 'evolution'),
#  ('text.The', 'evolution', 'of'),
#  ('evolution', 'of', 'NLP'),
#  ('of', 'NLP', 'can'),
#  ('NLP', 'can', 'be'),
#  ('can', 'be', 'traced'),
#  ('be', 'traced', 'back'),
#  ('traced', 'back', 'to'),
#  ('back', 'to', 'the'),
#  ('to', 'the', 'mid-20th'),
#  ('the', 'mid-20th', 'century'),
#  ('mid-20th', 'century', 'when'),
#  ('century', 'when', 'researchers'),
#  ('when', 'researchers', 'began'),
#  ('researchers', 'began', 'exploring'),
#  ('began', 'exploring', 'the'),
#  ('exploring', 'the', 'possibility'),
#  ('the', 'possibility', 'of'),
#  ('possibility', 'of', 'teaching'),
#  ('of', 'teaching', 'computers'),
#  ('teaching', 'computers', 'to'),
#  ('computers', 'to', 'understand'),
#  ('to', 'understand', 'and'),
#  ('understand', 'and', 'generate'),
#  ('and', 'generate', 'human'),
#  ('generate', 'human', 'language'),
#  ('human', 'language', '.'),
#  ('language', '.', 'Early'),
#  ('.', 'Early', 'endeavors'),
#  ('Early', 'endeavors', 'were'),
#  ('endeavors', 'were', 'marked'),
#  ('were', 'marked', 'by'),
#  ('marked', 'by', 'rule-based'),
#  ('by', 'rule-based', 'systems'),
#  ('rule-based', 'systems', ','),
#  ('systems', ',', 'where'),
#  (',', 'where', 'linguistic'),
#  ('where', 'linguistic', 'rules'),
#  ('linguistic', 'rules', 'were'),
#  ('rules', 'were', 'manually'),
#  ('were', 'manually', 'crafted'),
#  ('manually', 'crafted', 'to'),
#  ('crafted', 'to', 'parse'),
#  ('to', 'parse', 'and'),
#  ('parse', 'and', 'analyze'),
#  ('and', 'analyze', 'text'),
#  ('analyze', 'text', '.'),
#  ('text', '.', 'However'),
#  ('.', 'However', ','),
#  ('However', ',', 'the'),
#  (',', 'the', 'inherent'),
#  ('the', 'inherent', 'limitations'),
#  ('inherent', 'limitations', 'of'),
#  ('limitations', 'of', 'rule-based'),
#  ('of', 'rule-based', 'approaches'),
#  ('rule-based', 'approaches', 'became'),
#  ('approaches', 'became', 'evident'),
#  ('became', 'evident', 'as'),
#  ('evident', 'as', 'the'),
#  ('as', 'the', 'scale'),
#  ('the', 'scale', 'and'),
#  ('scale', 'and', 'complexity'),
#  ('and', 'complexity', 'of'),
#  ('complexity', 'of', 'linguistic'),
#  ('of', 'linguistic', 'patterns'),
#  ('linguistic', 'patterns', 'expanded.The'),
#  ('patterns', 'expanded.The', 'advent'),
#  ('expanded.The', 'advent', 'of'),
#  ('advent', 'of', 'machine'),
#  ('of', 'machine', 'learning'),
#  ('machine', 'learning', 'and'),
#  ('learning', 'and', 'the'),
#  ('and', 'the', 'availability'),
#  ('the', 'availability', 'of'),
#  ('availability', 'of', 'large-scale'),
#  ('of', 'large-scale', 'linguistic'),
#  ('large-scale', 'linguistic', 'datasets'),
#  ('linguistic', 'datasets', 'revolutionized'),
#  ('datasets', 'revolutionized', 'the'),
#  ('revolutionized', 'the', 'NLP'),
#  ('the', 'NLP', 'landscape'),
#  ('NLP', 'landscape', '.'),
#  ('landscape', '.', 'Statistical'),
#  ('.', 'Statistical', 'models'),
#  ('Statistical', 'models', ','),
#  ('models', ',', 'particularly'),
#  (',', 'particularly', 'those'),
#  ('particularly', 'those', 'based'),
#  ('those', 'based', 'on'),
#  ('based', 'on', 'probabilistic'),
#  ('on', 'probabilistic', 'approaches'),
#  ('probabilistic', 'approaches', ','),
#  ('approaches', ',', 'gained'),
#  (',', 'gained', 'prominence'),
#  ('gained', 'prominence', '.'),
#  ('prominence', '.', 'These'),
#  ('.', 'These', 'models'),
#  ('These', 'models', ','),
#  ('models', ',', 'often'),
#  (',', 'often', 'utilizing'),
#  ('often', 'utilizing', 'techniques'),
#  ('utilizing', 'techniques', 'like'),
#  ('techniques', 'like', 'Hidden'),
#  ('like', 'Hidden', 'Markov'),
#  ('Hidden', 'Markov', 'Models'),
#  ('Markov', 'Models', 'and'),
#  ('Models', 'and', 'n-gram'),
#  ('and', 'n-gram', 'analysis'),
#  ('n-gram', 'analysis', ','),
#  ('analysis', ',', 'demonstrated'),
#  (',', 'demonstrated', 'improved'),
#  ('demonstrated', 'improved', 'language'),
#  ('improved', 'language', 'understanding'),
#  ('language', 'understanding', 'capabilities'),
#  ('understanding', 'capabilities', 'by'),
#  ('capabilities', 'by', 'learning'),
#  ('by', 'learning', 'patterns'),
#  ('learning', 'patterns', 'and'),
#  ('patterns', 'and', 'probabilities'),
#  ('and', 'probabilities', 'from'),
#  ('probabilities', 'from', 'data'),
#  ('from', 'data', '.'),
#  ('data', '.', 'Yet'),
#  ('.', 'Yet', ','),
#  ('Yet', ',', 'they'),
#  (',', 'they', 'struggled'),
#  ('they', 'struggled', 'with'),
#  ('struggled', 'with', 'the'),
#  ('with', 'the', 'contextual'),
#  ('the', 'contextual', 'intricacies'),
#  ('contextual', 'intricacies', 'inherent'),
#  ('intricacies', 'inherent', 'in'),
#  ('inherent', 'in', 'language.A'),
#  ('in', 'language.A', 'paradigm'),
#  ('language.A', 'paradigm', 'shift'),
#  ('paradigm', 'shift', 'occurred'),
#  ('shift', 'occurred', 'with'),
#  ('occurred', 'with', 'the'),
#  ('with', 'the', 'rise'),
#  ('the', 'rise', 'of'),
#  ('rise', 'of', 'neural'),
#  ('of', 'neural', 'network-based'),
#  ('neural', 'network-based', 'approaches'),
#  ('network-based', 'approaches', ','),
#  ('approaches', ',', 'propelled'),
#  (',', 'propelled', 'by'),
#  ('propelled', 'by', 'the'),
#  ('by', 'the', 'deep'),
#  ('the', 'deep', 'learning'),
#  ('deep', 'learning', 'revolution'),
#  ('learning', 'revolution', '.'),
#  ('revolution', '.', 'Recurrent'),
#  ('.', 'Recurrent', 'Neural'),
#  ('Recurrent', 'Neural', 'Networks'),
#  ('Neural', 'Networks', '('),
#  ('Networks', '(', 'RNNs'),
#  ('(', 'RNNs', ')'),
#  ('RNNs', ')', 'and'),
#  (')', 'and', ','),
#  ('and', ',', 'more'),
#  (',', 'more', 'prominently'),
#  ('more', 'prominently', ','),
#  ('prominently', ',', 'Transformer'),
#  (',', 'Transformer', 'architectures'),
#  ('Transformer', 'architectures', ','),
#  ('architectures', ',', 'exemplified'),
#  (',', 'exemplified', 'by'),
#  ('exemplified', 'by', 'models'),
#  ('by', 'models', 'like'),
#  ('models', 'like', 'BERT'),
#  ('like', 'BERT', '('),
#  ('BERT', '(', 'Bidirectional'),
#  ('(', 'Bidirectional', 'Encoder'),
#  ('Bidirectional', 'Encoder', 'Representations'),
#  ('Encoder', 'Representations', 'from'),
#  ('Representations', 'from', 'Transformers'),
#  ('from', 'Transformers', ')'),
#  ('Transformers', ')', ','),
#  (')', ',', 'GPT'),
#  (',', 'GPT', '('),
#  ('GPT', '(', 'Generative'),
#  ('(', 'Generative', 'Pre-trained'),
#  ('Generative', 'Pre-trained', 'Transformer'),
#  ('Pre-trained', 'Transformer', ')'),
#  ('Transformer', ')', ','),
#  (')', ',', 'and'),
#  (',', 'and', 'their'),
#  ('and', 'their', 'successors'),
#  ('their', 'successors', ','),
#  ('successors', ',', 'have'),
#  (',', 'have', 'redefined'),
#  ('have', 'redefined', 'the'),
#  ('redefined', 'the', 'state-of-the-art'),
#  ('the', 'state-of-the-art', 'in'),
#  ('state-of-the-art', 'in', 'NLP'),
#  ('in', 'NLP', '.'),
#  ('NLP', '.', 'These'),
#  ('.', 'These', 'models'),
#  ('These', 'models', ','),
#  ('models', ',', 'often'),
#  (',', 'often', 'pre-trained'),
#  ('often', 'pre-trained', 'on'),
#  ('pre-trained', 'on', 'massive'),
#  ('on', 'massive', 'datasets'),
#  ('massive', 'datasets', ','),
#  ('datasets', ',', 'exhibit'),
#  (',', 'exhibit', 'an'),
#  ('exhibit', 'an', 'unprecedented'),
#  ('an', 'unprecedented', 'capacity'),
#  ('unprecedented', 'capacity', 'to'),
#  ('capacity', 'to', 'capture'),
#  ('to', 'capture', 'contextual'),
#  ('capture', 'contextual', 'nuances'),
#  ('contextual', 'nuances', ','),
#  ('nuances', ',', 'syntactic'),
#  (',', 'syntactic', 'structures'),
#  ('syntactic', 'structures', ','),
#  ('structures', ',', 'and'),
#  (',', 'and', 'even'),
#  ('and', 'even', 'semantic'),
#  ('even', 'semantic', 'relationships'),
#  ('semantic', 'relationships', 'within'),
#  ('relationships', 'within', 'language.NLP'),
#  ('within', 'language.NLP', 'applications'),
#  ('language.NLP', 'applications', 'have'),
#  ('applications', 'have', 'permeated'),
#  ('have', 'permeated', 'various'),
#  ('permeated', 'various', 'facets'),
#  ('various', 'facets', 'of'),
#  ('facets', 'of', 'our'),
#  ('of', 'our', 'daily'),
#  ('our', 'daily', 'lives'),
#  ('daily', 'lives', ','),
#  ('lives', ',', 'showcasing'),
#  (',', 'showcasing', 'the'),
#  ('showcasing', 'the', 'practical'),
#  ('the', 'practical', 'impact'),
#  ('practical', 'impact', 'of'),
#  ('impact', 'of', 'this'),
#  ('of', 'this', 'field'),
#  ('this', 'field', '.'),
#  ('field', '.', 'Virtual'),
#  ('.', 'Virtual', 'assistants'),
#  ('Virtual', 'assistants', ','),
#  ('assistants', ',', 'such'),
#  (',', 'such', 'as'),
#  ('such', 'as', 'Siri'),
#  ('as', 'Siri', 'and'),
#  ('Siri', 'and', 'Alexa'),
#  ('and', 'Alexa', ','),
#  ('Alexa', ',', 'leverage'),
#  (',', 'leverage', 'NLP'),
#  ('leverage', 'NLP', 'to'),
#  ('NLP', 'to', 'comprehend'),
#  ('to', 'comprehend', 'and'),
#  ('comprehend', 'and', 'respond'),
#  ('and', 'respond', 'to'),
#  ('respond', 'to', 'spoken'),
#  ('to', 'spoken', 'commands'),
#  ('spoken', 'commands', ','),
#  ('commands', ',', 'showcasing'),
#  (',', 'showcasing', 'the'),
#  ('showcasing', 'the', 'ability'),
#  ('the', 'ability', 'to'),
#  ('ability', 'to', 'understand'),
#  ('to', 'understand', 'and'),
#  ('understand', 'and', 'generate'),
#  ('and', 'generate', 'human-like'),
#  ('generate', 'human-like', 'speech'),
#  ('human-like', 'speech', '.'),
#  ('speech', '.', 'Sentiment'),
#  ('.', 'Sentiment', 'analysis'),
#  ('Sentiment', 'analysis', 'tools'),
#  ('analysis', 'tools', 'employ'),
#  ('tools', 'employ', 'NLP'),
#  ('employ', 'NLP', 'to'),
#  ('NLP', 'to', 'gauge'),
#  ('to', 'gauge', 'the'),
#  ('gauge', 'the', 'mood'),
#  ('the', 'mood', 'and'),
#  ('mood', 'and', 'opinions'),
#  ('and', 'opinions', 'expressed'),
#  ('opinions', 'expressed', 'in'),
#  ('expressed', 'in', 'online'),
#  ('in', 'online', 'reviews'),
#  ('online', 'reviews', ','),
#  ('reviews', ',', 'social'),
#  (',', 'social', 'media'),
#  ('social', 'media', 'posts'),
#  ('media', 'posts', ','),
#  ('posts', ',', 'and'),
#  (',', 'and', 'news'),
#  ('and', 'news', 'articles'),
#  ('news', 'articles', ','),
#  ('articles', ',', 'offering'),
#  (',', 'offering', 'valuable'),
#  ('offering', 'valuable', 'insights'),
#  ('valuable', 'insights', 'for'),
#  ('insights', 'for', 'businesses'),
#  ('for', 'businesses', 'and'),
#  ('businesses', 'and', 'researchers.Machine'),
#  ('and', 'researchers.Machine', 'translation'),
#  ('researchers.Machine', 'translation', ','),
#  ('translation', ',', 'another'),
#  (',', 'another', 'cornerstone'),
#  ('another', 'cornerstone', 'application'),
#  ('cornerstone', 'application', 'of'),
#  ('application', 'of', 'NLP'),
#  ('of', 'NLP', ','),
#  ('NLP', ',', 'has'),
#  (',', 'has', 'undergone'),
#  ('has', 'undergone', 'remarkable'),
#  ('undergone', 'remarkable', 'transformations'),
#  ('remarkable', 'transformations', '.'),
#  ('transformations', '.', 'Neural'),
#  ('.', 'Neural', 'machine'),
#  ('Neural', 'machine', 'translation'),
#  ('machine', 'translation', 'models'),
#  ('translation', 'models', ','),
#  ('models', ',', 'driven'),
#  (',', 'driven', 'by'),
#  ('driven', 'by', 'deep'),
#  ('by', 'deep', 'learning'),
#  ('deep', 'learning', ','),
#  ('learning', ',', 'have'),
#  (',', 'have', 'significantly'),
#  ('have', 'significantly', 'improved'),
#  ('significantly', 'improved', 'the'),
#  ('improved', 'the', 'accuracy'),
#  ('the', 'accuracy', 'and'),
#  ('accuracy', 'and', 'fluency'),
#  ('and', 'fluency', 'of'),
#  ('fluency', 'of', 'translations'),
#  ('of', 'translations', ','),
#  ('translations', ',', 'making'),
#  (',', 'making', 'cross-language'),
#  ('making', 'cross-language', 'communication'),
#  ('cross-language', 'communication', 'more'),
#  ('communication', 'more', 'accessible'),
#  ('more', 'accessible', '.'),
#  ('accessible', '.', 'Moreover'),
#  ('.', 'Moreover', ','),
#  ('Moreover', ',', 'in'),
#  (',', 'in', 'the'),
#  ('in', 'the', 'realm'),
#  ('the', 'realm', 'of'),
#  ('realm', 'of', 'healthcare'),
#  ('of', 'healthcare', ','),
#  ('healthcare', ',', 'NLP'),
#  (',', 'NLP', 'contributes'),
#  ('NLP', 'contributes', 'to'),
#  ('contributes', 'to', 'clinical'),
#  ('to', 'clinical', 'decision'),
#  ('clinical', 'decision', 'support'),
#  ('decision', 'support', 'systems'),
#  ('support', 'systems', ','),
#  ('systems', ',', 'extracting'),
#  (',', 'extracting', 'valuable'),
#  ('extracting', 'valuable', 'information'),
#  ('valuable', 'information', 'from'),
#  ('information', 'from', 'electronic'),
#  ('from', 'electronic', 'health'),
#  ('electronic', 'health', 'records'),
#  ('health', 'records', 'and'),
#  ('records', 'and', 'medical'),
#  ('and', 'medical', 'literature'),
#  ('medical', 'literature', ','),
#  ('literature', ',', 'aiding'),
#  (',', 'aiding', 'healthcare'),
#  ('aiding', 'healthcare', 'professionals'),
#  ('healthcare', 'professionals', 'in'),
#  ('professionals', 'in', 'making'),
#  ('in', 'making', 'informed'),
#  ('making', 'informed', 'decisions.Despite'),
#  ('informed', 'decisions.Despite', 'these'),
#  ('decisions.Despite', 'these', 'advancements'),
#  ('these', 'advancements', ','),
#  ('advancements', ',', 'challenges'),
#  (',', 'challenges', 'persist'),
#  ('challenges', 'persist', 'within'),
#  ('persist', 'within', 'the'),
#  ('within', 'the', 'realm'),
#  ('the', 'realm', 'of'),
#  ('realm', 'of', 'NLP'),
#  ('of', 'NLP', '.'),
#  ('NLP', '.', 'The'),
#  ('.', 'The', 'understanding'),
#  ('The', 'understanding', 'of'),
#  ('understanding', 'of', 'context'),
#  ('of', 'context', ','),
#  ('context', ',', 'especially'),
#  (',', 'especially', 'in'),
#  ('especially', 'in', 'ambiguous'),
#  ('in', 'ambiguous', 'scenarios'),
#  ('ambiguous', 'scenarios', ','),
#  ('scenarios', ',', 'remains'),
#  (',', 'remains', 'an'),
#  ('remains', 'an', 'ongoing'),
#  ('an', 'ongoing', 'area'),
#  ('ongoing', 'area', 'of'),
#  ('area', 'of', 'research'),
#  ('of', 'research', '.'),
#  ('research', '.', 'Issues'),
#  ('.', 'Issues', 'of'),
#  ('Issues', 'of', 'bias'),
#  ('of', 'bias', 'and'),
#  ('bias', 'and', 'fairness'),
#  ('and', 'fairness', 'in'),
#  ('fairness', 'in', 'language'),
#  ('in', 'language', 'models'),
#  ('language', 'models', 'have'),
#  ('models', 'have', 'garnered'),
#  ('have', 'garnered', 'increased'),
#  ('garnered', 'increased', 'attention'),
#  ('increased', 'attention', ','),
#  ('attention', ',', 'necessitating'),
#  (',', 'necessitating', 'ethical'),
#  ('necessitating', 'ethical', 'considerations'),
#  ('ethical', 'considerations', 'in'),
#  ('considerations', 'in', 'the'),
#  ('in', 'the', 'development'),
#  ('the', 'development', 'and'),
#  ('development', 'and', 'deployment'),
#  ('and', 'deployment', 'of'),
#  ('deployment', 'of', 'NLP'),
#  ('of', 'NLP', 'systems'),
#  ('NLP', 'systems', '.'),
#  ('systems', '.', 'Additionally'),
#  ('.', 'Additionally', ','),
#  ('Additionally', ',', 'the'),
#  (',', 'the', 'multilingual'),
#  ('the', 'multilingual', 'nature'),
#  ('multilingual', 'nature', 'of'),
#  ('nature', 'of', 'communication'),
#  ('of', 'communication', 'poses'),
#  ('communication', 'poses', 'a'),
#  ('poses', 'a', 'challenge'),
#  ('a', 'challenge', ','),
#  ('challenge', ',', 'requiring'),
#  (',', 'requiring', 'NLP'),
#  ('requiring', 'NLP', 'models'),
#  ('NLP', 'models', 'to'),
#  ('models', 'to', 'be'),
#  ('to', 'be', 'adept'),
#  ('be', 'adept', 'at'),
#  ('adept', 'at', 'understanding'),
#  ('at', 'understanding', 'diverse'),
#  ('understanding', 'diverse', 'linguistic'),
#  ('diverse', 'linguistic', 'structures'),
#  ('linguistic', 'structures', 'and'),
#  ('structures', 'and', 'cultural'),
#  ('and', 'cultural', 'nuances.The'),
#  ('cultural', 'nuances.The', 'future'),
#  ('nuances.The', 'future', 'trajectory'),
#  ('future', 'trajectory', 'of'),
#  ('trajectory', 'of', 'NLP'),
#  ('of', 'NLP', 'holds'),
#  ('NLP', 'holds', 'immense'),
#  ('holds', 'immense', 'promise'),
#  ('immense', 'promise', 'and'),
#  ('promise', 'and', 'raises'),
#  ('and', 'raises', 'intriguing'),
#  ('raises', 'intriguing', 'possibilities'),
#  ('intriguing', 'possibilities', '.'),
#  ('possibilities', '.', 'Continued'),
#  ('.', 'Continued', 'advancements'),
#  ('Continued', 'advancements', 'in'),
#  ('advancements', 'in', 'transformer'),
#  ('in', 'transformer', 'architectures'),
#  ('transformer', 'architectures', ','),
#  ('architectures', ',', 'coupled'),
#  (',', 'coupled', 'with'),
#  ('coupled', 'with', 'ongoing'),
#  ('with', 'ongoing', 'research'),
#  ('ongoing', 'research', 'in'),
#  ('research', 'in', 'unsupervised'),
#  ('in', 'unsupervised', 'and'),
#  ('unsupervised', 'and', 'self-supervised'),
#  ('and', 'self-supervised', 'learning'),
#  ('self-supervised', 'learning', ','),
#  ('learning', ',', 'are'),
#  (',', 'are', 'expected'),
#  ('are', 'expected', 'to'),
#  ('expected', 'to', 'further'),
#  ('to', 'further', 'enhance'),
#  ('further', 'enhance', 'the'),
#  ('enhance', 'the', 'capabilities'),
#  ('the', 'capabilities', 'of'),
#  ('capabilities', 'of', 'NLP'),
#  ('of', 'NLP', 'models'),
#  ('NLP', 'models', '.'),
#  ('models', '.', 'The'),
#  ('.', 'The', 'pursuit'),
#  ('The', 'pursuit', 'of'),
#  ('pursuit', 'of', 'Explainable'),
#  ('of', 'Explainable', 'AI'),
#  ('Explainable', 'AI', '('),
#  ('AI', '(', 'XAI'),
#  ('(', 'XAI', ')'),
#  ('XAI', ')', 'within'),
#  (')', 'within', 'NLP'),
#  ('within', 'NLP', 'aims'),
#  ('NLP', 'aims', 'to'),
#  ('aims', 'to', 'demystify'),
#  ('to', 'demystify', 'the'),
#  ('demystify', 'the', 'decision-making'),
#  ('the', 'decision-making', 'processes'),
#  ('decision-making', 'processes', 'of'),
#  ('processes', 'of', 'these'),
#  ('of', 'these', 'models'),
#  ('these', 'models', ','),
#  ('models', ',', 'fostering'),
#  (',', 'fostering', 'transparency'),
#  ('fostering', 'transparency', 'and'),
#  ('transparency', 'and', 'trust.In'),
#  ('and', 'trust.In', 'conclusion'),
#  ('trust.In', 'conclusion', ','),
#  ('conclusion', ',', 'Natural'),
#  (',', 'Natural', 'Language'),
#  ('Natural', 'Language', 'Processing'),
#  ('Language', 'Processing', 'stands'),
#  ('Processing', 'stands', 'as'),
#  ('stands', 'as', 'a'),
#  ('as', 'a', 'testament'),
#  ('a', 'testament', 'to'),
#  ('testament', 'to', 'the'),
#  ('to', 'the', 'remarkable'),
#  ('the', 'remarkable', 'convergence'),
#  ('remarkable', 'convergence', 'of'),
#  ('convergence', 'of', 'linguistics'),
#  ('of', 'linguistics', ','),
#  ('linguistics', ',', 'computer'),
#  (',', 'computer', 'science'),
#  ('computer', 'science', ','),
#  ('science', ',', 'and'),
#  (',', 'and', 'artificial'),
#  ('and', 'artificial', 'intelligence'),
#  ('artificial', 'intelligence', '.'),
#  ('intelligence', '.', 'From'),
#  ('.', 'From', 'rule-based'),
#  ('From', 'rule-based', 'systems'),
#  ('rule-based', 'systems', 'to'),
#  ('systems', 'to', 'state-of-the-art'),
#  ('to', 'state-of-the-art', 'transformer'),
#  ('state-of-the-art', 'transformer', 'models'),
#  ('transformer', 'models', ','),
#  ('models', ',', 'the'),
#  (',', 'the', 'journey'),
#  ('the', 'journey', 'of'),
#  ('journey', 'of', 'NLP'),
#  ('of', 'NLP', 'reflects'),
#  ('NLP', 'reflects', 'a'),
#  ('reflects', 'a', 'relentless'),
#  ('a', 'relentless', 'pursuit'),
#  ('relentless', 'pursuit', 'of'),
#  ('pursuit', 'of', 'understanding'),
#  ('of', 'understanding', 'and'),
#  ('understanding', 'and', 'harnessing'),
#  ('and', 'harnessing', 'the'),
#  ('harnessing', 'the', 'power'),
#  ('the', 'power', 'of'),
#  ('power', 'of', 'human'),
#  ('of', 'human', 'language'),
#  ('human', 'language', '.'),
#  ('language', '.', 'As'),
#  ('.', 'As', 'NLP'),
#  ('As', 'NLP', 'continues'),
#  ('NLP', 'continues', 'to'),
#  ('continues', 'to', 'shape'),
#  ('to', 'shape', 'our'),
#  ('shape', 'our', 'digital'),
#  ('our', 'digital', 'interactions'),
#  ('digital', 'interactions', ','),
#  ('interactions', ',', 'its'),
#  (',', 'its', 'impact'),
#  ('its', 'impact', 'reverberates'),
#  ('impact', 'reverberates', 'across'),
#  ('reverberates', 'across', 'industries'),
#  ('across', 'industries', ','),
#  ('industries', ',', 'shaping'),
#  (',', 'shaping', 'the'),
#  ('shaping', 'the', 'way'),
#  ('the', 'way', 'we'),
#  ('way', 'we', 'communicate'),
#  ('we', 'communicate', ','),
#  ('communicate', ',', 'gather'),
#  (',', 'gather', 'information'),
#  ('gather', 'information', ','),
#  ('information', ',', 'and'),
#  (',', 'and', 'engage'),
#  ('and', 'engage', 'with'),
#  ('engage', 'with', 'technology'),
#  ('with', 'technology', '.'),
#  ('technology', '.', 'The'),
#  ('.', 'The', 'ongoing'),
#  ('The', 'ongoing', 'exploration'),
#  ('ongoing', 'exploration', 'of'),
#  ('exploration', 'of', 'NLP'),
#  ('of', 'NLP', 'holds'),
#  ('NLP', 'holds', 'the'),
#  ('holds', 'the', 'promise'),
#  ('the', 'promise', 'of'),
#  ('promise', 'of', 'not'),
#  ('of', 'not', 'only'),
#  ('not', 'only', 'unraveling'),
#  ('only', 'unraveling', 'the'),
#  ('unraveling', 'the', 'intricacies'),
#  ('the', 'intricacies', 'of'),
#  ('intricacies', 'of', 'language'),
#  ('of', 'language', 'but'),
#  ('language', 'but', 'also'),
#  ('but', 'also', 'fostering'),
#  ('also', 'fostering', 'a'),
#  ('fostering', 'a', 'more'),
#  ('a', 'more', 'connected'),
#  ('more', 'connected', 'and'),
#  ('connected', 'and', 'intelligible'),
#  ('and', 'intelligible', 'future'),
#  ('intelligible', 'future', 'between'),
#  ('future', 'between', 'humans'),
#  ('between', 'humans', 'and'),
#  ('humans', 'and', 'machines.Computer'),
#  ('and', 'machines.Computer', 'vision'),
#  ('machines.Computer', 'vision', ','),
#  ('vision', ',', 'an'),
#  (',', 'an', 'interdisciplinary'),
#  ('an', 'interdisciplinary', 'field'),
#  ('interdisciplinary', 'field', 'situated'),
#  ('field', 'situated', 'at'),
#  ('situated', 'at', 'the'),
#  ('at', 'the', 'intersection'),
#  ('the', 'intersection', 'of'),
#  ('intersection', 'of', 'computer'),
#  ('of', 'computer', 'science'),
#  ('computer', 'science', ','),
#  ('science', ',', 'machine'),
#  (',', 'machine', 'learning'),
#  ('machine', 'learning', ','),
#  ('learning', ',', 'and'),
#  (',', 'and', 'image'),
#  ('and', 'image', 'processing'),
#  ('image', 'processing', ','),
#  ('processing', ',', 'seeks'),
#  (',', 'seeks', 'to'),
#  ('seeks', 'to', 'emulate'),
#  ('to', 'emulate', 'human'),
#  ('emulate', 'human', 'vision'),
#  ('human', 'vision', 'capabilities'),
#  ('vision', 'capabilities', 'in'),
#  ('capabilities', 'in', 'machines'),
#  ('in', 'machines', '.'),
#  ('machines', '.', 'At'),
#  ('.', 'At', 'its'),
#  ('At', 'its', 'essence'),
#  ('its', 'essence', ','),
#  ('essence', ',', 'computer'),
#  (',', 'computer', 'vision'),
#  ('computer', 'vision', 'endeavors'),
#  ('vision', 'endeavors', 'to'),
#  ('endeavors', 'to', 'empower'),
#  ('to', 'empower', 'machines'),
#  ('empower', 'machines', 'with'),
#  ('machines', 'with', 'the'),
#  ('with', 'the', 'ability'),
#  ('the', 'ability', 'to'),
#  ('ability', 'to', 'interpret'),
#  ('to', 'interpret', 'and'),
#  ('interpret', 'and', 'understand'),
#  ('and', 'understand', 'visual'),
#  ('understand', 'visual', 'information'),
#  ('visual', 'information', 'from'),
#  ('information', 'from', 'the'),
#  ('from', 'the', 'world'),
#  ('the', 'world', 'around'),
#  ('world', 'around', 'them'),
#  ('around', 'them', '.'),
#  ('them', '.', 'Anchored'),
#  ('.', 'Anchored', 'by'),
#  ('Anchored', 'by', 'a'),
#  ('by', 'a', 'myriad'),
#  ('a', 'myriad', 'of'),
#  ('myriad', 'of', 'algorithms'),
#  ('of', 'algorithms', ','),
#  ('algorithms', ',', 'models'),
#  (',', 'models', ','),
#  ('models', ',', 'and'),
#  (',', 'and', 'technologies'),
#  ('and', 'technologies', ','),
#  ('technologies', ',', 'computer'),
#  (',', 'computer', 'vision'),
#  ('computer', 'vision', 'has'),
#  ('vision', 'has', 'evolved'),
#  ('has', 'evolved', 'from'),
#  ('evolved', 'from', 'basic'),
#  ('from', 'basic', 'image'),
#  ('basic', 'image', 'processing'),
#  ('image', 'processing', 'tasks'),
#  ('processing', 'tasks', 'to'),
#  ('tasks', 'to', 'sophisticated'),
#  ('to', 'sophisticated', 'applications'),
#  ('sophisticated', 'applications', 'that'),
#  ('applications', 'that', 'transcend'),
#  ('that', 'transcend', 'human'),
#  ('transcend', 'human', 'visual'),
#  ('human', 'visual', 'abilities.The'),
#  ('visual', 'abilities.The', 'foundational'),
#  ('abilities.The', 'foundational', 'principle'),
#  ('foundational', 'principle', 'of'),
#  ('principle', 'of', 'computer'),
#  ('of', 'computer', 'vision'),
#  ('computer', 'vision', 'lies'),
#  ('vision', 'lies', 'in'),
#  ('lies', 'in', 'image'),
#  ('in', 'image', 'understanding'),
#  ('image', 'understanding', 'and'),
#  ('understanding', 'and', 'pattern'),
#  ('and', 'pattern', 'recognition'),
#  ('pattern', 'recognition', '.'),
#  ('recognition', '.', 'Early'),
#  ('.', 'Early', 'developments'),
#  ('Early', 'developments', 'centered'),
#  ('developments', 'centered', 'on'),
#  ('centered', 'on', 'tasks'),
#  ('on', 'tasks', 'such'),
#  ('tasks', 'such', 'as'),
#  ('such', 'as', 'image'),
#  ('as', 'image', 'segmentation'),
#  ('image', 'segmentation', 'and'),
#  ('segmentation', 'and', 'object'),
#  ('and', 'object', 'detection'),
#  ('object', 'detection', ','),
#  ('detection', ',', 'where'),
#  (',', 'where', 'algorithms'),
#  ('where', 'algorithms', 'were'),
#  ('algorithms', 'were', 'designed'),
#  ('were', 'designed', 'to'),
#  ('designed', 'to', 'identify'),
#  ('to', 'identify', 'and'),
#  ('identify', 'and', 'delineate'),
#  ('and', 'delineate', 'distinct'),
#  ('delineate', 'distinct', 'elements'),
#  ('distinct', 'elements', 'within'),
#  ('elements', 'within', 'an'),
#  ('within', 'an', 'image'),
#  ('an', 'image', '.'),
#  ('image', '.', 'As'),
#  ('.', 'As', 'the'),
#  ('As', 'the', 'field'),
#  ('the', 'field', 'progressed'),
#  ('field', 'progressed', ','),
#  ('progressed', ',', 'the'),
#  (',', 'the', 'advent'),
#  ('the', 'advent', 'of'),
#  ('advent', 'of', 'feature'),
#  ('of', 'feature', 'extraction'),
#  ('feature', 'extraction', 'techniques'),
#  ('extraction', 'techniques', ','),
#  ('techniques', ',', 'including'),
#  (',', 'including', 'edge'),
#  ('including', 'edge', 'detection'),
#  ('edge', 'detection', 'and'),
#  ('detection', 'and', 'corner'),
#  ('and', 'corner', 'detection'),
#  ('corner', 'detection', ','),
#  ('detection', ',', 'enhanced'),
#  (',', 'enhanced', 'the'),
#  ('enhanced', 'the', 'ability'),
#  ('the', 'ability', 'of'),
#  ('ability', 'of', 'systems'),
#  ('of', 'systems', 'to'),
#  ('systems', 'to', 'capture'),
#  ('to', 'capture', 'and'),
#  ('capture', 'and', 'analyze'),
#  ('and', 'analyze', 'intricate'),
#  ('analyze', 'intricate', 'details'),
#  ('intricate', 'details', 'in'),
#  ('details', 'in', 'visual'),
#  ('in', 'visual', 'data.Advancements'),
#  ('visual', 'data.Advancements', 'in'),
#  ('data.Advancements', 'in', 'machine'),
#  ('in', 'machine', 'learning'),
#  ('machine', 'learning', ','),
#  ('learning', ',', 'particularly'),
#  (',', 'particularly', 'the'),
#  ('particularly', 'the', 'rise'),
#  ('the', 'rise', 'of'),
#  ('rise', 'of', 'deep'),
#  ('of', 'deep', 'learning'),
#  ('deep', 'learning', 'architectures'),
#  ('learning', 'architectures', ','),
#  ('architectures', ',', 'marked'),
#  (',', 'marked', 'a'),
#  ('marked', 'a', 'watershed'),
#  ('a', 'watershed', 'moment'),
#  ('watershed', 'moment', 'in'),
#  ('moment', 'in', 'the'),
#  ('in', 'the', 'evolution'),
#  ('the', 'evolution', 'of'),
#  ('evolution', 'of', 'computer'),
#  ('of', 'computer', 'vision'),
#  ('computer', 'vision', '.'),
#  ('vision', '.', 'Convolutional'),
#  ('.', 'Convolutional', 'Neural'),
#  ('Convolutional', 'Neural', 'Networks'),
#  ('Neural', 'Networks', '('),
#  ('Networks', '(', 'CNNs'),
#  ('(', 'CNNs', ')'),
#  ('CNNs', ')', 'emerged'),
#  (')', 'emerged', 'as'),
#  ('emerged', 'as', 'a'),
#  ('as', 'a', 'cornerstone'),
#  ('a', 'cornerstone', 'technology'),
#  ('cornerstone', 'technology', ','),
#  ('technology', ',', 'revolutionizing'),
#  (',', 'revolutionizing', 'image'),
#  ('revolutionizing', 'image', 'classification'),
#  ('image', 'classification', ','),
#  ('classification', ',', 'object'),
#  (',', 'object', 'detection'),
#  ('object', 'detection', ','),
#  ('detection', ',', 'and'),
#  (',', 'and', 'semantic'),
#  ('and', 'semantic', 'segmentation'),
#  ('semantic', 'segmentation', '.'),
#  ('segmentation', '.', 'Pioneering'),
#  ('.', 'Pioneering', 'models'),
#  ('Pioneering', 'models', 'like'),
#  ('models', 'like', 'AlexNet'),
#  ('like', 'AlexNet', ','),
#  ('AlexNet', ',', 'VGGNet'),
#  (',', 'VGGNet', ','),
#  ('VGGNet', ',', 'and'),
#  (',', 'and', 'ResNet'),
#  ...]

# %%
from nltk.util import ngrams

# %%
import os
from nltk.corpus import PlaintextCorpusReader
corpus_root = os.path.expanduser('/home/chattha/nltk_data/corpora/dawood/')
daw_corpus = PlaintextCorpusReader(corpus_root, '.*', encoding = 'utf-8')
wordlist = daw_corpus.words()
bigramlist = list(ngrams(wordlist,2))
daw_corpus_raw = daw_corpus.raw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 daw_corpus = PlaintextCorpusReader(corpus_root, '.*', encoding = 'utf-8')
#       5 wordlist = daw_corpus.words()
# ----> 6 bigramlist = list(ngrams(wordlist,2))
#       7 daw_corpus_raw = daw_corpus.raw()
#
# NameError: name 'ngrams' is not defined

# %%
daw_corpus_raw
# Out:
# 'Natural Language Processing (NLP) represents a transformative field within the domain of artificial intelligence, dedicated to unraveling the complexities of human language and enabling machines to comprehend, interpret, and generate human-like text. At its core, NLP seeks to bridge the communication gap between humans and computers, opening up avenues for seamless interaction and understanding. This interdisciplinary field draws upon linguistics, computer science, and machine learning, fusing these domains to create algorithms and models that can navigate the nuances of natural language.One of the foundational challenges that NLP addresses is the inherent ambiguity and variability present in human language. Unlike structured data, natural language is rich, context-dependent, and laden with intricacies such as idioms, metaphors, and cultural nuances. NLP algorithms grapple with these challenges, aiming to impart machines with the capability to comprehend the subtleties of language, discern sentiment, and extract meaningful information from vast corpora of text.The evolution of NLP can be traced back to the mid-20th century when researchers began exploring the possibility of teaching computers to understand and generate human language. Early endeavors were marked by rule-based systems, where linguistic rules were manually crafted to parse and analyze text. However, the inherent limitations of rule-based approaches became evident as the scale and complexity of linguistic patterns expanded.The advent of machine learning and the availability of large-scale linguistic datasets revolutionized the NLP landscape. Statistical models, particularly those based on probabilistic approaches, gained prominence. These models, often utilizing techniques like Hidden Markov Models and n-gram analysis, demonstrated improved language understanding capabilities by learning patterns and probabilities from data. Yet, they struggled with the contextual intricacies inherent in language.A paradigm shift occurred with the rise of neural network-based approaches, propelled by the deep learning revolution. Recurrent Neural Networks (RNNs) and, more prominently, Transformer architectures, exemplified by models like BERT (Bidirectional Encoder Representations from Transformers), GPT (Generative Pre-trained Transformer), and their successors, have redefined the state-of-the-art in NLP. These models, often pre-trained on massive datasets, exhibit an unprecedented capacity to capture contextual nuances, syntactic structures, and even semantic relationships within language.NLP applications have permeated various facets of our daily lives, showcasing the practical impact of this field. Virtual assistants, such as Siri and Alexa, leverage NLP to comprehend and respond to spoken commands, showcasing the ability to understand and generate human-like speech. Sentiment analysis tools employ NLP to gauge the mood and opinions expressed in online reviews, social media posts, and news articles, offering valuable insights for businesses and researchers.Machine translation, another cornerstone application of NLP, has undergone remarkable transformations. Neural machine translation models, driven by deep learning, have significantly improved the accuracy and fluency of translations, making cross-language communication more accessible. Moreover, in the realm of healthcare, NLP contributes to clinical decision support systems, extracting valuable information from electronic health records and medical literature, aiding healthcare professionals in making informed decisions.Despite these advancements, challenges persist within the realm of NLP. The understanding of context, especially in ambiguous scenarios, remains an ongoing area of research. Issues of bias and fairness in language models have garnered increased attention, necessitating ethical considerations in the development and deployment of NLP systems. Additionally, the multilingual nature of communication poses a chal ...

# %%
from nltk.util import ngrams
words = nltk.word_tokenize(daw_corpus_raw)
daw_bigrams = list(ngrams(words, 2))
daw_trigrams = list(ngrams(words, 3))

# %%
daw_bigrams
# Out:
# [('Natural', 'Language'),
#  ('Language', 'Processing'),
#  ('Processing', '('),
#  ('(', 'NLP'),
#  ('NLP', ')'),
#  (')', 'represents'),
#  ('represents', 'a'),
#  ('a', 'transformative'),
#  ('transformative', 'field'),
#  ('field', 'within'),
#  ('within', 'the'),
#  ('the', 'domain'),
#  ('domain', 'of'),
#  ('of', 'artificial'),
#  ('artificial', 'intelligence'),
#  ('intelligence', ','),
#  (',', 'dedicated'),
#  ('dedicated', 'to'),
#  ('to', 'unraveling'),
#  ('unraveling', 'the'),
#  ('the', 'complexities'),
#  ('complexities', 'of'),
#  ('of', 'human'),
#  ('human', 'language'),
#  ('language', 'and'),
#  ('and', 'enabling'),
#  ('enabling', 'machines'),
#  ('machines', 'to'),
#  ('to', 'comprehend'),
#  ('comprehend', ','),
#  (',', 'interpret'),
#  ('interpret', ','),
#  (',', 'and'),
#  ('and', 'generate'),
#  ('generate', 'human-like'),
#  ('human-like', 'text'),
#  ('text', '.'),
#  ('.', 'At'),
#  ('At', 'its'),
#  ('its', 'core'),
#  ('core', ','),
#  (',', 'NLP'),
#  ('NLP', 'seeks'),
#  ('seeks', 'to'),
#  ('to', 'bridge'),
#  ('bridge', 'the'),
#  ('the', 'communication'),
#  ('communication', 'gap'),
#  ('gap', 'between'),
#  ('between', 'humans'),
#  ('humans', 'and'),
#  ('and', 'computers'),
#  ('computers', ','),
#  (',', 'opening'),
#  ('opening', 'up'),
#  ('up', 'avenues'),
#  ('avenues', 'for'),
#  ('for', 'seamless'),
#  ('seamless', 'interaction'),
#  ('interaction', 'and'),
#  ('and', 'understanding'),
#  ('understanding', '.'),
#  ('.', 'This'),
#  ('This', 'interdisciplinary'),
#  ('interdisciplinary', 'field'),
#  ('field', 'draws'),
#  ('draws', 'upon'),
#  ('upon', 'linguistics'),
#  ('linguistics', ','),
#  (',', 'computer'),
#  ('computer', 'science'),
#  ('science', ','),
#  (',', 'and'),
#  ('and', 'machine'),
#  ('machine', 'learning'),
#  ('learning', ','),
#  (',', 'fusing'),
#  ('fusing', 'these'),
#  ('these', 'domains'),
#  ('domains', 'to'),
#  ('to', 'create'),
#  ('create', 'algorithms'),
#  ('algorithms', 'and'),
#  ('and', 'models'),
#  ('models', 'that'),
#  ('that', 'can'),
#  ('can', 'navigate'),
#  ('navigate', 'the'),
#  ('the', 'nuances'),
#  ('nuances', 'of'),
#  ('of', 'natural'),
#  ('natural', 'language.One'),
#  ('language.One', 'of'),
#  ('of', 'the'),
#  ('the', 'foundational'),
#  ('foundational', 'challenges'),
#  ('challenges', 'that'),
#  ('that', 'NLP'),
#  ('NLP', 'addresses'),
#  ('addresses', 'is'),
#  ('is', 'the'),
#  ('the', 'inherent'),
#  ('inherent', 'ambiguity'),
#  ('ambiguity', 'and'),
#  ('and', 'variability'),
#  ('variability', 'present'),
#  ('present', 'in'),
#  ('in', 'human'),
#  ('human', 'language'),
#  ('language', '.'),
#  ('.', 'Unlike'),
#  ('Unlike', 'structured'),
#  ('structured', 'data'),
#  ('data', ','),
#  (',', 'natural'),
#  ('natural', 'language'),
#  ('language', 'is'),
#  ('is', 'rich'),
#  ('rich', ','),
#  (',', 'context-dependent'),
#  ('context-dependent', ','),
#  (',', 'and'),
#  ('and', 'laden'),
#  ('laden', 'with'),
#  ('with', 'intricacies'),
#  ('intricacies', 'such'),
#  ('such', 'as'),
#  ('as', 'idioms'),
#  ('idioms', ','),
#  (',', 'metaphors'),
#  ('metaphors', ','),
#  (',', 'and'),
#  ('and', 'cultural'),
#  ('cultural', 'nuances'),
#  ('nuances', '.'),
#  ('.', 'NLP'),
#  ('NLP', 'algorithms'),
#  ('algorithms', 'grapple'),
#  ('grapple', 'with'),
#  ('with', 'these'),
#  ('these', 'challenges'),
#  ('challenges', ','),
#  (',', 'aiming'),
#  ('aiming', 'to'),
#  ('to', 'impart'),
#  ('impart', 'machines'),
#  ('machines', 'with'),
#  ('with', 'the'),
#  ('the', 'capability'),
#  ('capability', 'to'),
#  ('to', 'comprehend'),
#  ('comprehend', 'the'),
#  ('the', 'subtleties'),
#  ('subtleties', 'of'),
#  ('of', 'language'),
#  ('language', ','),
#  (',', 'discern'),
#  ('discern', 'sentiment'),
#  ('sentiment', ','),
#  (',', 'and'),
#  ('and', 'extract'),
#  ('extract', 'meaningful'),
#  ('meaningful', 'information'),
#  ('information', 'from'),
#  ('from', 'vast'),
#  ('vast', 'corpora'),
#  ('corpora', 'of'),
#  ('of', 'text.The'),
#  ('text.The', 'evolution'),
#  ('evolution', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'can'),
#  ('can', 'be'),
#  ('be', 'traced'),
#  ('traced', 'back'),
#  ('back', 'to'),
#  ('to', 'the'),
#  ('the', 'mid-20th'),
#  ('mid-20th', 'century'),
#  ('century', 'when'),
#  ('when', 'researchers'),
#  ('researchers', 'began'),
#  ('began', 'exploring'),
#  ('exploring', 'the'),
#  ('the', 'possibility'),
#  ('possibility', 'of'),
#  ('of', 'teaching'),
#  ('teaching', 'computers'),
#  ('computers', 'to'),
#  ('to', 'understand'),
#  ('understand', 'and'),
#  ('and', 'generate'),
#  ('generate', 'human'),
#  ('human', 'language'),
#  ('language', '.'),
#  ('.', 'Early'),
#  ('Early', 'endeavors'),
#  ('endeavors', 'were'),
#  ('were', 'marked'),
#  ('marked', 'by'),
#  ('by', 'rule-based'),
#  ('rule-based', 'systems'),
#  ('systems', ','),
#  (',', 'where'),
#  ('where', 'linguistic'),
#  ('linguistic', 'rules'),
#  ('rules', 'were'),
#  ('were', 'manually'),
#  ('manually', 'crafted'),
#  ('crafted', 'to'),
#  ('to', 'parse'),
#  ('parse', 'and'),
#  ('and', 'analyze'),
#  ('analyze', 'text'),
#  ('text', '.'),
#  ('.', 'However'),
#  ('However', ','),
#  (',', 'the'),
#  ('the', 'inherent'),
#  ('inherent', 'limitations'),
#  ('limitations', 'of'),
#  ('of', 'rule-based'),
#  ('rule-based', 'approaches'),
#  ('approaches', 'became'),
#  ('became', 'evident'),
#  ('evident', 'as'),
#  ('as', 'the'),
#  ('the', 'scale'),
#  ('scale', 'and'),
#  ('and', 'complexity'),
#  ('complexity', 'of'),
#  ('of', 'linguistic'),
#  ('linguistic', 'patterns'),
#  ('patterns', 'expanded.The'),
#  ('expanded.The', 'advent'),
#  ('advent', 'of'),
#  ('of', 'machine'),
#  ('machine', 'learning'),
#  ('learning', 'and'),
#  ('and', 'the'),
#  ('the', 'availability'),
#  ('availability', 'of'),
#  ('of', 'large-scale'),
#  ('large-scale', 'linguistic'),
#  ('linguistic', 'datasets'),
#  ('datasets', 'revolutionized'),
#  ('revolutionized', 'the'),
#  ('the', 'NLP'),
#  ('NLP', 'landscape'),
#  ('landscape', '.'),
#  ('.', 'Statistical'),
#  ('Statistical', 'models'),
#  ('models', ','),
#  (',', 'particularly'),
#  ('particularly', 'those'),
#  ('those', 'based'),
#  ('based', 'on'),
#  ('on', 'probabilistic'),
#  ('probabilistic', 'approaches'),
#  ('approaches', ','),
#  (',', 'gained'),
#  ('gained', 'prominence'),
#  ('prominence', '.'),
#  ('.', 'These'),
#  ('These', 'models'),
#  ('models', ','),
#  (',', 'often'),
#  ('often', 'utilizing'),
#  ('utilizing', 'techniques'),
#  ('techniques', 'like'),
#  ('like', 'Hidden'),
#  ('Hidden', 'Markov'),
#  ('Markov', 'Models'),
#  ('Models', 'and'),
#  ('and', 'n-gram'),
#  ('n-gram', 'analysis'),
#  ('analysis', ','),
#  (',', 'demonstrated'),
#  ('demonstrated', 'improved'),
#  ('improved', 'language'),
#  ('language', 'understanding'),
#  ('understanding', 'capabilities'),
#  ('capabilities', 'by'),
#  ('by', 'learning'),
#  ('learning', 'patterns'),
#  ('patterns', 'and'),
#  ('and', 'probabilities'),
#  ('probabilities', 'from'),
#  ('from', 'data'),
#  ('data', '.'),
#  ('.', 'Yet'),
#  ('Yet', ','),
#  (',', 'they'),
#  ('they', 'struggled'),
#  ('struggled', 'with'),
#  ('with', 'the'),
#  ('the', 'contextual'),
#  ('contextual', 'intricacies'),
#  ('intricacies', 'inherent'),
#  ('inherent', 'in'),
#  ('in', 'language.A'),
#  ('language.A', 'paradigm'),
#  ('paradigm', 'shift'),
#  ('shift', 'occurred'),
#  ('occurred', 'with'),
#  ('with', 'the'),
#  ('the', 'rise'),
#  ('rise', 'of'),
#  ('of', 'neural'),
#  ('neural', 'network-based'),
#  ('network-based', 'approaches'),
#  ('approaches', ','),
#  (',', 'propelled'),
#  ('propelled', 'by'),
#  ('by', 'the'),
#  ('the', 'deep'),
#  ('deep', 'learning'),
#  ('learning', 'revolution'),
#  ('revolution', '.'),
#  ('.', 'Recurrent'),
#  ('Recurrent', 'Neural'),
#  ('Neural', 'Networks'),
#  ('Networks', '('),
#  ('(', 'RNNs'),
#  ('RNNs', ')'),
#  (')', 'and'),
#  ('and', ','),
#  (',', 'more'),
#  ('more', 'prominently'),
#  ('prominently', ','),
#  (',', 'Transformer'),
#  ('Transformer', 'architectures'),
#  ('architectures', ','),
#  (',', 'exemplified'),
#  ('exemplified', 'by'),
#  ('by', 'models'),
#  ('models', 'like'),
#  ('like', 'BERT'),
#  ('BERT', '('),
#  ('(', 'Bidirectional'),
#  ('Bidirectional', 'Encoder'),
#  ('Encoder', 'Representations'),
#  ('Representations', 'from'),
#  ('from', 'Transformers'),
#  ('Transformers', ')'),
#  (')', ','),
#  (',', 'GPT'),
#  ('GPT', '('),
#  ('(', 'Generative'),
#  ('Generative', 'Pre-trained'),
#  ('Pre-trained', 'Transformer'),
#  ('Transformer', ')'),
#  (')', ','),
#  (',', 'and'),
#  ('and', 'their'),
#  ('their', 'successors'),
#  ('successors', ','),
#  (',', 'have'),
#  ('have', 'redefined'),
#  ('redefined', 'the'),
#  ('the', 'state-of-the-art'),
#  ('state-of-the-art', 'in'),
#  ('in', 'NLP'),
#  ('NLP', '.'),
#  ('.', 'These'),
#  ('These', 'models'),
#  ('models', ','),
#  (',', 'often'),
#  ('often', 'pre-trained'),
#  ('pre-trained', 'on'),
#  ('on', 'massive'),
#  ('massive', 'datasets'),
#  ('datasets', ','),
#  (',', 'exhibit'),
#  ('exhibit', 'an'),
#  ('an', 'unprecedented'),
#  ('unprecedented', 'capacity'),
#  ('capacity', 'to'),
#  ('to', 'capture'),
#  ('capture', 'contextual'),
#  ('contextual', 'nuances'),
#  ('nuances', ','),
#  (',', 'syntactic'),
#  ('syntactic', 'structures'),
#  ('structures', ','),
#  (',', 'and'),
#  ('and', 'even'),
#  ('even', 'semantic'),
#  ('semantic', 'relationships'),
#  ('relationships', 'within'),
#  ('within', 'language.NLP'),
#  ('language.NLP', 'applications'),
#  ('applications', 'have'),
#  ('have', 'permeated'),
#  ('permeated', 'various'),
#  ('various', 'facets'),
#  ('facets', 'of'),
#  ('of', 'our'),
#  ('our', 'daily'),
#  ('daily', 'lives'),
#  ('lives', ','),
#  (',', 'showcasing'),
#  ('showcasing', 'the'),
#  ('the', 'practical'),
#  ('practical', 'impact'),
#  ('impact', 'of'),
#  ('of', 'this'),
#  ('this', 'field'),
#  ('field', '.'),
#  ('.', 'Virtual'),
#  ('Virtual', 'assistants'),
#  ('assistants', ','),
#  (',', 'such'),
#  ('such', 'as'),
#  ('as', 'Siri'),
#  ('Siri', 'and'),
#  ('and', 'Alexa'),
#  ('Alexa', ','),
#  (',', 'leverage'),
#  ('leverage', 'NLP'),
#  ('NLP', 'to'),
#  ('to', 'comprehend'),
#  ('comprehend', 'and'),
#  ('and', 'respond'),
#  ('respond', 'to'),
#  ('to', 'spoken'),
#  ('spoken', 'commands'),
#  ('commands', ','),
#  (',', 'showcasing'),
#  ('showcasing', 'the'),
#  ('the', 'ability'),
#  ('ability', 'to'),
#  ('to', 'understand'),
#  ('understand', 'and'),
#  ('and', 'generate'),
#  ('generate', 'human-like'),
#  ('human-like', 'speech'),
#  ('speech', '.'),
#  ('.', 'Sentiment'),
#  ('Sentiment', 'analysis'),
#  ('analysis', 'tools'),
#  ('tools', 'employ'),
#  ('employ', 'NLP'),
#  ('NLP', 'to'),
#  ('to', 'gauge'),
#  ('gauge', 'the'),
#  ('the', 'mood'),
#  ('mood', 'and'),
#  ('and', 'opinions'),
#  ('opinions', 'expressed'),
#  ('expressed', 'in'),
#  ('in', 'online'),
#  ('online', 'reviews'),
#  ('reviews', ','),
#  (',', 'social'),
#  ('social', 'media'),
#  ('media', 'posts'),
#  ('posts', ','),
#  (',', 'and'),
#  ('and', 'news'),
#  ('news', 'articles'),
#  ('articles', ','),
#  (',', 'offering'),
#  ('offering', 'valuable'),
#  ('valuable', 'insights'),
#  ('insights', 'for'),
#  ('for', 'businesses'),
#  ('businesses', 'and'),
#  ('and', 'researchers.Machine'),
#  ('researchers.Machine', 'translation'),
#  ('translation', ','),
#  (',', 'another'),
#  ('another', 'cornerstone'),
#  ('cornerstone', 'application'),
#  ('application', 'of'),
#  ('of', 'NLP'),
#  ('NLP', ','),
#  (',', 'has'),
#  ('has', 'undergone'),
#  ('undergone', 'remarkable'),
#  ('remarkable', 'transformations'),
#  ('transformations', '.'),
#  ('.', 'Neural'),
#  ('Neural', 'machine'),
#  ('machine', 'translation'),
#  ('translation', 'models'),
#  ('models', ','),
#  (',', 'driven'),
#  ('driven', 'by'),
#  ('by', 'deep'),
#  ('deep', 'learning'),
#  ('learning', ','),
#  (',', 'have'),
#  ('have', 'significantly'),
#  ('significantly', 'improved'),
#  ('improved', 'the'),
#  ('the', 'accuracy'),
#  ('accuracy', 'and'),
#  ('and', 'fluency'),
#  ('fluency', 'of'),
#  ('of', 'translations'),
#  ('translations', ','),
#  (',', 'making'),
#  ('making', 'cross-language'),
#  ('cross-language', 'communication'),
#  ('communication', 'more'),
#  ('more', 'accessible'),
#  ('accessible', '.'),
#  ('.', 'Moreover'),
#  ('Moreover', ','),
#  (',', 'in'),
#  ('in', 'the'),
#  ('the', 'realm'),
#  ('realm', 'of'),
#  ('of', 'healthcare'),
#  ('healthcare', ','),
#  (',', 'NLP'),
#  ('NLP', 'contributes'),
#  ('contributes', 'to'),
#  ('to', 'clinical'),
#  ('clinical', 'decision'),
#  ('decision', 'support'),
#  ('support', 'systems'),
#  ('systems', ','),
#  (',', 'extracting'),
#  ('extracting', 'valuable'),
#  ('valuable', 'information'),
#  ('information', 'from'),
#  ('from', 'electronic'),
#  ('electronic', 'health'),
#  ('health', 'records'),
#  ('records', 'and'),
#  ('and', 'medical'),
#  ('medical', 'literature'),
#  ('literature', ','),
#  (',', 'aiding'),
#  ('aiding', 'healthcare'),
#  ('healthcare', 'professionals'),
#  ('professionals', 'in'),
#  ('in', 'making'),
#  ('making', 'informed'),
#  ('informed', 'decisions.Despite'),
#  ('decisions.Despite', 'these'),
#  ('these', 'advancements'),
#  ('advancements', ','),
#  (',', 'challenges'),
#  ('challenges', 'persist'),
#  ('persist', 'within'),
#  ('within', 'the'),
#  ('the', 'realm'),
#  ('realm', 'of'),
#  ('of', 'NLP'),
#  ('NLP', '.'),
#  ('.', 'The'),
#  ('The', 'understanding'),
#  ('understanding', 'of'),
#  ('of', 'context'),
#  ('context', ','),
#  (',', 'especially'),
#  ('especially', 'in'),
#  ('in', 'ambiguous'),
#  ('ambiguous', 'scenarios'),
#  ('scenarios', ','),
#  (',', 'remains'),
#  ('remains', 'an'),
#  ('an', 'ongoing'),
#  ('ongoing', 'area'),
#  ('area', 'of'),
#  ('of', 'research'),
#  ('research', '.'),
#  ('.', 'Issues'),
#  ('Issues', 'of'),
#  ('of', 'bias'),
#  ('bias', 'and'),
#  ('and', 'fairness'),
#  ('fairness', 'in'),
#  ('in', 'language'),
#  ('language', 'models'),
#  ('models', 'have'),
#  ('have', 'garnered'),
#  ('garnered', 'increased'),
#  ('increased', 'attention'),
#  ('attention', ','),
#  (',', 'necessitating'),
#  ('necessitating', 'ethical'),
#  ('ethical', 'considerations'),
#  ('considerations', 'in'),
#  ('in', 'the'),
#  ('the', 'development'),
#  ('development', 'and'),
#  ('and', 'deployment'),
#  ('deployment', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'systems'),
#  ('systems', '.'),
#  ('.', 'Additionally'),
#  ('Additionally', ','),
#  (',', 'the'),
#  ('the', 'multilingual'),
#  ('multilingual', 'nature'),
#  ('nature', 'of'),
#  ('of', 'communication'),
#  ('communication', 'poses'),
#  ('poses', 'a'),
#  ('a', 'challenge'),
#  ('challenge', ','),
#  (',', 'requiring'),
#  ('requiring', 'NLP'),
#  ('NLP', 'models'),
#  ('models', 'to'),
#  ('to', 'be'),
#  ('be', 'adept'),
#  ('adept', 'at'),
#  ('at', 'understanding'),
#  ('understanding', 'diverse'),
#  ('diverse', 'linguistic'),
#  ('linguistic', 'structures'),
#  ('structures', 'and'),
#  ('and', 'cultural'),
#  ('cultural', 'nuances.The'),
#  ('nuances.The', 'future'),
#  ('future', 'trajectory'),
#  ('trajectory', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'holds'),
#  ('holds', 'immense'),
#  ('immense', 'promise'),
#  ('promise', 'and'),
#  ('and', 'raises'),
#  ('raises', 'intriguing'),
#  ('intriguing', 'possibilities'),
#  ('possibilities', '.'),
#  ('.', 'Continued'),
#  ('Continued', 'advancements'),
#  ('advancements', 'in'),
#  ('in', 'transformer'),
#  ('transformer', 'architectures'),
#  ('architectures', ','),
#  (',', 'coupled'),
#  ('coupled', 'with'),
#  ('with', 'ongoing'),
#  ('ongoing', 'research'),
#  ('research', 'in'),
#  ('in', 'unsupervised'),
#  ('unsupervised', 'and'),
#  ('and', 'self-supervised'),
#  ('self-supervised', 'learning'),
#  ('learning', ','),
#  (',', 'are'),
#  ('are', 'expected'),
#  ('expected', 'to'),
#  ('to', 'further'),
#  ('further', 'enhance'),
#  ('enhance', 'the'),
#  ('the', 'capabilities'),
#  ('capabilities', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'models'),
#  ('models', '.'),
#  ('.', 'The'),
#  ('The', 'pursuit'),
#  ('pursuit', 'of'),
#  ('of', 'Explainable'),
#  ('Explainable', 'AI'),
#  ('AI', '('),
#  ('(', 'XAI'),
#  ('XAI', ')'),
#  (')', 'within'),
#  ('within', 'NLP'),
#  ('NLP', 'aims'),
#  ('aims', 'to'),
#  ('to', 'demystify'),
#  ('demystify', 'the'),
#  ('the', 'decision-making'),
#  ('decision-making', 'processes'),
#  ('processes', 'of'),
#  ('of', 'these'),
#  ('these', 'models'),
#  ('models', ','),
#  (',', 'fostering'),
#  ('fostering', 'transparency'),
#  ('transparency', 'and'),
#  ('and', 'trust.In'),
#  ('trust.In', 'conclusion'),
#  ('conclusion', ','),
#  (',', 'Natural'),
#  ('Natural', 'Language'),
#  ('Language', 'Processing'),
#  ('Processing', 'stands'),
#  ('stands', 'as'),
#  ('as', 'a'),
#  ('a', 'testament'),
#  ('testament', 'to'),
#  ('to', 'the'),
#  ('the', 'remarkable'),
#  ('remarkable', 'convergence'),
#  ('convergence', 'of'),
#  ('of', 'linguistics'),
#  ('linguistics', ','),
#  (',', 'computer'),
#  ('computer', 'science'),
#  ('science', ','),
#  (',', 'and'),
#  ('and', 'artificial'),
#  ('artificial', 'intelligence'),
#  ('intelligence', '.'),
#  ('.', 'From'),
#  ('From', 'rule-based'),
#  ('rule-based', 'systems'),
#  ('systems', 'to'),
#  ('to', 'state-of-the-art'),
#  ('state-of-the-art', 'transformer'),
#  ('transformer', 'models'),
#  ('models', ','),
#  (',', 'the'),
#  ('the', 'journey'),
#  ('journey', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'reflects'),
#  ('reflects', 'a'),
#  ('a', 'relentless'),
#  ('relentless', 'pursuit'),
#  ('pursuit', 'of'),
#  ('of', 'understanding'),
#  ('understanding', 'and'),
#  ('and', 'harnessing'),
#  ('harnessing', 'the'),
#  ('the', 'power'),
#  ('power', 'of'),
#  ('of', 'human'),
#  ('human', 'language'),
#  ('language', '.'),
#  ('.', 'As'),
#  ('As', 'NLP'),
#  ('NLP', 'continues'),
#  ('continues', 'to'),
#  ('to', 'shape'),
#  ('shape', 'our'),
#  ('our', 'digital'),
#  ('digital', 'interactions'),
#  ('interactions', ','),
#  (',', 'its'),
#  ('its', 'impact'),
#  ('impact', 'reverberates'),
#  ('reverberates', 'across'),
#  ('across', 'industries'),
#  ('industries', ','),
#  (',', 'shaping'),
#  ('shaping', 'the'),
#  ('the', 'way'),
#  ('way', 'we'),
#  ('we', 'communicate'),
#  ('communicate', ','),
#  (',', 'gather'),
#  ('gather', 'information'),
#  ('information', ','),
#  (',', 'and'),
#  ('and', 'engage'),
#  ('engage', 'with'),
#  ('with', 'technology'),
#  ('technology', '.'),
#  ('.', 'The'),
#  ('The', 'ongoing'),
#  ('ongoing', 'exploration'),
#  ('exploration', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'holds'),
#  ('holds', 'the'),
#  ('the', 'promise'),
#  ('promise', 'of'),
#  ('of', 'not'),
#  ('not', 'only'),
#  ('only', 'unraveling'),
#  ('unraveling', 'the'),
#  ('the', 'intricacies'),
#  ('intricacies', 'of'),
#  ('of', 'language'),
#  ('language', 'but'),
#  ('but', 'also'),
#  ('also', 'fostering'),
#  ('fostering', 'a'),
#  ('a', 'more'),
#  ('more', 'connected'),
#  ('connected', 'and'),
#  ('and', 'intelligible'),
#  ('intelligible', 'future'),
#  ('future', 'between'),
#  ('between', 'humans'),
#  ('humans', 'and'),
#  ('and', 'machines.Computer'),
#  ('machines.Computer', 'vision'),
#  ('vision', ','),
#  (',', 'an'),
#  ('an', 'interdisciplinary'),
#  ('interdisciplinary', 'field'),
#  ('field', 'situated'),
#  ('situated', 'at'),
#  ('at', 'the'),
#  ('the', 'intersection'),
#  ('intersection', 'of'),
#  ('of', 'computer'),
#  ('computer', 'science'),
#  ('science', ','),
#  (',', 'machine'),
#  ('machine', 'learning'),
#  ('learning', ','),
#  (',', 'and'),
#  ('and', 'image'),
#  ('image', 'processing'),
#  ('processing', ','),
#  (',', 'seeks'),
#  ('seeks', 'to'),
#  ('to', 'emulate'),
#  ('emulate', 'human'),
#  ('human', 'vision'),
#  ('vision', 'capabilities'),
#  ('capabilities', 'in'),
#  ('in', 'machines'),
#  ('machines', '.'),
#  ('.', 'At'),
#  ('At', 'its'),
#  ('its', 'essence'),
#  ('essence', ','),
#  (',', 'computer'),
#  ('computer', 'vision'),
#  ('vision', 'endeavors'),
#  ('endeavors', 'to'),
#  ('to', 'empower'),
#  ('empower', 'machines'),
#  ('machines', 'with'),
#  ('with', 'the'),
#  ('the', 'ability'),
#  ('ability', 'to'),
#  ('to', 'interpret'),
#  ('interpret', 'and'),
#  ('and', 'understand'),
#  ('understand', 'visual'),
#  ('visual', 'information'),
#  ('information', 'from'),
#  ('from', 'the'),
#  ('the', 'world'),
#  ('world', 'around'),
#  ('around', 'them'),
#  ('them', '.'),
#  ('.', 'Anchored'),
#  ('Anchored', 'by'),
#  ('by', 'a'),
#  ('a', 'myriad'),
#  ('myriad', 'of'),
#  ('of', 'algorithms'),
#  ('algorithms', ','),
#  (',', 'models'),
#  ('models', ','),
#  (',', 'and'),
#  ('and', 'technologies'),
#  ('technologies', ','),
#  (',', 'computer'),
#  ('computer', 'vision'),
#  ('vision', 'has'),
#  ('has', 'evolved'),
#  ('evolved', 'from'),
#  ('from', 'basic'),
#  ('basic', 'image'),
#  ('image', 'processing'),
#  ('processing', 'tasks'),
#  ('tasks', 'to'),
#  ('to', 'sophisticated'),
#  ('sophisticated', 'applications'),
#  ('applications', 'that'),
#  ('that', 'transcend'),
#  ('transcend', 'human'),
#  ('human', 'visual'),
#  ('visual', 'abilities.The'),
#  ('abilities.The', 'foundational'),
#  ('foundational', 'principle'),
#  ('principle', 'of'),
#  ('of', 'computer'),
#  ('computer', 'vision'),
#  ('vision', 'lies'),
#  ('lies', 'in'),
#  ('in', 'image'),
#  ('image', 'understanding'),
#  ('understanding', 'and'),
#  ('and', 'pattern'),
#  ('pattern', 'recognition'),
#  ('recognition', '.'),
#  ('.', 'Early'),
#  ('Early', 'developments'),
#  ('developments', 'centered'),
#  ('centered', 'on'),
#  ('on', 'tasks'),
#  ('tasks', 'such'),
#  ('such', 'as'),
#  ('as', 'image'),
#  ('image', 'segmentation'),
#  ('segmentation', 'and'),
#  ('and', 'object'),
#  ('object', 'detection'),
#  ('detection', ','),
#  (',', 'where'),
#  ('where', 'algorithms'),
#  ('algorithms', 'were'),
#  ('were', 'designed'),
#  ('designed', 'to'),
#  ('to', 'identify'),
#  ('identify', 'and'),
#  ('and', 'delineate'),
#  ('delineate', 'distinct'),
#  ('distinct', 'elements'),
#  ('elements', 'within'),
#  ('within', 'an'),
#  ('an', 'image'),
#  ('image', '.'),
#  ('.', 'As'),
#  ('As', 'the'),
#  ('the', 'field'),
#  ('field', 'progressed'),
#  ('progressed', ','),
#  (',', 'the'),
#  ('the', 'advent'),
#  ('advent', 'of'),
#  ('of', 'feature'),
#  ('feature', 'extraction'),
#  ('extraction', 'techniques'),
#  ('techniques', ','),
#  (',', 'including'),
#  ('including', 'edge'),
#  ('edge', 'detection'),
#  ('detection', 'and'),
#  ('and', 'corner'),
#  ('corner', 'detection'),
#  ('detection', ','),
#  (',', 'enhanced'),
#  ('enhanced', 'the'),
#  ('the', 'ability'),
#  ('ability', 'of'),
#  ('of', 'systems'),
#  ('systems', 'to'),
#  ('to', 'capture'),
#  ('capture', 'and'),
#  ('and', 'analyze'),
#  ('analyze', 'intricate'),
#  ('intricate', 'details'),
#  ('details', 'in'),
#  ('in', 'visual'),
#  ('visual', 'data.Advancements'),
#  ('data.Advancements', 'in'),
#  ('in', 'machine'),
#  ('machine', 'learning'),
#  ('learning', ','),
#  (',', 'particularly'),
#  ('particularly', 'the'),
#  ('the', 'rise'),
#  ('rise', 'of'),
#  ('of', 'deep'),
#  ('deep', 'learning'),
#  ('learning', 'architectures'),
#  ('architectures', ','),
#  (',', 'marked'),
#  ('marked', 'a'),
#  ('a', 'watershed'),
#  ('watershed', 'moment'),
#  ('moment', 'in'),
#  ('in', 'the'),
#  ('the', 'evolution'),
#  ('evolution', 'of'),
#  ('of', 'computer'),
#  ('computer', 'vision'),
#  ('vision', '.'),
#  ('.', 'Convolutional'),
#  ('Convolutional', 'Neural'),
#  ('Neural', 'Networks'),
#  ('Networks', '('),
#  ('(', 'CNNs'),
#  ('CNNs', ')'),
#  (')', 'emerged'),
#  ('emerged', 'as'),
#  ('as', 'a'),
#  ('a', 'cornerstone'),
#  ('cornerstone', 'technology'),
#  ('technology', ','),
#  (',', 'revolutionizing'),
#  ('revolutionizing', 'image'),
#  ('image', 'classification'),
#  ('classification', ','),
#  (',', 'object'),
#  ('object', 'detection'),
#  ('detection', ','),
#  (',', 'and'),
#  ('and', 'semantic'),
#  ('semantic', 'segmentation'),
#  ('segmentation', '.'),
#  ('.', 'Pioneering'),
#  ('Pioneering', 'models'),
#  ('models', 'like'),
#  ('like', 'AlexNet'),
#  ('AlexNet', ','),
#  (',', 'VGGNet'),
#  ('VGGNet', ','),
#  (',', 'and'),
#  ...]

# %%
daw_trigrams
# Out:
# [('Natural', 'Language', 'Processing'),
#  ('Language', 'Processing', '('),
#  ('Processing', '(', 'NLP'),
#  ('(', 'NLP', ')'),
#  ('NLP', ')', 'represents'),
#  (')', 'represents', 'a'),
#  ('represents', 'a', 'transformative'),
#  ('a', 'transformative', 'field'),
#  ('transformative', 'field', 'within'),
#  ('field', 'within', 'the'),
#  ('within', 'the', 'domain'),
#  ('the', 'domain', 'of'),
#  ('domain', 'of', 'artificial'),
#  ('of', 'artificial', 'intelligence'),
#  ('artificial', 'intelligence', ','),
#  ('intelligence', ',', 'dedicated'),
#  (',', 'dedicated', 'to'),
#  ('dedicated', 'to', 'unraveling'),
#  ('to', 'unraveling', 'the'),
#  ('unraveling', 'the', 'complexities'),
#  ('the', 'complexities', 'of'),
#  ('complexities', 'of', 'human'),
#  ('of', 'human', 'language'),
#  ('human', 'language', 'and'),
#  ('language', 'and', 'enabling'),
#  ('and', 'enabling', 'machines'),
#  ('enabling', 'machines', 'to'),
#  ('machines', 'to', 'comprehend'),
#  ('to', 'comprehend', ','),
#  ('comprehend', ',', 'interpret'),
#  (',', 'interpret', ','),
#  ('interpret', ',', 'and'),
#  (',', 'and', 'generate'),
#  ('and', 'generate', 'human-like'),
#  ('generate', 'human-like', 'text'),
#  ('human-like', 'text', '.'),
#  ('text', '.', 'At'),
#  ('.', 'At', 'its'),
#  ('At', 'its', 'core'),
#  ('its', 'core', ','),
#  ('core', ',', 'NLP'),
#  (',', 'NLP', 'seeks'),
#  ('NLP', 'seeks', 'to'),
#  ('seeks', 'to', 'bridge'),
#  ('to', 'bridge', 'the'),
#  ('bridge', 'the', 'communication'),
#  ('the', 'communication', 'gap'),
#  ('communication', 'gap', 'between'),
#  ('gap', 'between', 'humans'),
#  ('between', 'humans', 'and'),
#  ('humans', 'and', 'computers'),
#  ('and', 'computers', ','),
#  ('computers', ',', 'opening'),
#  (',', 'opening', 'up'),
#  ('opening', 'up', 'avenues'),
#  ('up', 'avenues', 'for'),
#  ('avenues', 'for', 'seamless'),
#  ('for', 'seamless', 'interaction'),
#  ('seamless', 'interaction', 'and'),
#  ('interaction', 'and', 'understanding'),
#  ('and', 'understanding', '.'),
#  ('understanding', '.', 'This'),
#  ('.', 'This', 'interdisciplinary'),
#  ('This', 'interdisciplinary', 'field'),
#  ('interdisciplinary', 'field', 'draws'),
#  ('field', 'draws', 'upon'),
#  ('draws', 'upon', 'linguistics'),
#  ('upon', 'linguistics', ','),
#  ('linguistics', ',', 'computer'),
#  (',', 'computer', 'science'),
#  ('computer', 'science', ','),
#  ('science', ',', 'and'),
#  (',', 'and', 'machine'),
#  ('and', 'machine', 'learning'),
#  ('machine', 'learning', ','),
#  ('learning', ',', 'fusing'),
#  (',', 'fusing', 'these'),
#  ('fusing', 'these', 'domains'),
#  ('these', 'domains', 'to'),
#  ('domains', 'to', 'create'),
#  ('to', 'create', 'algorithms'),
#  ('create', 'algorithms', 'and'),
#  ('algorithms', 'and', 'models'),
#  ('and', 'models', 'that'),
#  ('models', 'that', 'can'),
#  ('that', 'can', 'navigate'),
#  ('can', 'navigate', 'the'),
#  ('navigate', 'the', 'nuances'),
#  ('the', 'nuances', 'of'),
#  ('nuances', 'of', 'natural'),
#  ('of', 'natural', 'language.One'),
#  ('natural', 'language.One', 'of'),
#  ('language.One', 'of', 'the'),
#  ('of', 'the', 'foundational'),
#  ('the', 'foundational', 'challenges'),
#  ('foundational', 'challenges', 'that'),
#  ('challenges', 'that', 'NLP'),
#  ('that', 'NLP', 'addresses'),
#  ('NLP', 'addresses', 'is'),
#  ('addresses', 'is', 'the'),
#  ('is', 'the', 'inherent'),
#  ('the', 'inherent', 'ambiguity'),
#  ('inherent', 'ambiguity', 'and'),
#  ('ambiguity', 'and', 'variability'),
#  ('and', 'variability', 'present'),
#  ('variability', 'present', 'in'),
#  ('present', 'in', 'human'),
#  ('in', 'human', 'language'),
#  ('human', 'language', '.'),
#  ('language', '.', 'Unlike'),
#  ('.', 'Unlike', 'structured'),
#  ('Unlike', 'structured', 'data'),
#  ('structured', 'data', ','),
#  ('data', ',', 'natural'),
#  (',', 'natural', 'language'),
#  ('natural', 'language', 'is'),
#  ('language', 'is', 'rich'),
#  ('is', 'rich', ','),
#  ('rich', ',', 'context-dependent'),
#  (',', 'context-dependent', ','),
#  ('context-dependent', ',', 'and'),
#  (',', 'and', 'laden'),
#  ('and', 'laden', 'with'),
#  ('laden', 'with', 'intricacies'),
#  ('with', 'intricacies', 'such'),
#  ('intricacies', 'such', 'as'),
#  ('such', 'as', 'idioms'),
#  ('as', 'idioms', ','),
#  ('idioms', ',', 'metaphors'),
#  (',', 'metaphors', ','),
#  ('metaphors', ',', 'and'),
#  (',', 'and', 'cultural'),
#  ('and', 'cultural', 'nuances'),
#  ('cultural', 'nuances', '.'),
#  ('nuances', '.', 'NLP'),
#  ('.', 'NLP', 'algorithms'),
#  ('NLP', 'algorithms', 'grapple'),
#  ('algorithms', 'grapple', 'with'),
#  ('grapple', 'with', 'these'),
#  ('with', 'these', 'challenges'),
#  ('these', 'challenges', ','),
#  ('challenges', ',', 'aiming'),
#  (',', 'aiming', 'to'),
#  ('aiming', 'to', 'impart'),
#  ('to', 'impart', 'machines'),
#  ('impart', 'machines', 'with'),
#  ('machines', 'with', 'the'),
#  ('with', 'the', 'capability'),
#  ('the', 'capability', 'to'),
#  ('capability', 'to', 'comprehend'),
#  ('to', 'comprehend', 'the'),
#  ('comprehend', 'the', 'subtleties'),
#  ('the', 'subtleties', 'of'),
#  ('subtleties', 'of', 'language'),
#  ('of', 'language', ','),
#  ('language', ',', 'discern'),
#  (',', 'discern', 'sentiment'),
#  ('discern', 'sentiment', ','),
#  ('sentiment', ',', 'and'),
#  (',', 'and', 'extract'),
#  ('and', 'extract', 'meaningful'),
#  ('extract', 'meaningful', 'information'),
#  ('meaningful', 'information', 'from'),
#  ('information', 'from', 'vast'),
#  ('from', 'vast', 'corpora'),
#  ('vast', 'corpora', 'of'),
#  ('corpora', 'of', 'text.The'),
#  ('of', 'text.The', 'evolution'),
#  ('text.The', 'evolution', 'of'),
#  ('evolution', 'of', 'NLP'),
#  ('of', 'NLP', 'can'),
#  ('NLP', 'can', 'be'),
#  ('can', 'be', 'traced'),
#  ('be', 'traced', 'back'),
#  ('traced', 'back', 'to'),
#  ('back', 'to', 'the'),
#  ('to', 'the', 'mid-20th'),
#  ('the', 'mid-20th', 'century'),
#  ('mid-20th', 'century', 'when'),
#  ('century', 'when', 'researchers'),
#  ('when', 'researchers', 'began'),
#  ('researchers', 'began', 'exploring'),
#  ('began', 'exploring', 'the'),
#  ('exploring', 'the', 'possibility'),
#  ('the', 'possibility', 'of'),
#  ('possibility', 'of', 'teaching'),
#  ('of', 'teaching', 'computers'),
#  ('teaching', 'computers', 'to'),
#  ('computers', 'to', 'understand'),
#  ('to', 'understand', 'and'),
#  ('understand', 'and', 'generate'),
#  ('and', 'generate', 'human'),
#  ('generate', 'human', 'language'),
#  ('human', 'language', '.'),
#  ('language', '.', 'Early'),
#  ('.', 'Early', 'endeavors'),
#  ('Early', 'endeavors', 'were'),
#  ('endeavors', 'were', 'marked'),
#  ('were', 'marked', 'by'),
#  ('marked', 'by', 'rule-based'),
#  ('by', 'rule-based', 'systems'),
#  ('rule-based', 'systems', ','),
#  ('systems', ',', 'where'),
#  (',', 'where', 'linguistic'),
#  ('where', 'linguistic', 'rules'),
#  ('linguistic', 'rules', 'were'),
#  ('rules', 'were', 'manually'),
#  ('were', 'manually', 'crafted'),
#  ('manually', 'crafted', 'to'),
#  ('crafted', 'to', 'parse'),
#  ('to', 'parse', 'and'),
#  ('parse', 'and', 'analyze'),
#  ('and', 'analyze', 'text'),
#  ('analyze', 'text', '.'),
#  ('text', '.', 'However'),
#  ('.', 'However', ','),
#  ('However', ',', 'the'),
#  (',', 'the', 'inherent'),
#  ('the', 'inherent', 'limitations'),
#  ('inherent', 'limitations', 'of'),
#  ('limitations', 'of', 'rule-based'),
#  ('of', 'rule-based', 'approaches'),
#  ('rule-based', 'approaches', 'became'),
#  ('approaches', 'became', 'evident'),
#  ('became', 'evident', 'as'),
#  ('evident', 'as', 'the'),
#  ('as', 'the', 'scale'),
#  ('the', 'scale', 'and'),
#  ('scale', 'and', 'complexity'),
#  ('and', 'complexity', 'of'),
#  ('complexity', 'of', 'linguistic'),
#  ('of', 'linguistic', 'patterns'),
#  ('linguistic', 'patterns', 'expanded.The'),
#  ('patterns', 'expanded.The', 'advent'),
#  ('expanded.The', 'advent', 'of'),
#  ('advent', 'of', 'machine'),
#  ('of', 'machine', 'learning'),
#  ('machine', 'learning', 'and'),
#  ('learning', 'and', 'the'),
#  ('and', 'the', 'availability'),
#  ('the', 'availability', 'of'),
#  ('availability', 'of', 'large-scale'),
#  ('of', 'large-scale', 'linguistic'),
#  ('large-scale', 'linguistic', 'datasets'),
#  ('linguistic', 'datasets', 'revolutionized'),
#  ('datasets', 'revolutionized', 'the'),
#  ('revolutionized', 'the', 'NLP'),
#  ('the', 'NLP', 'landscape'),
#  ('NLP', 'landscape', '.'),
#  ('landscape', '.', 'Statistical'),
#  ('.', 'Statistical', 'models'),
#  ('Statistical', 'models', ','),
#  ('models', ',', 'particularly'),
#  (',', 'particularly', 'those'),
#  ('particularly', 'those', 'based'),
#  ('those', 'based', 'on'),
#  ('based', 'on', 'probabilistic'),
#  ('on', 'probabilistic', 'approaches'),
#  ('probabilistic', 'approaches', ','),
#  ('approaches', ',', 'gained'),
#  (',', 'gained', 'prominence'),
#  ('gained', 'prominence', '.'),
#  ('prominence', '.', 'These'),
#  ('.', 'These', 'models'),
#  ('These', 'models', ','),
#  ('models', ',', 'often'),
#  (',', 'often', 'utilizing'),
#  ('often', 'utilizing', 'techniques'),
#  ('utilizing', 'techniques', 'like'),
#  ('techniques', 'like', 'Hidden'),
#  ('like', 'Hidden', 'Markov'),
#  ('Hidden', 'Markov', 'Models'),
#  ('Markov', 'Models', 'and'),
#  ('Models', 'and', 'n-gram'),
#  ('and', 'n-gram', 'analysis'),
#  ('n-gram', 'analysis', ','),
#  ('analysis', ',', 'demonstrated'),
#  (',', 'demonstrated', 'improved'),
#  ('demonstrated', 'improved', 'language'),
#  ('improved', 'language', 'understanding'),
#  ('language', 'understanding', 'capabilities'),
#  ('understanding', 'capabilities', 'by'),
#  ('capabilities', 'by', 'learning'),
#  ('by', 'learning', 'patterns'),
#  ('learning', 'patterns', 'and'),
#  ('patterns', 'and', 'probabilities'),
#  ('and', 'probabilities', 'from'),
#  ('probabilities', 'from', 'data'),
#  ('from', 'data', '.'),
#  ('data', '.', 'Yet'),
#  ('.', 'Yet', ','),
#  ('Yet', ',', 'they'),
#  (',', 'they', 'struggled'),
#  ('they', 'struggled', 'with'),
#  ('struggled', 'with', 'the'),
#  ('with', 'the', 'contextual'),
#  ('the', 'contextual', 'intricacies'),
#  ('contextual', 'intricacies', 'inherent'),
#  ('intricacies', 'inherent', 'in'),
#  ('inherent', 'in', 'language.A'),
#  ('in', 'language.A', 'paradigm'),
#  ('language.A', 'paradigm', 'shift'),
#  ('paradigm', 'shift', 'occurred'),
#  ('shift', 'occurred', 'with'),
#  ('occurred', 'with', 'the'),
#  ('with', 'the', 'rise'),
#  ('the', 'rise', 'of'),
#  ('rise', 'of', 'neural'),
#  ('of', 'neural', 'network-based'),
#  ('neural', 'network-based', 'approaches'),
#  ('network-based', 'approaches', ','),
#  ('approaches', ',', 'propelled'),
#  (',', 'propelled', 'by'),
#  ('propelled', 'by', 'the'),
#  ('by', 'the', 'deep'),
#  ('the', 'deep', 'learning'),
#  ('deep', 'learning', 'revolution'),
#  ('learning', 'revolution', '.'),
#  ('revolution', '.', 'Recurrent'),
#  ('.', 'Recurrent', 'Neural'),
#  ('Recurrent', 'Neural', 'Networks'),
#  ('Neural', 'Networks', '('),
#  ('Networks', '(', 'RNNs'),
#  ('(', 'RNNs', ')'),
#  ('RNNs', ')', 'and'),
#  (')', 'and', ','),
#  ('and', ',', 'more'),
#  (',', 'more', 'prominently'),
#  ('more', 'prominently', ','),
#  ('prominently', ',', 'Transformer'),
#  (',', 'Transformer', 'architectures'),
#  ('Transformer', 'architectures', ','),
#  ('architectures', ',', 'exemplified'),
#  (',', 'exemplified', 'by'),
#  ('exemplified', 'by', 'models'),
#  ('by', 'models', 'like'),
#  ('models', 'like', 'BERT'),
#  ('like', 'BERT', '('),
#  ('BERT', '(', 'Bidirectional'),
#  ('(', 'Bidirectional', 'Encoder'),
#  ('Bidirectional', 'Encoder', 'Representations'),
#  ('Encoder', 'Representations', 'from'),
#  ('Representations', 'from', 'Transformers'),
#  ('from', 'Transformers', ')'),
#  ('Transformers', ')', ','),
#  (')', ',', 'GPT'),
#  (',', 'GPT', '('),
#  ('GPT', '(', 'Generative'),
#  ('(', 'Generative', 'Pre-trained'),
#  ('Generative', 'Pre-trained', 'Transformer'),
#  ('Pre-trained', 'Transformer', ')'),
#  ('Transformer', ')', ','),
#  (')', ',', 'and'),
#  (',', 'and', 'their'),
#  ('and', 'their', 'successors'),
#  ('their', 'successors', ','),
#  ('successors', ',', 'have'),
#  (',', 'have', 'redefined'),
#  ('have', 'redefined', 'the'),
#  ('redefined', 'the', 'state-of-the-art'),
#  ('the', 'state-of-the-art', 'in'),
#  ('state-of-the-art', 'in', 'NLP'),
#  ('in', 'NLP', '.'),
#  ('NLP', '.', 'These'),
#  ('.', 'These', 'models'),
#  ('These', 'models', ','),
#  ('models', ',', 'often'),
#  (',', 'often', 'pre-trained'),
#  ('often', 'pre-trained', 'on'),
#  ('pre-trained', 'on', 'massive'),
#  ('on', 'massive', 'datasets'),
#  ('massive', 'datasets', ','),
#  ('datasets', ',', 'exhibit'),
#  (',', 'exhibit', 'an'),
#  ('exhibit', 'an', 'unprecedented'),
#  ('an', 'unprecedented', 'capacity'),
#  ('unprecedented', 'capacity', 'to'),
#  ('capacity', 'to', 'capture'),
#  ('to', 'capture', 'contextual'),
#  ('capture', 'contextual', 'nuances'),
#  ('contextual', 'nuances', ','),
#  ('nuances', ',', 'syntactic'),
#  (',', 'syntactic', 'structures'),
#  ('syntactic', 'structures', ','),
#  ('structures', ',', 'and'),
#  (',', 'and', 'even'),
#  ('and', 'even', 'semantic'),
#  ('even', 'semantic', 'relationships'),
#  ('semantic', 'relationships', 'within'),
#  ('relationships', 'within', 'language.NLP'),
#  ('within', 'language.NLP', 'applications'),
#  ('language.NLP', 'applications', 'have'),
#  ('applications', 'have', 'permeated'),
#  ('have', 'permeated', 'various'),
#  ('permeated', 'various', 'facets'),
#  ('various', 'facets', 'of'),
#  ('facets', 'of', 'our'),
#  ('of', 'our', 'daily'),
#  ('our', 'daily', 'lives'),
#  ('daily', 'lives', ','),
#  ('lives', ',', 'showcasing'),
#  (',', 'showcasing', 'the'),
#  ('showcasing', 'the', 'practical'),
#  ('the', 'practical', 'impact'),
#  ('practical', 'impact', 'of'),
#  ('impact', 'of', 'this'),
#  ('of', 'this', 'field'),
#  ('this', 'field', '.'),
#  ('field', '.', 'Virtual'),
#  ('.', 'Virtual', 'assistants'),
#  ('Virtual', 'assistants', ','),
#  ('assistants', ',', 'such'),
#  (',', 'such', 'as'),
#  ('such', 'as', 'Siri'),
#  ('as', 'Siri', 'and'),
#  ('Siri', 'and', 'Alexa'),
#  ('and', 'Alexa', ','),
#  ('Alexa', ',', 'leverage'),
#  (',', 'leverage', 'NLP'),
#  ('leverage', 'NLP', 'to'),
#  ('NLP', 'to', 'comprehend'),
#  ('to', 'comprehend', 'and'),
#  ('comprehend', 'and', 'respond'),
#  ('and', 'respond', 'to'),
#  ('respond', 'to', 'spoken'),
#  ('to', 'spoken', 'commands'),
#  ('spoken', 'commands', ','),
#  ('commands', ',', 'showcasing'),
#  (',', 'showcasing', 'the'),
#  ('showcasing', 'the', 'ability'),
#  ('the', 'ability', 'to'),
#  ('ability', 'to', 'understand'),
#  ('to', 'understand', 'and'),
#  ('understand', 'and', 'generate'),
#  ('and', 'generate', 'human-like'),
#  ('generate', 'human-like', 'speech'),
#  ('human-like', 'speech', '.'),
#  ('speech', '.', 'Sentiment'),
#  ('.', 'Sentiment', 'analysis'),
#  ('Sentiment', 'analysis', 'tools'),
#  ('analysis', 'tools', 'employ'),
#  ('tools', 'employ', 'NLP'),
#  ('employ', 'NLP', 'to'),
#  ('NLP', 'to', 'gauge'),
#  ('to', 'gauge', 'the'),
#  ('gauge', 'the', 'mood'),
#  ('the', 'mood', 'and'),
#  ('mood', 'and', 'opinions'),
#  ('and', 'opinions', 'expressed'),
#  ('opinions', 'expressed', 'in'),
#  ('expressed', 'in', 'online'),
#  ('in', 'online', 'reviews'),
#  ('online', 'reviews', ','),
#  ('reviews', ',', 'social'),
#  (',', 'social', 'media'),
#  ('social', 'media', 'posts'),
#  ('media', 'posts', ','),
#  ('posts', ',', 'and'),
#  (',', 'and', 'news'),
#  ('and', 'news', 'articles'),
#  ('news', 'articles', ','),
#  ('articles', ',', 'offering'),
#  (',', 'offering', 'valuable'),
#  ('offering', 'valuable', 'insights'),
#  ('valuable', 'insights', 'for'),
#  ('insights', 'for', 'businesses'),
#  ('for', 'businesses', 'and'),
#  ('businesses', 'and', 'researchers.Machine'),
#  ('and', 'researchers.Machine', 'translation'),
#  ('researchers.Machine', 'translation', ','),
#  ('translation', ',', 'another'),
#  (',', 'another', 'cornerstone'),
#  ('another', 'cornerstone', 'application'),
#  ('cornerstone', 'application', 'of'),
#  ('application', 'of', 'NLP'),
#  ('of', 'NLP', ','),
#  ('NLP', ',', 'has'),
#  (',', 'has', 'undergone'),
#  ('has', 'undergone', 'remarkable'),
#  ('undergone', 'remarkable', 'transformations'),
#  ('remarkable', 'transformations', '.'),
#  ('transformations', '.', 'Neural'),
#  ('.', 'Neural', 'machine'),
#  ('Neural', 'machine', 'translation'),
#  ('machine', 'translation', 'models'),
#  ('translation', 'models', ','),
#  ('models', ',', 'driven'),
#  (',', 'driven', 'by'),
#  ('driven', 'by', 'deep'),
#  ('by', 'deep', 'learning'),
#  ('deep', 'learning', ','),
#  ('learning', ',', 'have'),
#  (',', 'have', 'significantly'),
#  ('have', 'significantly', 'improved'),
#  ('significantly', 'improved', 'the'),
#  ('improved', 'the', 'accuracy'),
#  ('the', 'accuracy', 'and'),
#  ('accuracy', 'and', 'fluency'),
#  ('and', 'fluency', 'of'),
#  ('fluency', 'of', 'translations'),
#  ('of', 'translations', ','),
#  ('translations', ',', 'making'),
#  (',', 'making', 'cross-language'),
#  ('making', 'cross-language', 'communication'),
#  ('cross-language', 'communication', 'more'),
#  ('communication', 'more', 'accessible'),
#  ('more', 'accessible', '.'),
#  ('accessible', '.', 'Moreover'),
#  ('.', 'Moreover', ','),
#  ('Moreover', ',', 'in'),
#  (',', 'in', 'the'),
#  ('in', 'the', 'realm'),
#  ('the', 'realm', 'of'),
#  ('realm', 'of', 'healthcare'),
#  ('of', 'healthcare', ','),
#  ('healthcare', ',', 'NLP'),
#  (',', 'NLP', 'contributes'),
#  ('NLP', 'contributes', 'to'),
#  ('contributes', 'to', 'clinical'),
#  ('to', 'clinical', 'decision'),
#  ('clinical', 'decision', 'support'),
#  ('decision', 'support', 'systems'),
#  ('support', 'systems', ','),
#  ('systems', ',', 'extracting'),
#  (',', 'extracting', 'valuable'),
#  ('extracting', 'valuable', 'information'),
#  ('valuable', 'information', 'from'),
#  ('information', 'from', 'electronic'),
#  ('from', 'electronic', 'health'),
#  ('electronic', 'health', 'records'),
#  ('health', 'records', 'and'),
#  ('records', 'and', 'medical'),
#  ('and', 'medical', 'literature'),
#  ('medical', 'literature', ','),
#  ('literature', ',', 'aiding'),
#  (',', 'aiding', 'healthcare'),
#  ('aiding', 'healthcare', 'professionals'),
#  ('healthcare', 'professionals', 'in'),
#  ('professionals', 'in', 'making'),
#  ('in', 'making', 'informed'),
#  ('making', 'informed', 'decisions.Despite'),
#  ('informed', 'decisions.Despite', 'these'),
#  ('decisions.Despite', 'these', 'advancements'),
#  ('these', 'advancements', ','),
#  ('advancements', ',', 'challenges'),
#  (',', 'challenges', 'persist'),
#  ('challenges', 'persist', 'within'),
#  ('persist', 'within', 'the'),
#  ('within', 'the', 'realm'),
#  ('the', 'realm', 'of'),
#  ('realm', 'of', 'NLP'),
#  ('of', 'NLP', '.'),
#  ('NLP', '.', 'The'),
#  ('.', 'The', 'understanding'),
#  ('The', 'understanding', 'of'),
#  ('understanding', 'of', 'context'),
#  ('of', 'context', ','),
#  ('context', ',', 'especially'),
#  (',', 'especially', 'in'),
#  ('especially', 'in', 'ambiguous'),
#  ('in', 'ambiguous', 'scenarios'),
#  ('ambiguous', 'scenarios', ','),
#  ('scenarios', ',', 'remains'),
#  (',', 'remains', 'an'),
#  ('remains', 'an', 'ongoing'),
#  ('an', 'ongoing', 'area'),
#  ('ongoing', 'area', 'of'),
#  ('area', 'of', 'research'),
#  ('of', 'research', '.'),
#  ('research', '.', 'Issues'),
#  ('.', 'Issues', 'of'),
#  ('Issues', 'of', 'bias'),
#  ('of', 'bias', 'and'),
#  ('bias', 'and', 'fairness'),
#  ('and', 'fairness', 'in'),
#  ('fairness', 'in', 'language'),
#  ('in', 'language', 'models'),
#  ('language', 'models', 'have'),
#  ('models', 'have', 'garnered'),
#  ('have', 'garnered', 'increased'),
#  ('garnered', 'increased', 'attention'),
#  ('increased', 'attention', ','),
#  ('attention', ',', 'necessitating'),
#  (',', 'necessitating', 'ethical'),
#  ('necessitating', 'ethical', 'considerations'),
#  ('ethical', 'considerations', 'in'),
#  ('considerations', 'in', 'the'),
#  ('in', 'the', 'development'),
#  ('the', 'development', 'and'),
#  ('development', 'and', 'deployment'),
#  ('and', 'deployment', 'of'),
#  ('deployment', 'of', 'NLP'),
#  ('of', 'NLP', 'systems'),
#  ('NLP', 'systems', '.'),
#  ('systems', '.', 'Additionally'),
#  ('.', 'Additionally', ','),
#  ('Additionally', ',', 'the'),
#  (',', 'the', 'multilingual'),
#  ('the', 'multilingual', 'nature'),
#  ('multilingual', 'nature', 'of'),
#  ('nature', 'of', 'communication'),
#  ('of', 'communication', 'poses'),
#  ('communication', 'poses', 'a'),
#  ('poses', 'a', 'challenge'),
#  ('a', 'challenge', ','),
#  ('challenge', ',', 'requiring'),
#  (',', 'requiring', 'NLP'),
#  ('requiring', 'NLP', 'models'),
#  ('NLP', 'models', 'to'),
#  ('models', 'to', 'be'),
#  ('to', 'be', 'adept'),
#  ('be', 'adept', 'at'),
#  ('adept', 'at', 'understanding'),
#  ('at', 'understanding', 'diverse'),
#  ('understanding', 'diverse', 'linguistic'),
#  ('diverse', 'linguistic', 'structures'),
#  ('linguistic', 'structures', 'and'),
#  ('structures', 'and', 'cultural'),
#  ('and', 'cultural', 'nuances.The'),
#  ('cultural', 'nuances.The', 'future'),
#  ('nuances.The', 'future', 'trajectory'),
#  ('future', 'trajectory', 'of'),
#  ('trajectory', 'of', 'NLP'),
#  ('of', 'NLP', 'holds'),
#  ('NLP', 'holds', 'immense'),
#  ('holds', 'immense', 'promise'),
#  ('immense', 'promise', 'and'),
#  ('promise', 'and', 'raises'),
#  ('and', 'raises', 'intriguing'),
#  ('raises', 'intriguing', 'possibilities'),
#  ('intriguing', 'possibilities', '.'),
#  ('possibilities', '.', 'Continued'),
#  ('.', 'Continued', 'advancements'),
#  ('Continued', 'advancements', 'in'),
#  ('advancements', 'in', 'transformer'),
#  ('in', 'transformer', 'architectures'),
#  ('transformer', 'architectures', ','),
#  ('architectures', ',', 'coupled'),
#  (',', 'coupled', 'with'),
#  ('coupled', 'with', 'ongoing'),
#  ('with', 'ongoing', 'research'),
#  ('ongoing', 'research', 'in'),
#  ('research', 'in', 'unsupervised'),
#  ('in', 'unsupervised', 'and'),
#  ('unsupervised', 'and', 'self-supervised'),
#  ('and', 'self-supervised', 'learning'),
#  ('self-supervised', 'learning', ','),
#  ('learning', ',', 'are'),
#  (',', 'are', 'expected'),
#  ('are', 'expected', 'to'),
#  ('expected', 'to', 'further'),
#  ('to', 'further', 'enhance'),
#  ('further', 'enhance', 'the'),
#  ('enhance', 'the', 'capabilities'),
#  ('the', 'capabilities', 'of'),
#  ('capabilities', 'of', 'NLP'),
#  ('of', 'NLP', 'models'),
#  ('NLP', 'models', '.'),
#  ('models', '.', 'The'),
#  ('.', 'The', 'pursuit'),
#  ('The', 'pursuit', 'of'),
#  ('pursuit', 'of', 'Explainable'),
#  ('of', 'Explainable', 'AI'),
#  ('Explainable', 'AI', '('),
#  ('AI', '(', 'XAI'),
#  ('(', 'XAI', ')'),
#  ('XAI', ')', 'within'),
#  (')', 'within', 'NLP'),
#  ('within', 'NLP', 'aims'),
#  ('NLP', 'aims', 'to'),
#  ('aims', 'to', 'demystify'),
#  ('to', 'demystify', 'the'),
#  ('demystify', 'the', 'decision-making'),
#  ('the', 'decision-making', 'processes'),
#  ('decision-making', 'processes', 'of'),
#  ('processes', 'of', 'these'),
#  ('of', 'these', 'models'),
#  ('these', 'models', ','),
#  ('models', ',', 'fostering'),
#  (',', 'fostering', 'transparency'),
#  ('fostering', 'transparency', 'and'),
#  ('transparency', 'and', 'trust.In'),
#  ('and', 'trust.In', 'conclusion'),
#  ('trust.In', 'conclusion', ','),
#  ('conclusion', ',', 'Natural'),
#  (',', 'Natural', 'Language'),
#  ('Natural', 'Language', 'Processing'),
#  ('Language', 'Processing', 'stands'),
#  ('Processing', 'stands', 'as'),
#  ('stands', 'as', 'a'),
#  ('as', 'a', 'testament'),
#  ('a', 'testament', 'to'),
#  ('testament', 'to', 'the'),
#  ('to', 'the', 'remarkable'),
#  ('the', 'remarkable', 'convergence'),
#  ('remarkable', 'convergence', 'of'),
#  ('convergence', 'of', 'linguistics'),
#  ('of', 'linguistics', ','),
#  ('linguistics', ',', 'computer'),
#  (',', 'computer', 'science'),
#  ('computer', 'science', ','),
#  ('science', ',', 'and'),
#  (',', 'and', 'artificial'),
#  ('and', 'artificial', 'intelligence'),
#  ('artificial', 'intelligence', '.'),
#  ('intelligence', '.', 'From'),
#  ('.', 'From', 'rule-based'),
#  ('From', 'rule-based', 'systems'),
#  ('rule-based', 'systems', 'to'),
#  ('systems', 'to', 'state-of-the-art'),
#  ('to', 'state-of-the-art', 'transformer'),
#  ('state-of-the-art', 'transformer', 'models'),
#  ('transformer', 'models', ','),
#  ('models', ',', 'the'),
#  (',', 'the', 'journey'),
#  ('the', 'journey', 'of'),
#  ('journey', 'of', 'NLP'),
#  ('of', 'NLP', 'reflects'),
#  ('NLP', 'reflects', 'a'),
#  ('reflects', 'a', 'relentless'),
#  ('a', 'relentless', 'pursuit'),
#  ('relentless', 'pursuit', 'of'),
#  ('pursuit', 'of', 'understanding'),
#  ('of', 'understanding', 'and'),
#  ('understanding', 'and', 'harnessing'),
#  ('and', 'harnessing', 'the'),
#  ('harnessing', 'the', 'power'),
#  ('the', 'power', 'of'),
#  ('power', 'of', 'human'),
#  ('of', 'human', 'language'),
#  ('human', 'language', '.'),
#  ('language', '.', 'As'),
#  ('.', 'As', 'NLP'),
#  ('As', 'NLP', 'continues'),
#  ('NLP', 'continues', 'to'),
#  ('continues', 'to', 'shape'),
#  ('to', 'shape', 'our'),
#  ('shape', 'our', 'digital'),
#  ('our', 'digital', 'interactions'),
#  ('digital', 'interactions', ','),
#  ('interactions', ',', 'its'),
#  (',', 'its', 'impact'),
#  ('its', 'impact', 'reverberates'),
#  ('impact', 'reverberates', 'across'),
#  ('reverberates', 'across', 'industries'),
#  ('across', 'industries', ','),
#  ('industries', ',', 'shaping'),
#  (',', 'shaping', 'the'),
#  ('shaping', 'the', 'way'),
#  ('the', 'way', 'we'),
#  ('way', 'we', 'communicate'),
#  ('we', 'communicate', ','),
#  ('communicate', ',', 'gather'),
#  (',', 'gather', 'information'),
#  ('gather', 'information', ','),
#  ('information', ',', 'and'),
#  (',', 'and', 'engage'),
#  ('and', 'engage', 'with'),
#  ('engage', 'with', 'technology'),
#  ('with', 'technology', '.'),
#  ('technology', '.', 'The'),
#  ('.', 'The', 'ongoing'),
#  ('The', 'ongoing', 'exploration'),
#  ('ongoing', 'exploration', 'of'),
#  ('exploration', 'of', 'NLP'),
#  ('of', 'NLP', 'holds'),
#  ('NLP', 'holds', 'the'),
#  ('holds', 'the', 'promise'),
#  ('the', 'promise', 'of'),
#  ('promise', 'of', 'not'),
#  ('of', 'not', 'only'),
#  ('not', 'only', 'unraveling'),
#  ('only', 'unraveling', 'the'),
#  ('unraveling', 'the', 'intricacies'),
#  ('the', 'intricacies', 'of'),
#  ('intricacies', 'of', 'language'),
#  ('of', 'language', 'but'),
#  ('language', 'but', 'also'),
#  ('but', 'also', 'fostering'),
#  ('also', 'fostering', 'a'),
#  ('fostering', 'a', 'more'),
#  ('a', 'more', 'connected'),
#  ('more', 'connected', 'and'),
#  ('connected', 'and', 'intelligible'),
#  ('and', 'intelligible', 'future'),
#  ('intelligible', 'future', 'between'),
#  ('future', 'between', 'humans'),
#  ('between', 'humans', 'and'),
#  ('humans', 'and', 'machines.Computer'),
#  ('and', 'machines.Computer', 'vision'),
#  ('machines.Computer', 'vision', ','),
#  ('vision', ',', 'an'),
#  (',', 'an', 'interdisciplinary'),
#  ('an', 'interdisciplinary', 'field'),
#  ('interdisciplinary', 'field', 'situated'),
#  ('field', 'situated', 'at'),
#  ('situated', 'at', 'the'),
#  ('at', 'the', 'intersection'),
#  ('the', 'intersection', 'of'),
#  ('intersection', 'of', 'computer'),
#  ('of', 'computer', 'science'),
#  ('computer', 'science', ','),
#  ('science', ',', 'machine'),
#  (',', 'machine', 'learning'),
#  ('machine', 'learning', ','),
#  ('learning', ',', 'and'),
#  (',', 'and', 'image'),
#  ('and', 'image', 'processing'),
#  ('image', 'processing', ','),
#  ('processing', ',', 'seeks'),
#  (',', 'seeks', 'to'),
#  ('seeks', 'to', 'emulate'),
#  ('to', 'emulate', 'human'),
#  ('emulate', 'human', 'vision'),
#  ('human', 'vision', 'capabilities'),
#  ('vision', 'capabilities', 'in'),
#  ('capabilities', 'in', 'machines'),
#  ('in', 'machines', '.'),
#  ('machines', '.', 'At'),
#  ('.', 'At', 'its'),
#  ('At', 'its', 'essence'),
#  ('its', 'essence', ','),
#  ('essence', ',', 'computer'),
#  (',', 'computer', 'vision'),
#  ('computer', 'vision', 'endeavors'),
#  ('vision', 'endeavors', 'to'),
#  ('endeavors', 'to', 'empower'),
#  ('to', 'empower', 'machines'),
#  ('empower', 'machines', 'with'),
#  ('machines', 'with', 'the'),
#  ('with', 'the', 'ability'),
#  ('the', 'ability', 'to'),
#  ('ability', 'to', 'interpret'),
#  ('to', 'interpret', 'and'),
#  ('interpret', 'and', 'understand'),
#  ('and', 'understand', 'visual'),
#  ('understand', 'visual', 'information'),
#  ('visual', 'information', 'from'),
#  ('information', 'from', 'the'),
#  ('from', 'the', 'world'),
#  ('the', 'world', 'around'),
#  ('world', 'around', 'them'),
#  ('around', 'them', '.'),
#  ('them', '.', 'Anchored'),
#  ('.', 'Anchored', 'by'),
#  ('Anchored', 'by', 'a'),
#  ('by', 'a', 'myriad'),
#  ('a', 'myriad', 'of'),
#  ('myriad', 'of', 'algorithms'),
#  ('of', 'algorithms', ','),
#  ('algorithms', ',', 'models'),
#  (',', 'models', ','),
#  ('models', ',', 'and'),
#  (',', 'and', 'technologies'),
#  ('and', 'technologies', ','),
#  ('technologies', ',', 'computer'),
#  (',', 'computer', 'vision'),
#  ('computer', 'vision', 'has'),
#  ('vision', 'has', 'evolved'),
#  ('has', 'evolved', 'from'),
#  ('evolved', 'from', 'basic'),
#  ('from', 'basic', 'image'),
#  ('basic', 'image', 'processing'),
#  ('image', 'processing', 'tasks'),
#  ('processing', 'tasks', 'to'),
#  ('tasks', 'to', 'sophisticated'),
#  ('to', 'sophisticated', 'applications'),
#  ('sophisticated', 'applications', 'that'),
#  ('applications', 'that', 'transcend'),
#  ('that', 'transcend', 'human'),
#  ('transcend', 'human', 'visual'),
#  ('human', 'visual', 'abilities.The'),
#  ('visual', 'abilities.The', 'foundational'),
#  ('abilities.The', 'foundational', 'principle'),
#  ('foundational', 'principle', 'of'),
#  ('principle', 'of', 'computer'),
#  ('of', 'computer', 'vision'),
#  ('computer', 'vision', 'lies'),
#  ('vision', 'lies', 'in'),
#  ('lies', 'in', 'image'),
#  ('in', 'image', 'understanding'),
#  ('image', 'understanding', 'and'),
#  ('understanding', 'and', 'pattern'),
#  ('and', 'pattern', 'recognition'),
#  ('pattern', 'recognition', '.'),
#  ('recognition', '.', 'Early'),
#  ('.', 'Early', 'developments'),
#  ('Early', 'developments', 'centered'),
#  ('developments', 'centered', 'on'),
#  ('centered', 'on', 'tasks'),
#  ('on', 'tasks', 'such'),
#  ('tasks', 'such', 'as'),
#  ('such', 'as', 'image'),
#  ('as', 'image', 'segmentation'),
#  ('image', 'segmentation', 'and'),
#  ('segmentation', 'and', 'object'),
#  ('and', 'object', 'detection'),
#  ('object', 'detection', ','),
#  ('detection', ',', 'where'),
#  (',', 'where', 'algorithms'),
#  ('where', 'algorithms', 'were'),
#  ('algorithms', 'were', 'designed'),
#  ('were', 'designed', 'to'),
#  ('designed', 'to', 'identify'),
#  ('to', 'identify', 'and'),
#  ('identify', 'and', 'delineate'),
#  ('and', 'delineate', 'distinct'),
#  ('delineate', 'distinct', 'elements'),
#  ('distinct', 'elements', 'within'),
#  ('elements', 'within', 'an'),
#  ('within', 'an', 'image'),
#  ('an', 'image', '.'),
#  ('image', '.', 'As'),
#  ('.', 'As', 'the'),
#  ('As', 'the', 'field'),
#  ('the', 'field', 'progressed'),
#  ('field', 'progressed', ','),
#  ('progressed', ',', 'the'),
#  (',', 'the', 'advent'),
#  ('the', 'advent', 'of'),
#  ('advent', 'of', 'feature'),
#  ('of', 'feature', 'extraction'),
#  ('feature', 'extraction', 'techniques'),
#  ('extraction', 'techniques', ','),
#  ('techniques', ',', 'including'),
#  (',', 'including', 'edge'),
#  ('including', 'edge', 'detection'),
#  ('edge', 'detection', 'and'),
#  ('detection', 'and', 'corner'),
#  ('and', 'corner', 'detection'),
#  ('corner', 'detection', ','),
#  ('detection', ',', 'enhanced'),
#  (',', 'enhanced', 'the'),
#  ('enhanced', 'the', 'ability'),
#  ('the', 'ability', 'of'),
#  ('ability', 'of', 'systems'),
#  ('of', 'systems', 'to'),
#  ('systems', 'to', 'capture'),
#  ('to', 'capture', 'and'),
#  ('capture', 'and', 'analyze'),
#  ('and', 'analyze', 'intricate'),
#  ('analyze', 'intricate', 'details'),
#  ('intricate', 'details', 'in'),
#  ('details', 'in', 'visual'),
#  ('in', 'visual', 'data.Advancements'),
#  ('visual', 'data.Advancements', 'in'),
#  ('data.Advancements', 'in', 'machine'),
#  ('in', 'machine', 'learning'),
#  ('machine', 'learning', ','),
#  ('learning', ',', 'particularly'),
#  (',', 'particularly', 'the'),
#  ('particularly', 'the', 'rise'),
#  ('the', 'rise', 'of'),
#  ('rise', 'of', 'deep'),
#  ('of', 'deep', 'learning'),
#  ('deep', 'learning', 'architectures'),
#  ('learning', 'architectures', ','),
#  ('architectures', ',', 'marked'),
#  (',', 'marked', 'a'),
#  ('marked', 'a', 'watershed'),
#  ('a', 'watershed', 'moment'),
#  ('watershed', 'moment', 'in'),
#  ('moment', 'in', 'the'),
#  ('in', 'the', 'evolution'),
#  ('the', 'evolution', 'of'),
#  ('evolution', 'of', 'computer'),
#  ('of', 'computer', 'vision'),
#  ('computer', 'vision', '.'),
#  ('vision', '.', 'Convolutional'),
#  ('.', 'Convolutional', 'Neural'),
#  ('Convolutional', 'Neural', 'Networks'),
#  ('Neural', 'Networks', '('),
#  ('Networks', '(', 'CNNs'),
#  ('(', 'CNNs', ')'),
#  ('CNNs', ')', 'emerged'),
#  (')', 'emerged', 'as'),
#  ('emerged', 'as', 'a'),
#  ('as', 'a', 'cornerstone'),
#  ('a', 'cornerstone', 'technology'),
#  ('cornerstone', 'technology', ','),
#  ('technology', ',', 'revolutionizing'),
#  (',', 'revolutionizing', 'image'),
#  ('revolutionizing', 'image', 'classification'),
#  ('image', 'classification', ','),
#  ('classification', ',', 'object'),
#  (',', 'object', 'detection'),
#  ('object', 'detection', ','),
#  ('detection', ',', 'and'),
#  (',', 'and', 'semantic'),
#  ('and', 'semantic', 'segmentation'),
#  ('semantic', 'segmentation', '.'),
#  ('segmentation', '.', 'Pioneering'),
#  ('.', 'Pioneering', 'models'),
#  ('Pioneering', 'models', 'like'),
#  ('models', 'like', 'AlexNet'),
#  ('like', 'AlexNet', ','),
#  ('AlexNet', ',', 'VGGNet'),
#  (',', 'VGGNet', ','),
#  ('VGGNet', ',', 'and'),
#  (',', 'and', 'ResNet'),
#  ...]

# %%
wordlist = daw_corpus.words()
bigramlist = list(ngrams(wordlist,2))

# %%
bigramlist
# Out:
# [('Natural', 'Language'),
#  ('Language', 'Processing'),
#  ('Processing', '('),
#  ('(', 'NLP'),
#  ('NLP', ')'),
#  (')', 'represents'),
#  ('represents', 'a'),
#  ('a', 'transformative'),
#  ('transformative', 'field'),
#  ('field', 'within'),
#  ('within', 'the'),
#  ('the', 'domain'),
#  ('domain', 'of'),
#  ('of', 'artificial'),
#  ('artificial', 'intelligence'),
#  ('intelligence', ','),
#  (',', 'dedicated'),
#  ('dedicated', 'to'),
#  ('to', 'unraveling'),
#  ('unraveling', 'the'),
#  ('the', 'complexities'),
#  ('complexities', 'of'),
#  ('of', 'human'),
#  ('human', 'language'),
#  ('language', 'and'),
#  ('and', 'enabling'),
#  ('enabling', 'machines'),
#  ('machines', 'to'),
#  ('to', 'comprehend'),
#  ('comprehend', ','),
#  (',', 'interpret'),
#  ('interpret', ','),
#  (',', 'and'),
#  ('and', 'generate'),
#  ('generate', 'human'),
#  ('human', '-'),
#  ('-', 'like'),
#  ('like', 'text'),
#  ('text', '.'),
#  ('.', 'At'),
#  ('At', 'its'),
#  ('its', 'core'),
#  ('core', ','),
#  (',', 'NLP'),
#  ('NLP', 'seeks'),
#  ('seeks', 'to'),
#  ('to', 'bridge'),
#  ('bridge', 'the'),
#  ('the', 'communication'),
#  ('communication', 'gap'),
#  ('gap', 'between'),
#  ('between', 'humans'),
#  ('humans', 'and'),
#  ('and', 'computers'),
#  ('computers', ','),
#  (',', 'opening'),
#  ('opening', 'up'),
#  ('up', 'avenues'),
#  ('avenues', 'for'),
#  ('for', 'seamless'),
#  ('seamless', 'interaction'),
#  ('interaction', 'and'),
#  ('and', 'understanding'),
#  ('understanding', '.'),
#  ('.', 'This'),
#  ('This', 'interdisciplinary'),
#  ('interdisciplinary', 'field'),
#  ('field', 'draws'),
#  ('draws', 'upon'),
#  ('upon', 'linguistics'),
#  ('linguistics', ','),
#  (',', 'computer'),
#  ('computer', 'science'),
#  ('science', ','),
#  (',', 'and'),
#  ('and', 'machine'),
#  ('machine', 'learning'),
#  ('learning', ','),
#  (',', 'fusing'),
#  ('fusing', 'these'),
#  ('these', 'domains'),
#  ('domains', 'to'),
#  ('to', 'create'),
#  ('create', 'algorithms'),
#  ('algorithms', 'and'),
#  ('and', 'models'),
#  ('models', 'that'),
#  ('that', 'can'),
#  ('can', 'navigate'),
#  ('navigate', 'the'),
#  ('the', 'nuances'),
#  ('nuances', 'of'),
#  ('of', 'natural'),
#  ('natural', 'language'),
#  ('language', '.'),
#  ('.', 'One'),
#  ('One', 'of'),
#  ('of', 'the'),
#  ('the', 'foundational'),
#  ('foundational', 'challenges'),
#  ('challenges', 'that'),
#  ('that', 'NLP'),
#  ('NLP', 'addresses'),
#  ('addresses', 'is'),
#  ('is', 'the'),
#  ('the', 'inherent'),
#  ('inherent', 'ambiguity'),
#  ('ambiguity', 'and'),
#  ('and', 'variability'),
#  ('variability', 'present'),
#  ('present', 'in'),
#  ('in', 'human'),
#  ('human', 'language'),
#  ('language', '.'),
#  ('.', 'Unlike'),
#  ('Unlike', 'structured'),
#  ('structured', 'data'),
#  ('data', ','),
#  (',', 'natural'),
#  ('natural', 'language'),
#  ('language', 'is'),
#  ('is', 'rich'),
#  ('rich', ','),
#  (',', 'context'),
#  ('context', '-'),
#  ('-', 'dependent'),
#  ('dependent', ','),
#  (',', 'and'),
#  ('and', 'laden'),
#  ('laden', 'with'),
#  ('with', 'intricacies'),
#  ('intricacies', 'such'),
#  ('such', 'as'),
#  ('as', 'idioms'),
#  ('idioms', ','),
#  (',', 'metaphors'),
#  ('metaphors', ','),
#  (',', 'and'),
#  ('and', 'cultural'),
#  ('cultural', 'nuances'),
#  ('nuances', '.'),
#  ('.', 'NLP'),
#  ('NLP', 'algorithms'),
#  ('algorithms', 'grapple'),
#  ('grapple', 'with'),
#  ('with', 'these'),
#  ('these', 'challenges'),
#  ('challenges', ','),
#  (',', 'aiming'),
#  ('aiming', 'to'),
#  ('to', 'impart'),
#  ('impart', 'machines'),
#  ('machines', 'with'),
#  ('with', 'the'),
#  ('the', 'capability'),
#  ('capability', 'to'),
#  ('to', 'comprehend'),
#  ('comprehend', 'the'),
#  ('the', 'subtleties'),
#  ('subtleties', 'of'),
#  ('of', 'language'),
#  ('language', ','),
#  (',', 'discern'),
#  ('discern', 'sentiment'),
#  ('sentiment', ','),
#  (',', 'and'),
#  ('and', 'extract'),
#  ('extract', 'meaningful'),
#  ('meaningful', 'information'),
#  ('information', 'from'),
#  ('from', 'vast'),
#  ('vast', 'corpora'),
#  ('corpora', 'of'),
#  ('of', 'text'),
#  ('text', '.'),
#  ('.', 'The'),
#  ('The', 'evolution'),
#  ('evolution', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'can'),
#  ('can', 'be'),
#  ('be', 'traced'),
#  ('traced', 'back'),
#  ('back', 'to'),
#  ('to', 'the'),
#  ('the', 'mid'),
#  ('mid', '-'),
#  ('-', '20th'),
#  ('20th', 'century'),
#  ('century', 'when'),
#  ('when', 'researchers'),
#  ('researchers', 'began'),
#  ('began', 'exploring'),
#  ('exploring', 'the'),
#  ('the', 'possibility'),
#  ('possibility', 'of'),
#  ('of', 'teaching'),
#  ('teaching', 'computers'),
#  ('computers', 'to'),
#  ('to', 'understand'),
#  ('understand', 'and'),
#  ('and', 'generate'),
#  ('generate', 'human'),
#  ('human', 'language'),
#  ('language', '.'),
#  ('.', 'Early'),
#  ('Early', 'endeavors'),
#  ('endeavors', 'were'),
#  ('were', 'marked'),
#  ('marked', 'by'),
#  ('by', 'rule'),
#  ('rule', '-'),
#  ('-', 'based'),
#  ('based', 'systems'),
#  ('systems', ','),
#  (',', 'where'),
#  ('where', 'linguistic'),
#  ('linguistic', 'rules'),
#  ('rules', 'were'),
#  ('were', 'manually'),
#  ('manually', 'crafted'),
#  ('crafted', 'to'),
#  ('to', 'parse'),
#  ('parse', 'and'),
#  ('and', 'analyze'),
#  ('analyze', 'text'),
#  ('text', '.'),
#  ('.', 'However'),
#  ('However', ','),
#  (',', 'the'),
#  ('the', 'inherent'),
#  ('inherent', 'limitations'),
#  ('limitations', 'of'),
#  ('of', 'rule'),
#  ('rule', '-'),
#  ('-', 'based'),
#  ('based', 'approaches'),
#  ('approaches', 'became'),
#  ('became', 'evident'),
#  ('evident', 'as'),
#  ('as', 'the'),
#  ('the', 'scale'),
#  ('scale', 'and'),
#  ('and', 'complexity'),
#  ('complexity', 'of'),
#  ('of', 'linguistic'),
#  ('linguistic', 'patterns'),
#  ('patterns', 'expanded'),
#  ('expanded', '.'),
#  ('.', 'The'),
#  ('The', 'advent'),
#  ('advent', 'of'),
#  ('of', 'machine'),
#  ('machine', 'learning'),
#  ('learning', 'and'),
#  ('and', 'the'),
#  ('the', 'availability'),
#  ('availability', 'of'),
#  ('of', 'large'),
#  ('large', '-'),
#  ('-', 'scale'),
#  ('scale', 'linguistic'),
#  ('linguistic', 'datasets'),
#  ('datasets', 'revolutionized'),
#  ('revolutionized', 'the'),
#  ('the', 'NLP'),
#  ('NLP', 'landscape'),
#  ('landscape', '.'),
#  ('.', 'Statistical'),
#  ('Statistical', 'models'),
#  ('models', ','),
#  (',', 'particularly'),
#  ('particularly', 'those'),
#  ('those', 'based'),
#  ('based', 'on'),
#  ('on', 'probabilistic'),
#  ('probabilistic', 'approaches'),
#  ('approaches', ','),
#  (',', 'gained'),
#  ('gained', 'prominence'),
#  ('prominence', '.'),
#  ('.', 'These'),
#  ('These', 'models'),
#  ('models', ','),
#  (',', 'often'),
#  ('often', 'utilizing'),
#  ('utilizing', 'techniques'),
#  ('techniques', 'like'),
#  ('like', 'Hidden'),
#  ('Hidden', 'Markov'),
#  ('Markov', 'Models'),
#  ('Models', 'and'),
#  ('and', 'n'),
#  ('n', '-'),
#  ('-', 'gram'),
#  ('gram', 'analysis'),
#  ('analysis', ','),
#  (',', 'demonstrated'),
#  ('demonstrated', 'improved'),
#  ('improved', 'language'),
#  ('language', 'understanding'),
#  ('understanding', 'capabilities'),
#  ('capabilities', 'by'),
#  ('by', 'learning'),
#  ('learning', 'patterns'),
#  ('patterns', 'and'),
#  ('and', 'probabilities'),
#  ('probabilities', 'from'),
#  ('from', 'data'),
#  ('data', '.'),
#  ('.', 'Yet'),
#  ('Yet', ','),
#  (',', 'they'),
#  ('they', 'struggled'),
#  ('struggled', 'with'),
#  ('with', 'the'),
#  ('the', 'contextual'),
#  ('contextual', 'intricacies'),
#  ('intricacies', 'inherent'),
#  ('inherent', 'in'),
#  ('in', 'language'),
#  ('language', '.'),
#  ('.', 'A'),
#  ('A', 'paradigm'),
#  ('paradigm', 'shift'),
#  ('shift', 'occurred'),
#  ('occurred', 'with'),
#  ('with', 'the'),
#  ('the', 'rise'),
#  ('rise', 'of'),
#  ('of', 'neural'),
#  ('neural', 'network'),
#  ('network', '-'),
#  ('-', 'based'),
#  ('based', 'approaches'),
#  ('approaches', ','),
#  (',', 'propelled'),
#  ('propelled', 'by'),
#  ('by', 'the'),
#  ('the', 'deep'),
#  ('deep', 'learning'),
#  ('learning', 'revolution'),
#  ('revolution', '.'),
#  ('.', 'Recurrent'),
#  ('Recurrent', 'Neural'),
#  ('Neural', 'Networks'),
#  ('Networks', '('),
#  ('(', 'RNNs'),
#  ('RNNs', ')'),
#  (')', 'and'),
#  ('and', ','),
#  (',', 'more'),
#  ('more', 'prominently'),
#  ('prominently', ','),
#  (',', 'Transformer'),
#  ('Transformer', 'architectures'),
#  ('architectures', ','),
#  (',', 'exemplified'),
#  ('exemplified', 'by'),
#  ('by', 'models'),
#  ('models', 'like'),
#  ('like', 'BERT'),
#  ('BERT', '('),
#  ('(', 'Bidirectional'),
#  ('Bidirectional', 'Encoder'),
#  ('Encoder', 'Representations'),
#  ('Representations', 'from'),
#  ('from', 'Transformers'),
#  ('Transformers', '),'),
#  ('),', 'GPT'),
#  ('GPT', '('),
#  ('(', 'Generative'),
#  ('Generative', 'Pre'),
#  ('Pre', '-'),
#  ('-', 'trained'),
#  ('trained', 'Transformer'),
#  ('Transformer', '),'),
#  ('),', 'and'),
#  ('and', 'their'),
#  ('their', 'successors'),
#  ('successors', ','),
#  (',', 'have'),
#  ('have', 'redefined'),
#  ('redefined', 'the'),
#  ('the', 'state'),
#  ('state', '-'),
#  ('-', 'of'),
#  ('of', '-'),
#  ('-', 'the'),
#  ('the', '-'),
#  ('-', 'art'),
#  ('art', 'in'),
#  ('in', 'NLP'),
#  ('NLP', '.'),
#  ('.', 'These'),
#  ('These', 'models'),
#  ('models', ','),
#  (',', 'often'),
#  ('often', 'pre'),
#  ('pre', '-'),
#  ('-', 'trained'),
#  ('trained', 'on'),
#  ('on', 'massive'),
#  ('massive', 'datasets'),
#  ('datasets', ','),
#  (',', 'exhibit'),
#  ('exhibit', 'an'),
#  ('an', 'unprecedented'),
#  ('unprecedented', 'capacity'),
#  ('capacity', 'to'),
#  ('to', 'capture'),
#  ('capture', 'contextual'),
#  ('contextual', 'nuances'),
#  ('nuances', ','),
#  (',', 'syntactic'),
#  ('syntactic', 'structures'),
#  ('structures', ','),
#  (',', 'and'),
#  ('and', 'even'),
#  ('even', 'semantic'),
#  ('semantic', 'relationships'),
#  ('relationships', 'within'),
#  ('within', 'language'),
#  ('language', '.'),
#  ('.', 'NLP'),
#  ('NLP', 'applications'),
#  ('applications', 'have'),
#  ('have', 'permeated'),
#  ('permeated', 'various'),
#  ('various', 'facets'),
#  ('facets', 'of'),
#  ('of', 'our'),
#  ('our', 'daily'),
#  ('daily', 'lives'),
#  ('lives', ','),
#  (',', 'showcasing'),
#  ('showcasing', 'the'),
#  ('the', 'practical'),
#  ('practical', 'impact'),
#  ('impact', 'of'),
#  ('of', 'this'),
#  ('this', 'field'),
#  ('field', '.'),
#  ('.', 'Virtual'),
#  ('Virtual', 'assistants'),
#  ('assistants', ','),
#  (',', 'such'),
#  ('such', 'as'),
#  ('as', 'Siri'),
#  ('Siri', 'and'),
#  ('and', 'Alexa'),
#  ('Alexa', ','),
#  (',', 'leverage'),
#  ('leverage', 'NLP'),
#  ('NLP', 'to'),
#  ('to', 'comprehend'),
#  ('comprehend', 'and'),
#  ('and', 'respond'),
#  ('respond', 'to'),
#  ('to', 'spoken'),
#  ('spoken', 'commands'),
#  ('commands', ','),
#  (',', 'showcasing'),
#  ('showcasing', 'the'),
#  ('the', 'ability'),
#  ('ability', 'to'),
#  ('to', 'understand'),
#  ('understand', 'and'),
#  ('and', 'generate'),
#  ('generate', 'human'),
#  ('human', '-'),
#  ('-', 'like'),
#  ('like', 'speech'),
#  ('speech', '.'),
#  ('.', 'Sentiment'),
#  ('Sentiment', 'analysis'),
#  ('analysis', 'tools'),
#  ('tools', 'employ'),
#  ('employ', 'NLP'),
#  ('NLP', 'to'),
#  ('to', 'gauge'),
#  ('gauge', 'the'),
#  ('the', 'mood'),
#  ('mood', 'and'),
#  ('and', 'opinions'),
#  ('opinions', 'expressed'),
#  ('expressed', 'in'),
#  ('in', 'online'),
#  ('online', 'reviews'),
#  ('reviews', ','),
#  (',', 'social'),
#  ('social', 'media'),
#  ('media', 'posts'),
#  ('posts', ','),
#  (',', 'and'),
#  ('and', 'news'),
#  ('news', 'articles'),
#  ('articles', ','),
#  (',', 'offering'),
#  ('offering', 'valuable'),
#  ('valuable', 'insights'),
#  ('insights', 'for'),
#  ('for', 'businesses'),
#  ('businesses', 'and'),
#  ('and', 'researchers'),
#  ('researchers', '.'),
#  ('.', 'Machine'),
#  ('Machine', 'translation'),
#  ('translation', ','),
#  (',', 'another'),
#  ('another', 'cornerstone'),
#  ('cornerstone', 'application'),
#  ('application', 'of'),
#  ('of', 'NLP'),
#  ('NLP', ','),
#  (',', 'has'),
#  ('has', 'undergone'),
#  ('undergone', 'remarkable'),
#  ('remarkable', 'transformations'),
#  ('transformations', '.'),
#  ('.', 'Neural'),
#  ('Neural', 'machine'),
#  ('machine', 'translation'),
#  ('translation', 'models'),
#  ('models', ','),
#  (',', 'driven'),
#  ('driven', 'by'),
#  ('by', 'deep'),
#  ('deep', 'learning'),
#  ('learning', ','),
#  (',', 'have'),
#  ('have', 'significantly'),
#  ('significantly', 'improved'),
#  ('improved', 'the'),
#  ('the', 'accuracy'),
#  ('accuracy', 'and'),
#  ('and', 'fluency'),
#  ('fluency', 'of'),
#  ('of', 'translations'),
#  ('translations', ','),
#  (',', 'making'),
#  ('making', 'cross'),
#  ('cross', '-'),
#  ('-', 'language'),
#  ('language', 'communication'),
#  ('communication', 'more'),
#  ('more', 'accessible'),
#  ('accessible', '.'),
#  ('.', 'Moreover'),
#  ('Moreover', ','),
#  (',', 'in'),
#  ('in', 'the'),
#  ('the', 'realm'),
#  ('realm', 'of'),
#  ('of', 'healthcare'),
#  ('healthcare', ','),
#  (',', 'NLP'),
#  ('NLP', 'contributes'),
#  ('contributes', 'to'),
#  ('to', 'clinical'),
#  ('clinical', 'decision'),
#  ('decision', 'support'),
#  ('support', 'systems'),
#  ('systems', ','),
#  (',', 'extracting'),
#  ('extracting', 'valuable'),
#  ('valuable', 'information'),
#  ('information', 'from'),
#  ('from', 'electronic'),
#  ('electronic', 'health'),
#  ('health', 'records'),
#  ('records', 'and'),
#  ('and', 'medical'),
#  ('medical', 'literature'),
#  ('literature', ','),
#  (',', 'aiding'),
#  ('aiding', 'healthcare'),
#  ('healthcare', 'professionals'),
#  ('professionals', 'in'),
#  ('in', 'making'),
#  ('making', 'informed'),
#  ('informed', 'decisions'),
#  ('decisions', '.'),
#  ('.', 'Despite'),
#  ('Despite', 'these'),
#  ('these', 'advancements'),
#  ('advancements', ','),
#  (',', 'challenges'),
#  ('challenges', 'persist'),
#  ('persist', 'within'),
#  ('within', 'the'),
#  ('the', 'realm'),
#  ('realm', 'of'),
#  ('of', 'NLP'),
#  ('NLP', '.'),
#  ('.', 'The'),
#  ('The', 'understanding'),
#  ('understanding', 'of'),
#  ('of', 'context'),
#  ('context', ','),
#  (',', 'especially'),
#  ('especially', 'in'),
#  ('in', 'ambiguous'),
#  ('ambiguous', 'scenarios'),
#  ('scenarios', ','),
#  (',', 'remains'),
#  ('remains', 'an'),
#  ('an', 'ongoing'),
#  ('ongoing', 'area'),
#  ('area', 'of'),
#  ('of', 'research'),
#  ('research', '.'),
#  ('.', 'Issues'),
#  ('Issues', 'of'),
#  ('of', 'bias'),
#  ('bias', 'and'),
#  ('and', 'fairness'),
#  ('fairness', 'in'),
#  ('in', 'language'),
#  ('language', 'models'),
#  ('models', 'have'),
#  ('have', 'garnered'),
#  ('garnered', 'increased'),
#  ('increased', 'attention'),
#  ('attention', ','),
#  (',', 'necessitating'),
#  ('necessitating', 'ethical'),
#  ('ethical', 'considerations'),
#  ('considerations', 'in'),
#  ('in', 'the'),
#  ('the', 'development'),
#  ('development', 'and'),
#  ('and', 'deployment'),
#  ('deployment', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'systems'),
#  ('systems', '.'),
#  ('.', 'Additionally'),
#  ('Additionally', ','),
#  (',', 'the'),
#  ('the', 'multilingual'),
#  ('multilingual', 'nature'),
#  ('nature', 'of'),
#  ('of', 'communication'),
#  ('communication', 'poses'),
#  ('poses', 'a'),
#  ('a', 'challenge'),
#  ('challenge', ','),
#  (',', 'requiring'),
#  ('requiring', 'NLP'),
#  ('NLP', 'models'),
#  ('models', 'to'),
#  ('to', 'be'),
#  ('be', 'adept'),
#  ('adept', 'at'),
#  ('at', 'understanding'),
#  ('understanding', 'diverse'),
#  ('diverse', 'linguistic'),
#  ('linguistic', 'structures'),
#  ('structures', 'and'),
#  ('and', 'cultural'),
#  ('cultural', 'nuances'),
#  ('nuances', '.'),
#  ('.', 'The'),
#  ('The', 'future'),
#  ('future', 'trajectory'),
#  ('trajectory', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'holds'),
#  ('holds', 'immense'),
#  ('immense', 'promise'),
#  ('promise', 'and'),
#  ('and', 'raises'),
#  ('raises', 'intriguing'),
#  ('intriguing', 'possibilities'),
#  ('possibilities', '.'),
#  ('.', 'Continued'),
#  ('Continued', 'advancements'),
#  ('advancements', 'in'),
#  ('in', 'transformer'),
#  ('transformer', 'architectures'),
#  ('architectures', ','),
#  (',', 'coupled'),
#  ('coupled', 'with'),
#  ('with', 'ongoing'),
#  ('ongoing', 'research'),
#  ('research', 'in'),
#  ('in', 'unsupervised'),
#  ('unsupervised', 'and'),
#  ('and', 'self'),
#  ('self', '-'),
#  ('-', 'supervised'),
#  ('supervised', 'learning'),
#  ('learning', ','),
#  (',', 'are'),
#  ('are', 'expected'),
#  ('expected', 'to'),
#  ('to', 'further'),
#  ('further', 'enhance'),
#  ('enhance', 'the'),
#  ('the', 'capabilities'),
#  ('capabilities', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'models'),
#  ('models', '.'),
#  ('.', 'The'),
#  ('The', 'pursuit'),
#  ('pursuit', 'of'),
#  ('of', 'Explainable'),
#  ('Explainable', 'AI'),
#  ('AI', '('),
#  ('(', 'XAI'),
#  ('XAI', ')'),
#  (')', 'within'),
#  ('within', 'NLP'),
#  ('NLP', 'aims'),
#  ('aims', 'to'),
#  ('to', 'demystify'),
#  ('demystify', 'the'),
#  ('the', 'decision'),
#  ('decision', '-'),
#  ('-', 'making'),
#  ('making', 'processes'),
#  ('processes', 'of'),
#  ('of', 'these'),
#  ('these', 'models'),
#  ('models', ','),
#  (',', 'fostering'),
#  ('fostering', 'transparency'),
#  ('transparency', 'and'),
#  ('and', 'trust'),
#  ('trust', '.'),
#  ('.', 'In'),
#  ('In', 'conclusion'),
#  ('conclusion', ','),
#  (',', 'Natural'),
#  ('Natural', 'Language'),
#  ('Language', 'Processing'),
#  ('Processing', 'stands'),
#  ('stands', 'as'),
#  ('as', 'a'),
#  ('a', 'testament'),
#  ('testament', 'to'),
#  ('to', 'the'),
#  ('the', 'remarkable'),
#  ('remarkable', 'convergence'),
#  ('convergence', 'of'),
#  ('of', 'linguistics'),
#  ('linguistics', ','),
#  (',', 'computer'),
#  ('computer', 'science'),
#  ('science', ','),
#  (',', 'and'),
#  ('and', 'artificial'),
#  ('artificial', 'intelligence'),
#  ('intelligence', '.'),
#  ('.', 'From'),
#  ('From', 'rule'),
#  ('rule', '-'),
#  ('-', 'based'),
#  ('based', 'systems'),
#  ('systems', 'to'),
#  ('to', 'state'),
#  ('state', '-'),
#  ('-', 'of'),
#  ('of', '-'),
#  ('-', 'the'),
#  ('the', '-'),
#  ('-', 'art'),
#  ('art', 'transformer'),
#  ('transformer', 'models'),
#  ('models', ','),
#  (',', 'the'),
#  ('the', 'journey'),
#  ('journey', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'reflects'),
#  ('reflects', 'a'),
#  ('a', 'relentless'),
#  ('relentless', 'pursuit'),
#  ('pursuit', 'of'),
#  ('of', 'understanding'),
#  ('understanding', 'and'),
#  ('and', 'harnessing'),
#  ('harnessing', 'the'),
#  ('the', 'power'),
#  ('power', 'of'),
#  ('of', 'human'),
#  ('human', 'language'),
#  ('language', '.'),
#  ('.', 'As'),
#  ('As', 'NLP'),
#  ('NLP', 'continues'),
#  ('continues', 'to'),
#  ('to', 'shape'),
#  ('shape', 'our'),
#  ('our', 'digital'),
#  ('digital', 'interactions'),
#  ('interactions', ','),
#  (',', 'its'),
#  ('its', 'impact'),
#  ('impact', 'reverberates'),
#  ('reverberates', 'across'),
#  ('across', 'industries'),
#  ('industries', ','),
#  (',', 'shaping'),
#  ('shaping', 'the'),
#  ('the', 'way'),
#  ('way', 'we'),
#  ('we', 'communicate'),
#  ('communicate', ','),
#  (',', 'gather'),
#  ('gather', 'information'),
#  ('information', ','),
#  (',', 'and'),
#  ('and', 'engage'),
#  ('engage', 'with'),
#  ('with', 'technology'),
#  ('technology', '.'),
#  ('.', 'The'),
#  ('The', 'ongoing'),
#  ('ongoing', 'exploration'),
#  ('exploration', 'of'),
#  ('of', 'NLP'),
#  ('NLP', 'holds'),
#  ('holds', 'the'),
#  ('the', 'promise'),
#  ('promise', 'of'),
#  ('of', 'not'),
#  ('not', 'only'),
#  ('only', 'unraveling'),
#  ('unraveling', 'the'),
#  ('the', 'intricacies'),
#  ('intricacies', 'of'),
#  ('of', 'language'),
#  ('language', 'but'),
#  ('but', 'also'),
#  ('also', 'fostering'),
#  ('fostering', 'a'),
#  ('a', 'more'),
#  ('more', 'connected'),
#  ('connected', 'and'),
#  ('and', 'intelligible'),
#  ('intelligible', 'future'),
#  ('future', 'between'),
#  ('between', 'humans'),
#  ('humans', 'and'),
#  ('and', 'machines'),
#  ('machines', '.'),
#  ('.', 'Computer'),
#  ('Computer', 'vision'),
#  ('vision', ','),
#  (',', 'an'),
#  ('an', 'interdisciplinary'),
#  ('interdisciplinary', 'field'),
#  ('field', 'situated'),
#  ('situated', 'at'),
#  ('at', 'the'),
#  ('the', 'intersection'),
#  ('intersection', 'of'),
#  ('of', 'computer'),
#  ('computer', 'science'),
#  ('science', ','),
#  (',', 'machine'),
#  ('machine', 'learning'),
#  ('learning', ','),
#  (',', 'and'),
#  ('and', 'image'),
#  ('image', 'processing'),
#  ('processing', ','),
#  (',', 'seeks'),
#  ('seeks', 'to'),
#  ('to', 'emulate'),
#  ('emulate', 'human'),
#  ('human', 'vision'),
#  ('vision', 'capabilities'),
#  ('capabilities', 'in'),
#  ('in', 'machines'),
#  ('machines', '.'),
#  ('.', 'At'),
#  ('At', 'its'),
#  ('its', 'essence'),
#  ('essence', ','),
#  (',', 'computer'),
#  ('computer', 'vision'),
#  ('vision', 'endeavors'),
#  ('endeavors', 'to'),
#  ('to', 'empower'),
#  ('empower', 'machines'),
#  ('machines', 'with'),
#  ('with', 'the'),
#  ('the', 'ability'),
#  ('ability', 'to'),
#  ('to', 'interpret'),
#  ('interpret', 'and'),
#  ('and', 'understand'),
#  ('understand', 'visual'),
#  ('visual', 'information'),
#  ('information', 'from'),
#  ('from', 'the'),
#  ('the', 'world'),
#  ('world', 'around'),
#  ('around', 'them'),
#  ('them', '.'),
#  ('.', 'Anchored'),
#  ('Anchored', 'by'),
#  ('by', 'a'),
#  ('a', 'myriad'),
#  ('myriad', 'of'),
#  ('of', 'algorithms'),
#  ('algorithms', ','),
#  (',', 'models'),
#  ('models', ','),
#  (',', 'and'),
#  ('and', 'technologies'),
#  ('technologies', ','),
#  (',', 'computer'),
#  ('computer', 'vision'),
#  ('vision', 'has'),
#  ('has', 'evolved'),
#  ('evolved', 'from'),
#  ('from', 'basic'),
#  ('basic', 'image'),
#  ('image', 'processing'),
#  ('processing', 'tasks'),
#  ('tasks', 'to'),
#  ('to', 'sophisticated'),
#  ('sophisticated', 'applications'),
#  ('applications', 'that'),
#  ('that', 'transcend'),
#  ('transcend', 'human'),
#  ('human', 'visual'),
#  ('visual', 'abilities'),
#  ('abilities', '.'),
#  ('.', 'The'),
#  ('The', 'foundational'),
#  ('foundational', 'principle'),
#  ('principle', 'of'),
#  ('of', 'computer'),
#  ('computer', 'vision'),
#  ('vision', 'lies'),
#  ('lies', 'in'),
#  ('in', 'image'),
#  ('image', 'understanding'),
#  ('understanding', 'and'),
#  ('and', 'pattern'),
#  ('pattern', 'recognition'),
#  ('recognition', '.'),
#  ('.', 'Early'),
#  ('Early', 'developments'),
#  ('developments', 'centered'),
#  ('centered', 'on'),
#  ('on', 'tasks'),
#  ('tasks', 'such'),
#  ('such', 'as'),
#  ('as', 'image'),
#  ('image', 'segmentation'),
#  ('segmentation', 'and'),
#  ('and', 'object'),
#  ('object', 'detection'),
#  ('detection', ','),
#  (',', 'where'),
#  ('where', 'algorithms'),
#  ('algorithms', 'were'),
#  ('were', 'designed'),
#  ('designed', 'to'),
#  ('to', 'identify'),
#  ('identify', 'and'),
#  ('and', 'delineate'),
#  ('delineate', 'distinct'),
#  ('distinct', 'elements'),
#  ('elements', 'within'),
#  ('within', 'an'),
#  ('an', 'image'),
#  ('image', '.'),
#  ('.', 'As'),
#  ('As', 'the'),
#  ('the', 'field'),
#  ('field', 'progressed'),
#  ('progressed', ','),
#  (',', 'the'),
#  ('the', 'advent'),
#  ('advent', 'of'),
#  ('of', 'feature'),
#  ('feature', 'extraction'),
#  ('extraction', 'techniques'),
#  ('techniques', ','),
#  (',', 'including'),
#  ('including', 'edge'),
#  ('edge', 'detection'),
#  ('detection', 'and'),
#  ('and', 'corner'),
#  ('corner', 'detection'),
#  ('detection', ','),
#  (',', 'enhanced'),
#  ('enhanced', 'the'),
#  ('the', 'ability'),
#  ('ability', 'of'),
#  ('of', 'systems'),
#  ('systems', 'to'),
#  ...]

# %% [markdown]
# # Task 3: Generating Random Text with Bigrams

# %%
cfd = nltk.ConditionalFreqDist(bigramlist)

# %%
def generate_model(cfdist, word, num):
    for i in range(num):
        print(word, end=' ')
        # Check if the word is in the set of available samples
        if word in cfdist:
            word = cfdist[word].max()
        else:
            break  # Break the loop if there are no more samples

# %%
generate_model(cfd, 'computer', 30)
# Out:
# computer vision , and generate human language . The future trajectory of NLP . The future trajectory of NLP . The future trajectory of NLP . The future trajectory of

# %%
len(wordlist)
# Out:
# 1628
